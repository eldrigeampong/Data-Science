# %% [markdown]
# # Trade of goods , US$, HS 1992, ALL COMMODITIES

# %% [markdown]
# http://unstats.un.org/unsd/
# https://comtrade.un.org/db/mr/rfGlossaryList.aspx

# %% [markdown]
# The United Nations Commodity Trade Statistics Database (UN Comtrade) stores more than 1 billion trade data records from 1962. Over 140 reporter countries provide the United Nations Statistics Division with their annual international trade statistics detailed by commodities and partner countries. These data are subsequently transformed into the United Nations Statistics Division standard format with consistent coding and valuation using the UN/OECD CoprA internal processing system.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings

# %% [markdown]
# # Settings

# %%
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.autolayout'] = True
plt.rcParams['font.size'] = 12
path = Path.cwd()                                          # get current working directory
warnings.filterwarnings('ignore')

# %% [markdown]
# # Fetch Data

# %%
df = pd.read_csv('Trade of goods , US$, HS 1992, ALL COMMODITIES.csv')

# %% [markdown]
# # Head and Tail

# %%
df
# Out:
#       Country or Area  Year        Commodity       Flow   Trade (USD)  \
# 0         Afghanistan  2018  ALL COMMODITIES     Import  7.406590e+09
# 1         Afghanistan  2018  ALL COMMODITIES     Export  8.845045e+08
# 2         Afghanistan  2018  ALL COMMODITIES  Re-Export  9.263097e+06
# 3         Afghanistan  2016  ALL COMMODITIES     Import  6.534140e+09
# 4         Afghanistan  2016  ALL COMMODITIES     Export  5.964553e+08
# ...               ...   ...              ...        ...           ...
# 10139        Zimbabwe  2001  ALL COMMODITIES     Export  1.206663e+09
# 10140        Zimbabwe  2001  ALL COMMODITIES  Re-Export  1.594229e+07
# 10141        Zimbabwe  2000  ALL COMMODITIES     Export  1.879631e+09
# 10142        Zimbabwe  1995  ALL COMMODITIES     Import  2.658853e+09
# 10143        Zimbabwe  1995  ALL COMMODITIES     Export  1.845906e+09
#
#        Weight (kg) Quantity Name  Quantity
# 0              NaN   No Quantity       0.0
# 1              0.0   No Quantity       0.0
# 2              0.0   No Quantity       0.0
# 3              NaN   No Quantity       NaN
# 4              NaN   No Quantity       NaN
# ...            ...           ...       ...
# 10139          NaN   No Quantity       NaN
# 10140          NaN   No Quantity       NaN
# 10141          NaN   No Quantity       NaN
# 10142          NaN   No Quantity       NaN
# 10143          NaN   No Quantity       NaN
#
# [10144 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10144 entries, 0 to 10143
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  10144 non-null  object
#  1   Year             10144 non-null  int64
#  2   Commodity        10144 non-null  object
#  3   Flow             10144 non-null  object
#  4   Trade (USD)      10144 non-null  float64
#  5   Weight (kg)      983 non-null    float64
#  6   Quantity Name    10144 non-null  object
#  7   Quantity         1437 non-null   float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 634.1+ KB

# %%
df.rename(columns={'Country or Area': 'country_or_area'}, inplace=True)                    
df.columns = [col.lower() for col in df.columns]  
df
# Out:
#       country_or_area  year        commodity       flow   trade (usd)  \
# 0         Afghanistan  2018  ALL COMMODITIES     Import  7.406590e+09
# 1         Afghanistan  2018  ALL COMMODITIES     Export  8.845045e+08
# 2         Afghanistan  2018  ALL COMMODITIES  Re-Export  9.263097e+06
# 3         Afghanistan  2016  ALL COMMODITIES     Import  6.534140e+09
# 4         Afghanistan  2016  ALL COMMODITIES     Export  5.964553e+08
# ...               ...   ...              ...        ...           ...
# 10139        Zimbabwe  2001  ALL COMMODITIES     Export  1.206663e+09
# 10140        Zimbabwe  2001  ALL COMMODITIES  Re-Export  1.594229e+07
# 10141        Zimbabwe  2000  ALL COMMODITIES     Export  1.879631e+09
# 10142        Zimbabwe  1995  ALL COMMODITIES     Import  2.658853e+09
# 10143        Zimbabwe  1995  ALL COMMODITIES     Export  1.845906e+09
#
#        weight (kg) quantity name  quantity
# 0              NaN   No Quantity       0.0
# 1              0.0   No Quantity       0.0
# 2              0.0   No Quantity       0.0
# 3              NaN   No Quantity       NaN
# 4              NaN   No Quantity       NaN
# ...            ...           ...       ...
# 10139          NaN   No Quantity       NaN
# 10140          NaN   No Quantity       NaN
# 10141          NaN   No Quantity       NaN
# 10142          NaN   No Quantity       NaN
# 10143          NaN   No Quantity       NaN
#
# [10144 rows x 8 columns]

# %%
cols = ['country_or_area', 'year', 'flow', 'trade (usd)']
df_sub = df[cols]
df_sub
# Out:
#       country_or_area  year       flow   trade (usd)
# 0         Afghanistan  2018     Import  7.406590e+09
# 1         Afghanistan  2018     Export  8.845045e+08
# 2         Afghanistan  2018  Re-Export  9.263097e+06
# 3         Afghanistan  2016     Import  6.534140e+09
# 4         Afghanistan  2016     Export  5.964553e+08
# ...               ...   ...        ...           ...
# 10139        Zimbabwe  2001     Export  1.206663e+09
# 10140        Zimbabwe  2001  Re-Export  1.594229e+07
# 10141        Zimbabwe  2000     Export  1.879631e+09
# 10142        Zimbabwe  1995     Import  2.658853e+09
# 10143        Zimbabwe  1995     Export  1.845906e+09
#
# [10144 rows x 4 columns]

# %% [markdown]
# # Descriptive statistics

# %%
min_trade = np.round(df_sub['trade (usd)'].min(), 2)
mean_trade = np.round(df_sub['trade (usd)'].mean(), 2)
max_trade = np.round(df_sub['trade (usd)'].max(), 2)

print('The minimum, mean and maximum trades are ${:,}, ${:,} and ${:,} respectively'.format(min_trade, mean_trade, max_trade))

df_sub['trade (usd)'].describe(include='number')
# Out:
# The minimum, mean and maximum trades are $2.0, $66,931,662,399.26 and $2,611,432,490,157.0 respectively
# count    1.014400e+04
# mean     6.693166e+10
# std      2.112641e+11
# min      2.000000e+00
# 25%      4.379713e+08
# 50%      4.022039e+09
# 75%      3.381102e+10
# max      2.611432e+12
# Name: trade (usd), dtype: float64

# %% [markdown]
# # Discretization and quantiling

# %%
df_sub['trade cat'] = pd.qcut(df_sub['trade (usd)'], [0, 0.25, 0.5, 0.75, 1], labels=['low', 'medium', 'high', 'very high'])
df_sub
# Out:
#       country_or_area  year       flow   trade (usd) trade cat
# 0         Afghanistan  2018     Import  7.406590e+09      high
# 1         Afghanistan  2018     Export  8.845045e+08    medium
# 2         Afghanistan  2018  Re-Export  9.263097e+06       low
# 3         Afghanistan  2016     Import  6.534140e+09      high
# 4         Afghanistan  2016     Export  5.964553e+08    medium
# ...               ...   ...        ...           ...       ...
# 10139        Zimbabwe  2001     Export  1.206663e+09    medium
# 10140        Zimbabwe  2001  Re-Export  1.594229e+07       low
# 10141        Zimbabwe  2000     Export  1.879631e+09    medium
# 10142        Zimbabwe  1995     Import  2.658853e+09    medium
# 10143        Zimbabwe  1995     Export  1.845906e+09    medium
#
# [10144 rows x 5 columns]

# %%
df_sub.describe(exclude='number')
# Out:
#        country_or_area    flow trade cat
# count            10144   10144     10144
# unique             210       4         4
# top             Canada  Import       low
# freq                98    4173      2536

# %%
df_sub['flow'].value_counts()                     # count unique flow
# Out:
# Import       4173
# Export       4156
# Re-Export    1156
# Re-Import     659
# Name: flow, dtype: int64

# %% [markdown]
# # Dataframe Grouping

# %%
cnt_area_grp = df_sub.groupby(['country_or_area'])
cnt_area_grp.head()
# Out:
#       country_or_area  year       flow   trade (usd) trade cat
# 0         Afghanistan  2018     Import  7.406590e+09      high
# 1         Afghanistan  2018     Export  8.845045e+08    medium
# 2         Afghanistan  2018  Re-Export  9.263097e+06       low
# 3         Afghanistan  2016     Import  6.534140e+09      high
# 4         Afghanistan  2016     Export  5.964553e+08    medium
# ...               ...   ...        ...           ...       ...
# 10100        Zimbabwe  2018     Import  6.258856e+09      high
# 10101        Zimbabwe  2018     Export  4.037203e+09      high
# 10102        Zimbabwe  2017     Import  4.962103e+09      high
# 10103        Zimbabwe  2017     Export  3.480382e+09    medium
# 10104        Zimbabwe  2016     Import  5.211577e+09      high
#
# [1032 rows x 5 columns]

# %%
cnt_area_grp.get_group('China')
# Out:
#      country_or_area  year       flow   trade (usd)  trade cat
# 1958           China  2018     Import  2.134983e+12  very high
# 1959           China  2018     Export  2.494230e+12  very high
# 1960           China  2018  Re-Import  1.463818e+11  very high
# 1961           China  2017     Import  1.843793e+12  very high
# 1962           China  2017     Export  2.263371e+12  very high
# ...              ...   ...        ...           ...        ...
# 2025           China  1994     Export  1.210063e+11  very high
# 2026           China  1993     Import  1.039589e+11  very high
# 2027           China  1993     Export  9.174395e+10  very high
# 2028           China  1992     Import  8.058530e+10  very high
# 2029           China  1992     Export  8.494002e+10  very high
#
# [72 rows x 5 columns]

# %%
cnt_area_grp.get_group('USA')
# Out:
#      country_or_area  year       flow   trade (usd)  trade cat
# 9816             USA  2018     Import  2.611432e+12  very high
# 9817             USA  2018     Export  1.665303e+12  very high
# 9818             USA  2018  Re-Export  2.520493e+11  very high
# 9819             USA  2017     Import  2.405277e+12  very high
# 9820             USA  2017     Export  1.545810e+12  very high
# ...              ...   ...        ...           ...        ...
# 9895             USA  1992     Export  4.473301e+11  very high
# 9896             USA  1992  Re-Export  2.245862e+10       high
# 9897             USA  1991     Import  5.089440e+11  very high
# 9898             USA  1991     Export  4.215554e+11  very high
# 9899             USA  1991  Re-Export  2.057163e+10       high
#
# [84 rows x 5 columns]

# %%
cnt_area_grp.get_group('Germany').head()
# Out:
#      country_or_area  year    flow   trade (usd)  trade cat
# 3726         Germany  2018  Import  1.292726e+12  very high
# 3727         Germany  2018  Export  1.562419e+12  very high
# 3728         Germany  2017  Import  1.167753e+12  very high
# 3729         Germany  2017  Export  1.446642e+12  very high
# 3730         Germany  2016  Import  1.060882e+12  very high

# %%
cnt_area_grp.get_group('Netherlands').head()
# Out:
#      country_or_area  year    flow   trade (usd)  trade cat
# 6300     Netherlands  2018  Import  5.006305e+11  very high
# 6301     Netherlands  2018  Export  5.559214e+11  very high
# 6302     Netherlands  2017  Import  4.618703e+11  very high
# 6303     Netherlands  2017  Export  5.279370e+11  very high
# 6304     Netherlands  2016  Import  4.080650e+11  very high

# %%
cnt_area_grp.get_group('Japan').head()
# Out:
#      country_or_area  year    flow   trade (usd)  trade cat
# 4783           Japan  2019  Import  7.208948e+11  very high
# 4784           Japan  2019  Export  7.056400e+11  very high
# 4785           Japan  2018  Import  7.482176e+11  very high
# 4786           Japan  2018  Export  7.382012e+11  very high
# 4787           Japan  2017  Import  6.714743e+11  very high

# %%
cnt_area_grp.get_group('China, Hong Kong SAR').head()
# Out:
#            country_or_area  year    flow   trade (usd)  trade cat
# 2030  China, Hong Kong SAR  2019  Import  5.785902e+11  very high
# 2031  China, Hong Kong SAR  2019  Export  5.357110e+11  very high
# 2032  China, Hong Kong SAR  2018  Import  6.273270e+11  very high
# 2033  China, Hong Kong SAR  2018  Export  5.691057e+11  very high
# 2034  China, Hong Kong SAR  2017  Import  5.893174e+11  very high

# %%
cnt_area_grp.get_group('Rep. of Korea').head()
# Out:
#      country_or_area  year    flow   trade (usd)  trade cat
# 7312   Rep. of Korea  2018  Import  5.351834e+11  very high
# 7313   Rep. of Korea  2018  Export  6.048073e+11  very high
# 7314   Rep. of Korea  2017  Import  4.784692e+11  very high
# 7315   Rep. of Korea  2017  Export  5.736274e+11  very high
# 7316   Rep. of Korea  2016  Import  4.061819e+11  very high

# %%
cnt_area_grp.get_group('Italy').head()
# Out:
#      country_or_area  year       flow   trade (usd)  trade cat
# 4637           Italy  2018     Import  5.035811e+11  very high
# 4638           Italy  2018     Export  5.499070e+11  very high
# 4639           Italy  2018  Re-Export  2.385311e+10       high
# 4640           Italy  2018  Re-Import  4.986970e+09       high
# 4641           Italy  2017     Import  4.535830e+11  very high

# %%
cnt_area_grp.get_group('France').head()
# Out:
#      country_or_area  year       flow   trade (usd)  trade cat
# 3396          France  2018     Import  6.593745e+11  very high
# 3397          France  2018     Export  5.685359e+11  very high
# 3398          France  2018  Re-Import  5.690757e+09       high
# 3399          France  2017     Import  6.131326e+11  very high
# 3400          France  2017     Export  5.233851e+11  very high

# %%
cnt_area_grp.get_group('Belgium').head()
# Out:
#     country_or_area  year    flow   trade (usd)  trade cat
# 932         Belgium  2018  Import  4.547138e+11  very high
# 933         Belgium  2018  Export  4.686433e+11  very high
# 934         Belgium  2017  Import  4.090248e+11  very high
# 935         Belgium  2017  Export  4.300924e+11  very high
# 936         Belgium  2016  Import  3.792983e+11  very high
