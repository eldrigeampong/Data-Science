# %% [markdown]
# # International migrants and refugees

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings

# %% [markdown]
# # Options and Settings

# %%
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.autolayout'] = True
plt.rcParams['font.size'] = 12
path = os.getcwd()                                         # get current working directory
warnings.simplefilter('ignore')

# %% [markdown]
# # Import Data

# %%
filepath = os.path.join('datasets', 'International Migrants and Refugees.csv')
df = pd.read_csv(filepath)

# %% [markdown]
# # Head and Tail

# %%
df
# Out:
#       Region/Country/Area                     Unnamed: 1  Year  \
# 0                       1  Total, all countries or areas  2005
# 1                       1  Total, all countries or areas  2005
# 2                       1  Total, all countries or areas  2005
# 3                       1  Total, all countries or areas  2005
# 4                       1  Total, all countries or areas  2010
# ...                   ...                            ...   ...
# 6587                  716                       Zimbabwe  2020
# 6588                  716                       Zimbabwe  2020
# 6589                  716                       Zimbabwe  2020
# 6590                  716                       Zimbabwe  2020
# 6591                  716                       Zimbabwe  2020
#
#                                                  Series        Value  \
# 0      International migrant stock: Both sexes (number)  191446828.0
# 1     International migrant stock: Both sexes (% tot...          2.9
# 2     International migrant stock: Male (% total Pop...          3.0
# 3     International migrant stock: Female (% total P...          2.9
# 4      International migrant stock: Both sexes (number)  220983187.0
# ...                                                 ...          ...
# 6587  International migrant stock: Female (% total P...          2.3
# 6588  Total refugees and people in refugee-like situ...       9118.0
# 6589   Asylum seekers, including pending cases (number)      11766.0
# 6590                 Other of concern to UNHCR (number)     271263.0
# 6591      Total population of concern to UNHCR (number)     292147.0
#
#                                               Footnotes  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6587                                Including refugees.
# 6588                                                NaN
# 6589                                                NaN
# 6590  A study is being pursued to provide a revised ...
# 6591                                                NaN
#
#                                                  Source Unnamed: 7 Unnamed: 8
# 0     United Nations Population Division, New York, ...        NaN        NaN
# 1     United Nations Population Division, New York, ...        NaN        NaN
# 2     United Nations Population Division, New York, ...        NaN        NaN
# 3     United Nations Population Division, New York, ...        NaN        NaN
# 4     United Nations Population Division, New York, ...        NaN        NaN
# ...                                                 ...        ...        ...
# 6587  United Nations Population Division, New York, ...        NaN        NaN
# 6588  United Nations High Commissioner for Refugees ...        NaN        NaN
# 6589  United Nations High Commissioner for Refugees ...        NaN        NaN
# 6590  United Nations High Commissioner for Refugees ...        NaN        NaN
# 6591  United Nations High Commissioner for Refugees ...        NaN        NaN
#
# [6592 rows x 9 columns]

# %%
df.shape
# Out:
# (6592, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6592 entries, 0 to 6591
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Region/Country/Area  6592 non-null   int64
#  1   Unnamed: 1           6592 non-null   object
#  2   Year                 6592 non-null   int64
#  3   Series               6592 non-null   object
#  4   Value                6592 non-null   float64
#  5   Footnotes            3856 non-null   object
#  6   Source               6592 non-null   object
#  7   Unnamed: 7           629 non-null    object
#  8   Unnamed: 8           16 non-null     object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 463.6+ KB

# %%
df.columns
# Out:
# Index(['Region/Country/Area', 'Unnamed: 1', 'Year', 'Series', 'Value',
#        'Footnotes', 'Source', 'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')

# %%
df.rename(columns={'Region/Country/Area': 'Code', 
                   'Unnamed: 1': 'RegionCountryArea',
                   }, inplace=True)

df
# Out:
#       Code              RegionCountryArea  Year  \
# 0        1  Total, all countries or areas  2005
# 1        1  Total, all countries or areas  2005
# 2        1  Total, all countries or areas  2005
# 3        1  Total, all countries or areas  2005
# 4        1  Total, all countries or areas  2010
# ...    ...                            ...   ...
# 6587   716                       Zimbabwe  2020
# 6588   716                       Zimbabwe  2020
# 6589   716                       Zimbabwe  2020
# 6590   716                       Zimbabwe  2020
# 6591   716                       Zimbabwe  2020
#
#                                                  Series        Value  \
# 0      International migrant stock: Both sexes (number)  191446828.0
# 1     International migrant stock: Both sexes (% tot...          2.9
# 2     International migrant stock: Male (% total Pop...          3.0
# 3     International migrant stock: Female (% total P...          2.9
# 4      International migrant stock: Both sexes (number)  220983187.0
# ...                                                 ...          ...
# 6587  International migrant stock: Female (% total P...          2.3
# 6588  Total refugees and people in refugee-like situ...       9118.0
# 6589   Asylum seekers, including pending cases (number)      11766.0
# 6590                 Other of concern to UNHCR (number)     271263.0
# 6591      Total population of concern to UNHCR (number)     292147.0
#
#                                               Footnotes  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6587                                Including refugees.
# 6588                                                NaN
# 6589                                                NaN
# 6590  A study is being pursued to provide a revised ...
# 6591                                                NaN
#
#                                                  Source Unnamed: 7 Unnamed: 8
# 0     United Nations Population Division, New York, ...        NaN        NaN
# 1     United Nations Population Division, New York, ...        NaN        NaN
# 2     United Nations Population Division, New York, ...        NaN        NaN
# 3     United Nations Population Division, New York, ...        NaN        NaN
# 4     United Nations Population Division, New York, ...        NaN        NaN
# ...                                                 ...        ...        ...
# 6587  United Nations Population Division, New York, ...        NaN        NaN
# 6588  United Nations High Commissioner for Refugees ...        NaN        NaN
# 6589  United Nations High Commissioner for Refugees ...        NaN        NaN
# 6590  United Nations High Commissioner for Refugees ...        NaN        NaN
# 6591  United Nations High Commissioner for Refugees ...        NaN        NaN
#
# [6592 rows x 9 columns]

# %%
df1 = df[['Code', 'RegionCountryArea', 'Year', 'Series', 'Value']]
df1
# Out:
#       Code              RegionCountryArea  Year  \
# 0        1  Total, all countries or areas  2005
# 1        1  Total, all countries or areas  2005
# 2        1  Total, all countries or areas  2005
# 3        1  Total, all countries or areas  2005
# 4        1  Total, all countries or areas  2010
# ...    ...                            ...   ...
# 6587   716                       Zimbabwe  2020
# 6588   716                       Zimbabwe  2020
# 6589   716                       Zimbabwe  2020
# 6590   716                       Zimbabwe  2020
# 6591   716                       Zimbabwe  2020
#
#                                                  Series        Value
# 0      International migrant stock: Both sexes (number)  191446828.0
# 1     International migrant stock: Both sexes (% tot...          2.9
# 2     International migrant stock: Male (% total Pop...          3.0
# 3     International migrant stock: Female (% total P...          2.9
# 4      International migrant stock: Both sexes (number)  220983187.0
# ...                                                 ...          ...
# 6587  International migrant stock: Female (% total P...          2.3
# 6588  Total refugees and people in refugee-like situ...       9118.0
# 6589   Asylum seekers, including pending cases (number)      11766.0
# 6590                 Other of concern to UNHCR (number)     271263.0
# 6591      Total population of concern to UNHCR (number)     292147.0
#
# [6592 rows x 5 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6592 entries, 0 to 6591
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Code               6592 non-null   int64
#  1   RegionCountryArea  6592 non-null   object
#  2   Year               6592 non-null   int64
#  3   Series             6592 non-null   object
#  4   Value              6592 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 257.6+ KB

# %%
df1.shape
# Out:
# (6592, 5)

# %%
df1.describe(include='object')
# Out:
#            RegionCountryArea                                            Series
# count                   6592                                              6592
# unique                   263                                                 8
# top     China, Hong Kong SAR  International migrant stock: Both sexes (number)
# freq                      36                                              1045

# %%
df1['RegionCountryArea'].value_counts()
# Out:
# China, Hong Kong SAR    36
# Eritrea                 35
# Egypt                   35
# Switzerland             35
# Ghana                   34
#                         ..
# San Marino               8
# Isle of Man              8
# Tokelau                  8
# Cook Islands             8
# Latin America            4
# Name: RegionCountryArea, Length: 263, dtype: int64

# %%
df1['Series'].value_counts()
# Out:
# International migrant stock: Both sexes (number)                 1045
# International migrant stock: Both sexes (% total population)     1045
# International migrant stock: Male (% total Population)            913
# International migrant stock: Female (% total Population)          913
# Total population of concern to UNHCR (number)                     752
# Total refugees and people in refugee-like situations (number)     702
# Asylum seekers, including pending cases (number)                  685
# Other of concern to UNHCR (number)                                537
# Name: Series, dtype: int64

# %%
df1['Year'].value_counts()
# Out:
# 2020    1666
# 2015    1640
# 2010    1609
# 2005    1535
# 2019      61
# 2017      28
# 2018      27
# 2016      26
# Name: Year, dtype: int64

# %%
df1['Value'].describe()
# Out:
# count    6.592000e+03
# mean     7.122918e+05
# std      7.074442e+06
# min      0.000000e+00
# 25%      4.200000e+00
# 50%      6.260000e+01
# 75%      2.429975e+04
# max      2.805981e+08
# Name: Value, dtype: float64

# %% [markdown]
# # Missing Values Exploration

# %%
df1.isna().sum()
# Out:
# Code                 0
# RegionCountryArea    0
# Year                 0
# Series               0
# Value                0
# dtype: int64

# %% [markdown]
# # Grouping and Aggregation

# %%
reg_coun_area = df1.groupby('RegionCountryArea')
reg_coun_area.head()
# Out:
#       Code              RegionCountryArea  Year  \
# 0        1  Total, all countries or areas  2005
# 1        1  Total, all countries or areas  2005
# 2        1  Total, all countries or areas  2005
# 3        1  Total, all countries or areas  2005
# 4        1  Total, all countries or areas  2010
# ...    ...                            ...   ...
# 6561   716                       Zimbabwe  2005
# 6562   716                       Zimbabwe  2005
# 6563   716                       Zimbabwe  2005
# 6564   716                       Zimbabwe  2005
# 6565   716                       Zimbabwe  2005
#
#                                                  Series        Value
# 0      International migrant stock: Both sexes (number)  191446828.0
# 1     International migrant stock: Both sexes (% tot...          2.9
# 2     International migrant stock: Male (% total Pop...          3.0
# 3     International migrant stock: Female (% total P...          2.9
# 4      International migrant stock: Both sexes (number)  220983187.0
# ...                                                 ...          ...
# 6561   International migrant stock: Both sexes (number)     402226.0
# 6562  International migrant stock: Both sexes (% tot...          3.3
# 6563  International migrant stock: Male (% total Pop...          4.0
# 6564  International migrant stock: Female (% total P...          2.7
# 6565  Total refugees and people in refugee-like situ...      13850.0
#
# [1314 rows x 5 columns]

# %%
agg_value_stats = reg_coun_area.agg(
    agg_pct = pd.NamedAgg('Value', np.min),
    agg_mean = pd.NamedAgg('Value', np.mean),
    agg_max = pd.NamedAgg('Value', np.max),
    agg_sum = pd.NamedAgg('Value', np.sum)
)

agg_value_stats
# Out:
#                    agg_pct      agg_mean     agg_max      agg_sum
# RegionCountryArea
# Afghanistan            0.3  3.700264e+05   2802857.0   11840846.2
# Africa                 1.6  7.554332e+06  32536151.0  181303959.9
# Albania                1.0  7.813232e+03     64739.0     242210.2
# Algeria                0.5  6.004057e+04    250378.0    1681136.0
# American Samoa        40.7  1.188458e+04     24233.0      95076.6
# ...                    ...           ...         ...          ...
# Western Europe        11.8  6.588340e+06  33231117.0  105413433.6
# Western Sahara         0.8  1.187375e+03      5424.0      18998.0
# Yemen                  0.7  4.222225e+05   4010022.0   13511118.5
# Zambia                 0.8  4.661269e+04    252895.0    1491606.2
# Zimbabwe               2.3  9.210712e+04    416141.0    2855320.6
#
# [263 rows x 4 columns]

# %% [markdown]
# # Data Exploration By Region

# %% [markdown]
# # Africa

# %%
reg_coun_area.get_group('Africa').head(10)
# Out:
#     Code RegionCountryArea  Year  \
# 24     2            Africa  2005
# 25     2            Africa  2005
# 26     2            Africa  2005
# 27     2            Africa  2005
# 28     2            Africa  2010
# 29     2            Africa  2010
# 30     2            Africa  2010
# 31     2            Africa  2010
# 32     2            Africa  2015
# 33     2            Africa  2015
#
#                                                Series       Value
# 24   International migrant stock: Both sexes (number)  16040087.0
# 25  International migrant stock: Both sexes (% tot...         1.8
# 26  International migrant stock: Male (% total Pop...         1.9
# 27  International migrant stock: Female (% total P...         1.6
# 28   International migrant stock: Both sexes (number)  17806677.0
# 29  International migrant stock: Both sexes (% tot...         1.7
# 30  International migrant stock: Male (% total Pop...         1.8
# 31  International migrant stock: Female (% total P...         1.6
# 32   International migrant stock: Both sexes (number)  22860792.0
# 33  International migrant stock: Both sexes (% tot...         1.9

# %% [markdown]
# Northern Africa

# %%
reg_coun_area.get_group('Northern Africa').head(10)
# Out:
#     Code RegionCountryArea  Year  \
# 48    15   Northern Africa  2005
# 49    15   Northern Africa  2005
# 50    15   Northern Africa  2010
# 51    15   Northern Africa  2010
# 52    15   Northern Africa  2015
# 53    15   Northern Africa  2015
# 54    15   Northern Africa  2020
# 55    15   Northern Africa  2020
#
#                                                Series      Value
# 48   International migrant stock: Both sexes (number)  1749718.0
# 49  International migrant stock: Both sexes (% tot...        0.9
# 50   International migrant stock: Both sexes (number)  1952040.0
# 51  International migrant stock: Both sexes (% tot...        1.0
# 52   International migrant stock: Both sexes (number)  2138918.0
# 53  International migrant stock: Both sexes (% tot...        1.0
# 54   International migrant stock: Both sexes (number)  3167926.0
# 55  International migrant stock: Both sexes (% tot...        1.3

# %% [markdown]
# Sub-Saharan Africa

# %%
reg_coun_area.get_group('Sub-Saharan Africa').head(10)
# Out:
#     Code   RegionCountryArea  Year  \
# 56   202  Sub-Saharan Africa  2005
# 57   202  Sub-Saharan Africa  2005
# 58   202  Sub-Saharan Africa  2005
# 59   202  Sub-Saharan Africa  2005
# 60   202  Sub-Saharan Africa  2010
# 61   202  Sub-Saharan Africa  2010
# 62   202  Sub-Saharan Africa  2010
# 63   202  Sub-Saharan Africa  2010
# 64   202  Sub-Saharan Africa  2015
# 65   202  Sub-Saharan Africa  2015
#
#                                                Series       Value
# 56   International migrant stock: Both sexes (number)  14290369.0
# 57  International migrant stock: Both sexes (% tot...         2.0
# 58  International migrant stock: Male (% total Pop...         2.1
# 59  International migrant stock: Female (% total P...         1.8
# 60   International migrant stock: Both sexes (number)  15854637.0
# 61  International migrant stock: Both sexes (% tot...         1.9
# 62  International migrant stock: Male (% total Pop...         2.0
# 63  International migrant stock: Female (% total P...         1.8
# 64   International migrant stock: Both sexes (number)  20721874.0
# 65  International migrant stock: Both sexes (% tot...         2.2

# %% [markdown]
# Eastern Africa

# %%
reg_coun_area.get_group('Middle Africa').head(10)
# Out:
#     Code RegionCountryArea  Year  \
# 88    17     Middle Africa  2005
# 89    17     Middle Africa  2005
# 90    17     Middle Africa  2005
# 91    17     Middle Africa  2005
# 92    17     Middle Africa  2010
# 93    17     Middle Africa  2010
# 94    17     Middle Africa  2010
# 95    17     Middle Africa  2010
# 96    17     Middle Africa  2015
# 97    17     Middle Africa  2015
#
#                                                Series      Value
# 88   International migrant stock: Both sexes (number)  1961951.0
# 89  International migrant stock: Both sexes (% tot...        1.8
# 90  International migrant stock: Male (% total Pop...        1.8
# 91  International migrant stock: Female (% total P...        1.7
# 92   International migrant stock: Both sexes (number)  2436802.0
# 93  International migrant stock: Both sexes (% tot...        1.9
# 94  International migrant stock: Male (% total Pop...        1.9
# 95  International migrant stock: Female (% total P...        1.8
# 96   International migrant stock: Both sexes (number)  3479911.0
# 97  International migrant stock: Both sexes (% tot...        2.3

# %% [markdown]
# Middle Africa

# %%
reg_coun_area.get_group('Middle Africa').head(10)
# Out:
#     Code RegionCountryArea  Year  \
# 88    17     Middle Africa  2005
# 89    17     Middle Africa  2005
# 90    17     Middle Africa  2005
# 91    17     Middle Africa  2005
# 92    17     Middle Africa  2010
# 93    17     Middle Africa  2010
# 94    17     Middle Africa  2010
# 95    17     Middle Africa  2010
# 96    17     Middle Africa  2015
# 97    17     Middle Africa  2015
#
#                                                Series      Value
# 88   International migrant stock: Both sexes (number)  1961951.0
# 89  International migrant stock: Both sexes (% tot...        1.8
# 90  International migrant stock: Male (% total Pop...        1.8
# 91  International migrant stock: Female (% total P...        1.7
# 92   International migrant stock: Both sexes (number)  2436802.0
# 93  International migrant stock: Both sexes (% tot...        1.9
# 94  International migrant stock: Male (% total Pop...        1.9
# 95  International migrant stock: Female (% total P...        1.8
# 96   International migrant stock: Both sexes (number)  3479911.0
# 97  International migrant stock: Both sexes (% tot...        2.3

# %% [markdown]
# Southern Africa

# %%
reg_coun_area.get_group('Southern Africa').head(10)
# Out:
#      Code RegionCountryArea  Year  \
# 104    18   Southern Africa  2005
# 105    18   Southern Africa  2005
# 106    18   Southern Africa  2005
# 107    18   Southern Africa  2005
# 108    18   Southern Africa  2010
# 109    18   Southern Africa  2010
# 110    18   Southern Africa  2010
# 111    18   Southern Africa  2010
# 112    18   Southern Africa  2015
# 113    18   Southern Africa  2015
#
#                                                 Series      Value
# 104   International migrant stock: Both sexes (number)  1582721.0
# 105  International migrant stock: Both sexes (% tot...        2.9
# 106  International migrant stock: Male (% total Pop...        3.4
# 107  International migrant stock: Female (% total P...        2.4
# 108   International migrant stock: Both sexes (number)  2352541.0
# 109  International migrant stock: Both sexes (% tot...        4.0
# 110  International migrant stock: Male (% total Pop...        4.7
# 111  International migrant stock: Female (% total P...        3.4
# 112   International migrant stock: Both sexes (number)  3477903.0
# 113  International migrant stock: Both sexes (% tot...        5.5

# %% [markdown]
# Western Africa

# %%
reg_coun_area.get_group('Western Africa').head(10)
# Out:
#      Code RegionCountryArea  Year  \
# 120    11    Western Africa  2005
# 121    11    Western Africa  2005
# 122    11    Western Africa  2005
# 123    11    Western Africa  2005
# 124    11    Western Africa  2010
# 125    11    Western Africa  2010
# 126    11    Western Africa  2010
# 127    11    Western Africa  2010
# 128    11    Western Africa  2015
# 129    11    Western Africa  2015
#
#                                                 Series      Value
# 120   International migrant stock: Both sexes (number)  5957048.0
# 121  International migrant stock: Both sexes (% tot...        2.2
# 122  International migrant stock: Male (% total Pop...        2.4
# 123  International migrant stock: Female (% total P...        2.1
# 124   International migrant stock: Both sexes (number)  6321637.0
# 125  International migrant stock: Both sexes (% tot...        2.1
# 126  International migrant stock: Male (% total Pop...        2.2
# 127  International migrant stock: Female (% total P...        1.9
# 128   International migrant stock: Both sexes (number)  7067138.0
# 129  International migrant stock: Both sexes (% tot...        2.0

# %% [markdown]
# # Alternative Indexing

# %%
cols = ['Africa', 'Northern Africa', 'Sub-Saharan Africa', 'Eastern Africa', 
        'Middle Africa', 'Southern Africa', 'Western Africa', 'Northern America']

df2 = df1[df['RegionCountryArea'].isin(cols)]
df2
# Out:
#      Code RegionCountryArea  Year  \
# 24      2            Africa  2005
# 25      2            Africa  2005
# 26      2            Africa  2005
# 27      2            Africa  2005
# 28      2            Africa  2010
# ..    ...               ...   ...
# 154    21  Northern America  2019
# 155    21  Northern America  2020
# 156    21  Northern America  2020
# 157    21  Northern America  2020
# 158    21  Northern America  2020
#
#                                                 Series       Value
# 24    International migrant stock: Both sexes (number)  16040087.0
# 25   International migrant stock: Both sexes (% tot...         1.8
# 26   International migrant stock: Male (% total Pop...         1.9
# 27   International migrant stock: Female (% total P...         1.6
# 28    International migrant stock: Both sexes (number)  17806677.0
# ..                                                 ...         ...
# 154      Total population of concern to UNHCR (number)   1233055.0
# 155   International migrant stock: Both sexes (number)  58708795.0
# 156  International migrant stock: Both sexes (% tot...        15.9
# 157  International migrant stock: Male (% total Pop...        15.5
# 158  International migrant stock: Female (% total P...        16.3
#
# [135 rows x 5 columns]

# %% [markdown]
# # Grouping By Region - Africa

# %%
df2.groupby('RegionCountryArea').head()
# Out:
#      Code   RegionCountryArea  Year  \
# 24      2              Africa  2005
# 25      2              Africa  2005
# 26      2              Africa  2005
# 27      2              Africa  2005
# 28      2              Africa  2010
# 48     15     Northern Africa  2005
# 49     15     Northern Africa  2005
# 50     15     Northern Africa  2010
# 51     15     Northern Africa  2010
# 52     15     Northern Africa  2015
# 56    202  Sub-Saharan Africa  2005
# 57    202  Sub-Saharan Africa  2005
# 58    202  Sub-Saharan Africa  2005
# 59    202  Sub-Saharan Africa  2005
# 60    202  Sub-Saharan Africa  2010
# 72     14      Eastern Africa  2005
# 73     14      Eastern Africa  2005
# 74     14      Eastern Africa  2005
# 75     14      Eastern Africa  2005
# 76     14      Eastern Africa  2010
# 88     17       Middle Africa  2005
# 89     17       Middle Africa  2005
# 90     17       Middle Africa  2005
# 91     17       Middle Africa  2005
# 92     17       Middle Africa  2010
# 104    18     Southern Africa  2005
# 105    18     Southern Africa  2005
# 106    18     Southern Africa  2005
# 107    18     Southern Africa  2005
# 108    18     Southern Africa  2010
# 120    11      Western Africa  2005
# 121    11      Western Africa  2005
# 122    11      Western Africa  2005
# 123    11      Western Africa  2005
# 124    11      Western Africa  2010
# 136    21    Northern America  2005
# 137    21    Northern America  2005
# 138    21    Northern America  2005
# 139    21    Northern America  2005
# 140    21    Northern America  2010
#
#                                                 Series       Value
# 24    International migrant stock: Both sexes (number)  16040087.0
# 25   International migrant stock: Both sexes (% tot...         1.8
# 26   International migrant stock: Male (% total Pop...         1.9
# 27   International migrant stock: Female (% total P...         1.6
# 28    International migrant stock: Both sexes (number)  17806677.0
# 48    International migrant stock: Both sexes (number)   1749718.0
# 49   International migrant stock: Both sexes (% tot...         0.9
# 50    International migrant stock: Both sexes (number)   1952040.0
# 51   International migrant stock: Both sexes (% tot...         1.0
# 52    International migrant stock: Both sexes (number)   2138918.0
# 56    International migrant stock: Both sexes (number)  14290369.0
# 57   International migrant stock: Both sexes (% tot...         2.0
# 58   International migrant stock: Male (% total Pop...         2.1
# 59   International migrant stock: Female (% total P...         1.8
# 60    International migrant stock: Both sexes (number)  15854637.0
# 72    International migrant stock: Both sexes (number)   4788649.0
# 73   International migrant stock: Both sexes (% tot...         1.6
# 74   International migrant stock: Male (% total Pop...         1.7
# 75   International migrant stock: Female (% total P...         1.5
# 76    International migrant stock: Both sexes (number)   4743657.0
# 88    International migrant stock: Both sexes (number)   1961951.0
# 89   International migrant stock: Both sexes (% tot...         1.8
# 90   International migrant stock: Male (% total Pop...         1.8
# 91   International migrant stock: Female (% total P...         1.7
# 92    International migrant stock: Both sexes (number)   2436802.0
# 104   International migrant stock: Both sexes (number)   1582721.0
# 105  International migrant stock: Both sexes (% tot...         2.9
# 106  International migrant stock: Male (% total Pop...         3.4
# 107  International migrant stock: Female (% total P...         2.4
# 108   International migrant stock: Both sexes (number)   2352541.0
# 120   International migrant stock: Both sexes (number)   5957048.0
# 121  International migrant stock: Both sexes (% tot...         2.2
# 122  International migrant stock: Male (% total Pop...         2.4
# 123  International migrant stock: Female (% total P...         2.1
# 124   International migrant stock: Both sexes (number)   6321637.0
# 136   International migrant stock: Both sexes (number)  45363089.0
# 137  International migrant stock: Both sexes (% tot...        13.9
# 138  International migrant stock: Male (% total Pop...        14.0
# 139  International migrant stock: Female (% total P...        13.8
# 140   International migrant stock: Both sexes (number)  50970524.0
