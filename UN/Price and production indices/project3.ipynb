# %% [markdown]
# # Index of industrial production

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings

# %% [markdown]
# # Options and Settings

# %%
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.autolayout'] = True
plt.rcParams['figure.figsize'] = [12, 9]
plt.rcParams['font.size'] = 12
path = os.getcwd()                                         # get current working directory
warnings.simplefilter('ignore')

# %% [markdown]
# # Import Data

# %%
filepath = os.path.join('datasets', 'Index of industrial production.csv')
df = pd.read_csv(filepath)

# %% [markdown]
# # Head and Tail

# %%
df
# Out:
#       Region/Country/Area Unnamed: 1  \
# 0                       8    Albania
# 1                       8    Albania
# 2                       8    Albania
# 3                       8    Albania
# 4                       8    Albania
# ...                   ...        ...
# 6876                  716   Zimbabwe
# 6877                  716   Zimbabwe
# 6878                  716   Zimbabwe
# 6879                  716   Zimbabwe
# 6880                  716   Zimbabwe
#
#                                                  Series  Year  Value  \
# 0     Index of industrial production: Total industry...  2007  118.5
# 1     Index of industrial production: Total industry...  2008  142.7
# 2     Index of industrial production: Total industry...  2009  148.3
# 3     Index of industrial production: Total industry...  2010  200.2
# 4     Index of industrial production: Total industry...  2011  237.6
# ...                                                 ...   ...    ...
# 6876  Index of industrial production: Electricity, g...  2007   75.9
# 6877  Index of industrial production: Electricity, g...  2008   75.8
# 6878  Index of industrial production: Electricity, g...  2009   72.5
# 6879  Index of industrial production: Electricity, g...  2010   79.5
# 6880  Index of industrial production: Electricity, g...  2011   86.9
#
#                                   Footnotes  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 6876  The indices are based on ISIC Rev. 3.
# 6877  The indices are based on ISIC Rev. 3.
# 6878  The indices are based on ISIC Rev. 3.
# 6879  The indices are based on ISIC Rev. 3.
# 6880  The indices are based on ISIC Rev. 3.
#
#                                                  Source  \
# 0     United Nations Statistics Division, New York, ...
# 1     United Nations Statistics Division, New York, ...
# 2     United Nations Statistics Division, New York, ...
# 3     United Nations Statistics Division, New York, ...
# 4     United Nations Statistics Division, New York, ...
# ...                                                 ...
# 6876                   Data refers to electricity only.
# 6877                   Data refers to electricity only.
# 6878                   Data refers to electricity only.
# 6879                   Data refers to electricity only.
# 6880                   Data refers to electricity only.
#
#                                              Unnamed: 7 Unnamed: 8
# 0                                                   NaN        NaN
# 1                                                   NaN        NaN
# 2                                                   NaN        NaN
# 3                                                   NaN        NaN
# 4                                                   NaN        NaN
# ...                                                 ...        ...
# 6876  United Nations Statistics Division, New York, ...        NaN
# 6877  United Nations Statistics Division, New York, ...        NaN
# 6878  United Nations Statistics Division, New York, ...        NaN
# 6879  United Nations Statistics Division, New York, ...        NaN
# 6880  United Nations Statistics Division, New York, ...        NaN
#
# [6881 rows x 9 columns]

# %%
df.shape
# Out:
# (6881, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6881 entries, 0 to 6880
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Region/Country/Area  6881 non-null   int64
#  1   Unnamed: 1           6881 non-null   object
#  2   Series               6881 non-null   object
#  3   Year                 6881 non-null   int64
#  4   Value                6881 non-null   float64
#  5   Footnotes            4163 non-null   object
#  6   Source               6881 non-null   object
#  7   Unnamed: 7           931 non-null    object
#  8   Unnamed: 8           88 non-null     object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 483.9+ KB

# %%
df.rename(columns={'Region/Country/Area': 'Code', 
                   'Unnamed: 1': 'Country/Area',
                   }, inplace=True)

df.head()
# Out:
#    Code Country/Area                                             Series  Year  \
# 0     8      Albania  Index of industrial production: Total industry...  2007
# 1     8      Albania  Index of industrial production: Total industry...  2008
# 2     8      Albania  Index of industrial production: Total industry...  2009
# 3     8      Albania  Index of industrial production: Total industry...  2010
# 4     8      Albania  Index of industrial production: Total industry...  2011
#
#    Value Footnotes                                             Source  \
# 0  118.5       NaN  United Nations Statistics Division, New York, ...
# 1  142.7       NaN  United Nations Statistics Division, New York, ...
# 2  148.3       NaN  United Nations Statistics Division, New York, ...
# 3  200.2       NaN  United Nations Statistics Division, New York, ...
# 4  237.6       NaN  United Nations Statistics Division, New York, ...
#
#   Unnamed: 7 Unnamed: 8
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df1 = df[['Code', 'Country/Area', 'Year', 'Series', 'Value']]
df1
# Out:
#       Code Country/Area  Year  \
# 0        8      Albania  2007
# 1        8      Albania  2008
# 2        8      Albania  2009
# 3        8      Albania  2010
# 4        8      Albania  2011
# ...    ...          ...   ...
# 6876   716     Zimbabwe  2007
# 6877   716     Zimbabwe  2008
# 6878   716     Zimbabwe  2009
# 6879   716     Zimbabwe  2010
# 6880   716     Zimbabwe  2011
#
#                                                  Series  Value
# 0     Index of industrial production: Total industry...  118.5
# 1     Index of industrial production: Total industry...  142.7
# 2     Index of industrial production: Total industry...  148.3
# 3     Index of industrial production: Total industry...  200.2
# 4     Index of industrial production: Total industry...  237.6
# ...                                                 ...    ...
# 6876  Index of industrial production: Electricity, g...   75.9
# 6877  Index of industrial production: Electricity, g...   75.8
# 6878  Index of industrial production: Electricity, g...   72.5
# 6879  Index of industrial production: Electricity, g...   79.5
# 6880  Index of industrial production: Electricity, g...   86.9
#
# [6881 rows x 5 columns]

# %%
df1.shape
# Out:
# (6881, 5)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6881 entries, 0 to 6880
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Code          6881 non-null   int64
#  1   Country/Area  6881 non-null   object
#  2   Year          6881 non-null   int64
#  3   Series        6881 non-null   object
#  4   Value         6881 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 268.9+ KB

# %%
df1.describe(include='object')
# Out:
#        Country/Area                                             Series
# count          6881                                               6881
# unique          127                                                 15
# top         Belgium  Index of industrial production: Manufacturing ...
# freq             80                                                862

# %%
df1['Country/Area'].value_counts()
# Out:
# Belgium        80
# Lithuania      80
# Tunisia        80
# Netherlands    80
# Australia      80
#                ..
# Gabon          13
# Suriname       12
# Chad            7
# Benin           7
# Uzbekistan      5
# Name: Country/Area, Length: 127, dtype: int64

# %%
df1['Series'].value_counts()
# Out:
# Index of industrial production: Manufacturing (Index base: 2005=100)                                                         862
# Index of industrial production: Food, beverages and tobacco (Index base: 2005=100)                                           755
# Index of industrial production: Mining (Index base: 2005=100)                                                                752
# Index of industrial production: Textiles, wearing apparel, leather, footwear (Index base: 2005=100)                          731
# Index of industrial production: Chemicals, petroleum, rubber and plastic products (Index base: 2005=100)                     731
# Index of industrial production: Total industry - Mining; manufacturing; electricity, gas and water (Index base: 2005=100)    700
# Index of industrial production: Metal products and machinery (Index Base: 2005=100)                                          677
# Index of industrial production: Basic metals (Index base: 2005=100)                                                          599
# Index of industrial production: Electricity, gas and water (Index base: 2005=100)                                            447
# Index of industrial production: Electricity, gas, steam (Index base: 2005=100)                                               396
# Index of industrial production: Water and waste management (Index base: 2005=100)                                            156
# Index of industrial production: Machinery (Index base: 2005=100)                                                              39
# Index of industrial production: Metal products (Index base: 2005=100)                                                         20
# Index of industrial production: Miscellaneous manufacturing industries (Index base: 2005=100)                                  8
# Index of industrial production: Mining and manufacturing (Index base: 2005=100)                                                8
# Name: Series, dtype: int64

# %%
df1['Code'].value_counts()
# Out:
# 56     80
# 440    80
# 788    80
# 528    80
# 36     80
#        ..
# 266    13
# 740    12
# 148     7
# 204     7
# 860     5
# Name: Code, Length: 127, dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
df1.rename(
    columns={'Series': 'IndexIndustrialProduction'}, inplace=True
)

df1.head()
# Out:
#    Code Country/Area  Year                          IndexIndustrialProduction  \
# 0     8      Albania  2007  Index of industrial production: Total industry...
# 1     8      Albania  2008  Index of industrial production: Total industry...
# 2     8      Albania  2009  Index of industrial production: Total industry...
# 3     8      Albania  2010  Index of industrial production: Total industry...
# 4     8      Albania  2011  Index of industrial production: Total industry...
#
#    Value
# 0  118.5
# 1  142.7
# 2  148.3
# 3  200.2
# 4  237.6

# %%
df1['IndexIndustrialProduction'] = df1['IndexIndustrialProduction'].str.lstrip('Index of industrial production: ')   # left strip strings
df1['IndexIndustrialProduction'] = df1['IndexIndustrialProduction'].str.rstrip('(Index base: 2005=100)')   # right strip strings
df1
# Out:
#       Code Country/Area  Year  \
# 0        8      Albania  2007
# 1        8      Albania  2008
# 2        8      Albania  2009
# 3        8      Albania  2010
# 4        8      Albania  2011
# ...    ...          ...   ...
# 6876   716     Zimbabwe  2007
# 6877   716     Zimbabwe  2008
# 6878   716     Zimbabwe  2009
# 6879   716     Zimbabwe  2010
# 6880   716     Zimbabwe  2011
#
#                               IndexIndustrialProduction  Value
# 0     Total industry - Mining; manufacturing; electr...  118.5
# 1     Total industry - Mining; manufacturing; electr...  142.7
# 2     Total industry - Mining; manufacturing; electr...  148.3
# 3     Total industry - Mining; manufacturing; electr...  200.2
# 4     Total industry - Mining; manufacturing; electr...  237.6
# ...                                                 ...    ...
# 6876                         Electricity, gas and water   75.9
# 6877                         Electricity, gas and water   75.8
# 6878                         Electricity, gas and water   72.5
# 6879                         Electricity, gas and water   79.5
# 6880                         Electricity, gas and water   86.9
#
# [6881 rows x 5 columns]

# %%
df1['Year'].value_counts()
# Out:
# 2007    954
# 2008    954
# 2009    930
# 2010    921
# 2011    881
# 2012    824
# 2013    762
# 2014    655
# Name: Year, dtype: int64

# %%
df1['Value'].describe()
# Out:
# count    6881.000000
# mean      113.930286
# std        51.892630
# min         5.600000
# 25%        94.400000
# 50%       107.800000
# 75%       124.000000
# max      1748.600000
# Name: Value, dtype: float64

# %% [markdown]
# # Missing Values Exploration

# %%
df1.isna().sum()
# Out:
# Code                         0
# Country/Area                 0
# Year                         0
# IndexIndustrialProduction    0
# Value                        0
# dtype: int64

# %% [markdown]
# # Grouping and Aggregation

# %% [markdown]
# Group By Country or Area

# %%
df1_gpd = df1.groupby('Country/Area')
df1_gpd.head()
# Out:
#       Code Country/Area  Year  \
# 0        8      Albania  2007
# 1        8      Albania  2008
# 2        8      Albania  2009
# 3        8      Albania  2010
# 4        8      Albania  2011
# ...    ...          ...   ...
# 6861   716     Zimbabwe  2007
# 6862   716     Zimbabwe  2008
# 6863   716     Zimbabwe  2009
# 6864   716     Zimbabwe  2007
# 6865   716     Zimbabwe  2008
#
#                               IndexIndustrialProduction  Value
# 0     Total industry - Mining; manufacturing; electr...  118.5
# 1     Total industry - Mining; manufacturing; electr...  142.7
# 2     Total industry - Mining; manufacturing; electr...  148.3
# 3     Total industry - Mining; manufacturing; electr...  200.2
# 4     Total industry - Mining; manufacturing; electr...  237.6
# ...                                                 ...    ...
# 6861                                      Manufacturing   79.9
# 6862                                      Manufacturing   59.2
# 6863                                      Manufacturing   59.2
# 6864                        Food, beverages and tobacco   50.1
# 6865                        Food, beverages and tobacco   42.4
#
# [635 rows x 5 columns]

# %% [markdown]
# # Data Visualization

# %%
# helper function to plot line charts
def plot_line(x, y, hue, df, title=None, xlabel=None, ylabel=None):
    # initiate matplot figure
    fig, ax = plt.subplots(figsize=(14, 12))
    fig.autofmt_xdate()

    # plot line chart
    sns.barplot(
        x=x, y=y,
        hue=hue,
        data=df)

    # label plot axis
    ax.set(title=title, xlabel=xlabel, ylabel=ylabel)

    return plot_line

# %%
plot_line(
    x='Year', y='Value',
    hue='IndexIndustrialProduction', 
    df=df1_gpd.get_group('Albania'), 
    xlabel='Year', ylabel='Index of industrial production'
)
# Out:
# <function __main__.plot_line(x, y, hue, df, title=None, xlabel=None, ylabel=None)>
