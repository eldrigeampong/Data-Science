# %% [markdown]
# # Trade of goods , US$, HS 1992, 02 Meat and edible meat offal

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings

# %% [markdown]
# # Options and Settings

# %%
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.autolayout'] = True
plt.rcParams['figure.figsize'] = [12, 9]
plt.rcParams['font.size'] = 12
path = os.getcwd()                                         # get current working directory
warnings.simplefilter('ignore')

# %% [markdown]
# # Import Data

# %%
filepath = os.path.join('datasets', 'Trade of goods , US$, HS 1992, 02 Meat and edible meat offal.csv')
df = pd.read_csv(filepath)

# %% [markdown]
# # Head and Tail

# %%
df
# Out:
#       Country or Area  Year  \
# 0         Afghanistan  2018
# 1         Afghanistan  2011
# 2         Afghanistan  2008
# 3             Albania  2018
# 4             Albania  2018
# ...               ...   ...
# 99995           Italy  2013
# 99996           Italy  2013
# 99997           Italy  2013
# 99998           Italy  2013
# 99999           Italy  2013
#
#                                                Commodity       Flow  \
# 0                                  Bovine livers, frozen     Import
# 1                    Goat meat, fresh, chilled or frozen     Import
# 2            Bovine carcasses and half carcasses, frozen     Import
# 3                           Bovine cuts boneless, frozen     Import
# 4      Hams, shoulders and cuts, of swine, bone in, f...     Import
# ...                                                  ...        ...
# 99995  Bellies (streaky) of swine, salted, dried or s...  Re-Export
# 99996  Swine meat, salted/dried/smoked not ham/should...     Import
# ...

# %%
df.shape
# Out:
# (100000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Country or Area  100000 non-null  object
#  1   Year             100000 non-null  int64
#  2   Commodity        100000 non-null  object
#  3   Flow             100000 non-null  object
#  4   Trade (USD)      100000 non-null  float64
#  5   Weight (kg)      99693 non-null   float64
#  6   Quantity Name    100000 non-null  object
#  7   Quantity         99835 non-null   float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 6.1+ MB

# %%
df.rename(columns={'Country or Area': 'Country_or_Area'}, inplace=True)
df
# Out:
#       Country_or_Area  Year  \
# 0         Afghanistan  2018
# 1         Afghanistan  2011
# 2         Afghanistan  2008
# 3             Albania  2018
# 4             Albania  2018
# ...               ...   ...
# 99995           Italy  2013
# 99996           Italy  2013
# 99997           Italy  2013
# 99998           Italy  2013
# 99999           Italy  2013
#
#                                                Commodity       Flow  \
# 0                                  Bovine livers, frozen     Import
# 1                    Goat meat, fresh, chilled or frozen     Import
# 2            Bovine carcasses and half carcasses, frozen     Import
# 3                           Bovine cuts boneless, frozen     Import
# 4      Hams, shoulders and cuts, of swine, bone in, f...     Import
# ...                                                  ...        ...
# 99995  Bellies (streaky) of swine, salted, dried or s...  Re-Export
# 99996  Swine meat, salted/dried/smoked not ham/should...     Import
# ...

# %%
df.describe(include='object')
# Out:
#        Country_or_Area                     Commodity    Flow  \
# count           100000                        100000  100000
# unique              96                            50       4
# top             Canada  Bovine cuts boneless, frozen  Import
# freq              3199                          3087   60429
#
#               Quantity Name
# count                100000
# unique                    2
# top     Weight in kilograms
# freq                  99391

# %%
df['Country_or_Area'].value_counts()
# Out:
# Canada                  3199
# China, Hong Kong SAR    3105
# France                  3084
# Denmark                 2888
# Greece                  2853
#                         ...
# Guinea-Bissau             30
# Djibouti                  21
# Iraq                      11
# Afghanistan                3
# Haiti                      1
# Name: Country_or_Area, Length: 96, dtype: int64

# %%
df['Year'].value_counts().head()
# Out:
# 2011    4199
# 2009    4176
# 2007    4174
# 2012    4171
# 2010    4161
# Name: Year, dtype: int64

# %%
df['Commodity'].value_counts()
# Out:
# Bovine cuts boneless, frozen                             3087
# Fowl cuts & offal, domestic, except livers, frozen       2962
# Fowls, domestic, whole, frozen                           2763
# Swine cuts, frozen nes                                   2733
# Swine meat, salted/dried/smoked not ham/shoulder/bell    2668
# Bovine edible offal, frozen except livers and tongues    2630
# Bovine cuts boneless, fresh or chilled                   2624
# Bovine cuts bone in, frozen                              2615
# Meat and edible meat offal cured, flours, meals nes      2577
# Poultry cuts & offal, except livers, fresh or chilled    2449
# Meat and edible offal nes fresh, chilled or frozen       2426
# Poultry, domestic, whole, fresh or chilled               2405
# Swine cuts, fresh or chilled, nes                        2380
# Sheep cuts, bone in, frozen                              2368
# Hams and shoulders, swine, salted, dried or smoked       2339
# ...

# %%
df['Flow'].value_counts()
# Out:
# Import       60429
# Export       35429
# Re-Export     2773
# Re-Import     1369
# Name: Flow, dtype: int64

# %%
from matplotlib.ticker import FuncFormatter

# helper function format y-axis
def thousand(x, pos):
    return '%1.1fK' % (x * 1e-3)

format_tsd = FuncFormatter(thousand)

# create figure and axis
fig, ax = plt.subplots()

# plot bar graph
sns.barplot(
    data=df,
    x=df['Flow'].value_counts().keys(), y=df['Flow'].value_counts().values)

# label plot axis
ax.set(xlabel='Flow', ylabel='Count')

# set y-axis major formatter
ax.yaxis.set_major_formatter(format_tsd)

# %%
df['Quantity Name'].value_counts()
# Out:
# Weight in kilograms    99391
# No Quantity              609
# Name: Quantity Name, dtype: int64

# %%
# create figure and axis
fig, ax = plt.subplots()

# plot bar graph
sns.barplot(
    data=df,
    x=df['Quantity Name'].value_counts().keys(), y=df['Quantity Name'].value_counts().values)

# label plot axis
ax.set(xlabel='Quantity Name', ylabel='Count')

# set y-axis major formatter
ax.yaxis.set_major_formatter(format_tsd)

# %%
df[['Trade (USD)', 'Weight (kg)', 'Quantity']].describe()
# Out:
#         Trade (USD)   Weight (kg)      Quantity
# count  1.000000e+05  9.969300e+04  9.983500e+04
# mean   2.180448e+07  9.577409e+06  9.578149e+06
# std    1.359232e+08  1.686987e+08  1.685806e+08
# min    1.805550e-03  0.000000e+00  0.000000e+00
# 25%    1.426775e+04  4.222000e+03  4.230000e+03
# 50%    1.861790e+05  6.911600e+04  6.949200e+04
# 75%    2.679070e+06  1.102814e+06  1.106734e+06
# max    5.039515e+09  4.478712e+10  4.478712e+10

# %%
data = df[['Trade (USD)', 'Weight (kg)', 'Quantity']]

plt.figure(figsize=(16, 10))
for i in range(3):
    plt.subplot(1, 3, i+1)
    sns.kdeplot(data=data, x=data.columns[i], kernel='kde')

# %% [markdown]
# # Missing Values Exploration

# %%
df.isna().sum()
# Out:
# Country_or_Area      0
# Year                 0
# Commodity            0
# Flow                 0
# Trade (USD)          0
# Weight (kg)        307
# Quantity Name        0
# Quantity           165
# dtype: int64

# %%
df[df['Weight (kg)'].isna()]                                                 # filter missing rows in weight column
# Out:
#       Country_or_Area  Year  \
# 2666           Angola  2018
# 2806           Angola  2016
# 3428         Anguilla  2004
# 3433         Anguilla  2004
# 3437         Anguilla  2004
# ...               ...   ...
# 99236          Israel  2002
# 99247          Israel  2001
# 99262          Israel  2000
# 99471           Italy  2018
# 99711           Italy  2015
#
#                                                Commodity    Flow  \
# 2666   Hams, shoulders and cuts, of swine, bone in, f...  Import
# 2806   Hams, shoulders and cuts, of swine, bone in, f...  Import
# 3428          Poultry, domestic, whole, fresh or chilled  Import
# 3433   Poultry cuts & offal, except livers, fresh or ...  Import
# 3437                    Poultry livers, domestic, frozen  Import
# ...                                                  ...     ...
# 99236         Poultry, domestic, whole, fresh or chilled  Export
# 99247         Poultry, domestic, whole, fresh or chilled  Export
# ...

# %%
df[df['Quantity'].isna()]                                                 # filter missing rows in quantity column
# Out:
#       Country_or_Area  Year  \
# 3428         Anguilla  2004
# 3433         Anguilla  2004
# 3437         Anguilla  2004
# 3440         Anguilla  2004
# 3465         Anguilla  2003
# ...               ...   ...
# 93736           India  2010
# 93743           India  2010
# 99236          Israel  2002
# 99247          Israel  2001
# 99262          Israel  2000
#
#                                                Commodity    Flow  Trade (USD)  \
# 3428          Poultry, domestic, whole, fresh or chilled  Import      14769.0
# 3433   Poultry cuts & offal, except livers, fresh or ...  Import      90377.0
# 3437                    Poultry livers, domestic, frozen  Import       1288.0
# 3440   Meat and edible meat offal cured, flours, meal...  Import       1015.0
# 3465          Poultry, domestic, whole, fresh or chilled  Import      10010.0
# ...                                                  ...     ...          ...
# ...

# %%
df1 = df.dropna()                                                                   # drop missing values
df1
# Out:
#       Country_or_Area  Year  \
# 0         Afghanistan  2018
# 1         Afghanistan  2011
# 2         Afghanistan  2008
# 3             Albania  2018
# 4             Albania  2018
# ...               ...   ...
# 99995           Italy  2013
# 99996           Italy  2013
# 99997           Italy  2013
# 99998           Italy  2013
# 99999           Italy  2013
#
#                                                Commodity       Flow  \
# 0                                  Bovine livers, frozen     Import
# 1                    Goat meat, fresh, chilled or frozen     Import
# 2            Bovine carcasses and half carcasses, frozen     Import
# 3                           Bovine cuts boneless, frozen     Import
# 4      Hams, shoulders and cuts, of swine, bone in, f...     Import
# ...                                                  ...        ...
# 99995  Bellies (streaky) of swine, salted, dried or s...  Re-Export
# 99996  Swine meat, salted/dried/smoked not ham/should...     Import
# ...

# %%
df1.isna().sum()
# Out:
# Country_or_Area    0
# Year               0
# Commodity          0
# Flow               0
# Trade (USD)        0
# Weight (kg)        0
# Quantity Name      0
# Quantity           0
# dtype: int64

# %% [markdown]
# # Grouping and Aggregation

# %%
country_area_grouped = df1.groupby('Country_or_Area')
country_area_grouped.head()
# Out:
#       Country_or_Area  Year  \
# 0         Afghanistan  2018
# 1         Afghanistan  2011
# 2         Afghanistan  2008
# 3             Albania  2018
# 4             Albania  2018
# ...               ...   ...
# 99378           Italy  2018
# 99379           Italy  2018
# 99380           Italy  2018
# 99381           Italy  2018
# 99382           Italy  2018
#
#                                                Commodity       Flow  \
# 0                                  Bovine livers, frozen     Import
# 1                    Goat meat, fresh, chilled or frozen     Import
# 2            Bovine carcasses and half carcasses, frozen     Import
# 3                           Bovine cuts boneless, frozen     Import
# 4      Hams, shoulders and cuts, of swine, bone in, f...     Import
# ...                                                  ...        ...
# 99378  Bovine carcasses and half carcasses, fresh or ...     Import
# 99379  Bovine carcasses and half carcasses, fresh or ...     Export
# ...

# %% [markdown]
# # Aggregation by Trade (USD)

# %%
agg_trade_stats = country_area_grouped[['Country_or_Area', 'Year', 'Flow', 'Trade (USD)']].agg(
    min_trade = pd.NamedAgg('Trade (USD)', np.min),
    mean_trade = pd.NamedAgg('Trade (USD)', np.mean),
    max_trade = pd.NamedAgg('Trade (USD)', np.max),
    total_trade = pd.NamedAgg('Trade (USD)', np.sum),
)

agg_trade_stats
# Out:
#                   min_trade    mean_trade     max_trade   total_trade
# Country_or_Area
# Afghanistan      3441.00000  1.713774e+06  5.131032e+06  5.141322e+06
# Albania             1.00000  1.142173e+06  3.068334e+07  1.001686e+09
# Algeria             9.00000  5.091861e+06  1.889593e+08  3.386087e+09
# Andorra             6.00000  5.939218e+05  8.436815e+06  6.562835e+08
# Angola              1.15000  1.230854e+07  3.959814e+08  7.705147e+09
# ...                     ...           ...           ...           ...
# Iran              217.00000  2.154672e+07  7.682125e+08  4.977292e+09
# Iraq             1285.00000  1.517779e+07  8.649236e+07  1.669557e+08
# Ireland             9.29712  2.801557e+07  1.801444e+09  7.242025e+10
# Israel           1000.00000  1.723935e+07  4.763400e+08  7.050896e+09
# Italy              35.00000  7.462144e+07  1.459932e+09  4.626529e+10
#
# [96 rows x 4 columns]

# %%
agg_trade_stats['total_trade'].sort_values(ascending=False).head(10)                 # top ten country or area with the highest trade in dollars
# Out:
# Country_or_Area
# Germany                 2.991127e+11
# EU-28                   2.202470e+11
# Brazil                  2.017705e+11
# France                  1.966410e+11
# Australia               1.575054e+11
# China, Hong Kong SAR    1.401133e+11
# Denmark                 1.381661e+11
# Canada                  1.337139e+11
# Belgium                 9.503489e+10
# China                   9.257182e+10
# Name: total_trade, dtype: float64

# %%
# helper function for formatting plot y-axis
from matplotlib.ticker import FuncFormatter

def trillion(x, pos):
    'The two args are the value and tick position'
    return '%1.1fT' % (x * 1e-12)

format_trill = FuncFormatter(trillion)


def billion(x, pos):
    'The two args are the value and tick position'
    return '%1.1fB' % (x * 1e-9)

format_bill = FuncFormatter(billion)


def million(x, pos):
    'The two args are the value and tick position'
    return '%1.1fM' % (x * 1e-6)

format_mill = FuncFormatter(million)


# helper function to plot horizontal bar chart 
def plot_hbar(y, width, align='center', xlabel=None, ylabel=None, title=None, color=None, formatter=None):

    # Initialize the matplotlib figure
    fig, ax = plt.subplots()

    # plot bar chart
    ax.barh(
        y=y, width=width,
        align=align, color=color
    )

    # Add informative axis label
    ax.set(xlabel=xlabel, ylabel=ylabel, title=title)

    # labels read top-to-bottom
    ax.invert_yaxis()  

    # set axis formatter
    ax.xaxis.set_major_formatter(formatter=formatter)

    # despine x-axis and y-axis
    sns.despine(left=True, bottom=True)

    return plot_hbar

# %%
top_10_trade = agg_trade_stats['total_trade'].sort_values(ascending=False).head(10)

plot_hbar(y=top_10_trade.keys(), width=top_10_trade.values, 
          xlabel='Trade (USD)', ylabel='Country or Area', title='Trade of Goods (Meat and edible meat offal)',
          formatter=format_bill
          )
# Out:
# <function __main__.plot_hbar(y, width, align='center', xlabel=None, ylabel=None, title=None, color=None, formatter=None)>

# %%
agg_trade_stats['total_trade'].sort_values(ascending=True).head(10)           # top ten country or area with the lowest trade in dollars
# Out:
# Country_or_Area
# Haiti            8.000000e+03
# Eritrea          3.039630e+05
# Chad             3.634410e+05
# Guinea-Bissau    6.366490e+05
# Djibouti         2.418273e+06
# Burkina Faso     3.780525e+06
# Afghanistan      5.141322e+06
# Cook Isds        1.140680e+07
# Cambodia         1.754184e+07
# Anguilla         2.057230e+07
# Name: total_trade, dtype: float64

# %%
low_10_trade = agg_trade_stats['total_trade'].sort_values(ascending=True).head(10)

plot_hbar(y=low_10_trade.keys(), width=low_10_trade.values, 
          xlabel='Trade (USD)', ylabel='Country or Area', title='Trade of Goods (Meat and edible meat offal)',
          formatter=format_mill
          )
# Out:
# <function __main__.plot_hbar(y, width, align='center', xlabel=None, ylabel=None, title=None, color=None, formatter=None)>

# %% [markdown]
# # Trade of Goods By Country or Area Exploration

# %%
# lineplot helper function to plot individual countries or areas
def plot_line(data, x, y, ci=None, hue=None, size=None, style=None, title=None, xlabel=None, ylabel=None, formatter=None):
    # create figure and axis
    fig, ax = plt.subplots()

    # plot line chart
    sns.lineplot(
        data=data,
        x=x, y=y, ci=ci,
        hue=hue, size=size, style=style)

    # label plot axis
    ax.set(title=title, xlabel=xlabel, ylabel=ylabel)

    # set y-axis formatter
    ax.yaxis.set_major_formatter(formatter=formatter)

    return plot_line

# %%
plot_line(
    data=country_area_grouped.get_group('Germany'),
    x='Year', y='Trade (USD)', ci=None,
    title='Germany', xlabel='Year', ylabel='Trade of Goods ($)',
    hue='Flow', size='Flow', style='Flow',
    formatter=format_mill
)
# Out:
# <function __main__.plot_line(data, x, y, ci=None, hue=None, size=None, style=None, title=None, xlabel=None, ylabel=None, formatter=None)>

# %%
plot_line(
    data=country_area_grouped.get_group('Brazil'),
    x='Year', y='Trade (USD)', ci=None,
    title='Brazil', xlabel='Year', ylabel='Trade of Goods ($)',
    hue='Flow', size='Flow', style='Flow',
    formatter=format_mill
)
# Out:
# <function __main__.plot_line(data, x, y, ci=None, hue=None, size=None, style=None, title=None, xlabel=None, ylabel=None, formatter=None)>

# %%
plot_line(
    data=country_area_grouped.get_group('France'),
    x='Year', y='Trade (USD)', ci=None,
    title='France', xlabel='Year', ylabel='Trade of Goods ($)',
    hue='Flow', size='Flow', style='Flow',
    formatter=format_mill
)
# Out:
# <function __main__.plot_line(data, x, y, ci=None, hue=None, size=None, style=None, title=None, xlabel=None, ylabel=None, formatter=None)>

# %%
plot_line(
    data=country_area_grouped.get_group('Australia'),
    x='Year', y='Trade (USD)', ci=None,
    title='Australia', xlabel='Year', ylabel='Trade of Goods ($)',
    hue='Flow', size='Flow', style='Flow',
    formatter=format_mill
)
# Out:
# <function __main__.plot_line(data, x, y, ci=None, hue=None, size=None, style=None, title=None, xlabel=None, ylabel=None, formatter=None)>
