# %% [markdown]
# # GDP and GDP per capita

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings

# %% [markdown]
# # Options and Settings

# %%
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.autolayout'] = True
plt.rcParams['figure.figsize'] = [12, 9]
plt.rcParams['font.size'] = 12
path = os.getcwd()                                         # get current working directory
warnings.simplefilter('ignore')

# %% [markdown]
# # Import Data

# %%
filepath = os.path.join('datasets', 'GDP and GDP Per Capita.csv')
df = pd.read_csv(filepath)

# %% [markdown]
# # Head and Tail

# %%
df
# Out:
#       Region/Country/Area                     Unnamed: 1  Year  \
# 0                       1  Total, all countries or areas  1995
# 1                       1  Total, all countries or areas  2005
# 2                       1  Total, all countries or areas  2010
# 3                       1  Total, all countries or areas  2015
# 4                       1  Total, all countries or areas  2017
# ...                   ...                            ...   ...
# 6768                  716                       Zimbabwe  2010
# 6769                  716                       Zimbabwe  2015
# 6770                  716                       Zimbabwe  2017
# 6771                  716                       Zimbabwe  2018
# 6772                  716                       Zimbabwe  2019
#
#                                               Series       Value Footnotes  \
# 0     GDP in current prices (millions of US dollars)  31140783.0       NaN
# ...

# %%
df.shape
# Out:
# (6773, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6773 entries, 0 to 6772
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Region/Country/Area  6773 non-null   int64
#  1   Unnamed: 1           6773 non-null   object
#  2   Year                 6773 non-null   int64
#  3   Series               6773 non-null   object
#  4   Value                6773 non-null   float64
#  5   Footnotes            169 non-null    object
#  6   Source               6773 non-null   object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 370.5+ KB

# %%
df.rename(columns={'Region/Country/Area': 'Code', 
                   'Unnamed: 1': 'Region/Country/Area',
                   }, inplace=True)

df
# Out:
#       Code            Region/Country/Area  Year  \
# 0        1  Total, all countries or areas  1995
# 1        1  Total, all countries or areas  2005
# 2        1  Total, all countries or areas  2010
# 3        1  Total, all countries or areas  2015
# 4        1  Total, all countries or areas  2017
# ...    ...                            ...   ...
# 6768   716                       Zimbabwe  2010
# 6769   716                       Zimbabwe  2015
# 6770   716                       Zimbabwe  2017
# 6771   716                       Zimbabwe  2018
# 6772   716                       Zimbabwe  2019
#
#                                               Series       Value Footnotes  \
# 0     GDP in current prices (millions of US dollars)  31140783.0       NaN
# 1     GDP in current prices (millions of US dollars)  47623151.0       NaN
# 2     GDP in current prices (millions of US dollars)  66272559.0       NaN
# 3     GDP in current prices (millions of US dollars)  74985744.0       NaN
# ...

# %%
df1 = df[['Code', 'Region/Country/Area', 'Year', 'Series', 'Value']]
df1
# Out:
#       Code            Region/Country/Area  Year  \
# 0        1  Total, all countries or areas  1995
# 1        1  Total, all countries or areas  2005
# 2        1  Total, all countries or areas  2010
# 3        1  Total, all countries or areas  2015
# 4        1  Total, all countries or areas  2017
# ...    ...                            ...   ...
# 6768   716                       Zimbabwe  2010
# 6769   716                       Zimbabwe  2015
# 6770   716                       Zimbabwe  2017
# 6771   716                       Zimbabwe  2018
# 6772   716                       Zimbabwe  2019
#
#                                               Series       Value
# 0     GDP in current prices (millions of US dollars)  31140783.0
# 1     GDP in current prices (millions of US dollars)  47623151.0
# 2     GDP in current prices (millions of US dollars)  66272559.0
# 3     GDP in current prices (millions of US dollars)  74985744.0
# ...

# %%
df1.shape
# Out:
# (6773, 5)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6773 entries, 0 to 6772
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Code                 6773 non-null   int64
#  1   Region/Country/Area  6773 non-null   object
#  2   Year                 6773 non-null   int64
#  3   Series               6773 non-null   object
#  4   Value                6773 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 264.7+ KB

# %%
df1.describe(include='object')
# Out:
#                   Region/Country/Area  \
# count                            6773
# unique                            244
# top     Total, all countries or areas
# freq                               28
#
#                                                 Series
# count                                             6773
# unique                                               4
# top     GDP in current prices (millions of US dollars)
# freq                                              1694

# %%
df1['Region/Country/Area'].value_counts()
# Out:
# Total, all countries or areas    28
# Nepal                            28
# Mauritius                        28
# Mexico                           28
# Micronesia (Fed. States of)      28
#                                  ..
# Cura�ao                          23
# South Sudan                      20
# Sudan                            20
# Sudan [former]                   12
# Netherlands Antilles [former]    12
# Name: Region/Country/Area, Length: 244, dtype: int64

# %%
df1['Series'].value_counts()
# Out:
# GDP in current prices (millions of US dollars)          1694
# GDP per capita (US dollars)                             1694
# GDP in constant 2010 prices (millions of US dollars)    1694
# GDP real rates of growth (percent)                      1691
# Name: Series, dtype: int64

# %%
df1['Code'].value_counts()
# Out:
# 1      28
# 524    28
# 480    28
# 484    28
# 583    28
#        ..
# 531    23
# 728    20
# 729    20
# 736    12
# 530    12
# Name: Code, Length: 244, dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
df1['Region/Country/Area'].replace(
    {'C�te d�Ivoire': "Côte d'Ivoire", 
    'Cura�ao': 'Curaçao'}, inplace=True
)

df1['Region/Country/Area'].unique()
# Out:
# array(['Total, all countries or areas', 'Africa', 'Northern Africa',
#        'Sub-Saharan Africa', 'Eastern Africa', 'Middle Africa',
#        'Southern Africa', 'Western Africa', 'Americas',
#        'Northern America', 'Latin America & the Caribbean', 'Caribbean',
#        'Central America', 'South America', 'Asia', 'Central Asia',
#        'Eastern Asia', 'South-eastern Asia', 'Southern Asia',
#        'Western Asia', 'Europe', 'Eastern Europe', 'Northern Europe',
#        'Southern Europe', 'Western Europe', 'Oceania',
#        'Australia and New Zealand', 'Melanesia', 'Micronesia',
#        'Polynesia', 'Afghanistan', 'Albania', 'Algeria', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
# ...

# %%
df1['Year'].value_counts()
# Out:
# 2010    976
# 2015    968
# 2017    968
# 2018    968
# 2019    968
# 2005    966
# 1995    959
# Name: Year, dtype: int64

# %%
df1['Value'].describe()
# Out:
# count    6.773000e+03
# mean     5.803989e+05
# std      3.969967e+06
# min     -4.550000e+01
# 25%      3.050000e+01
# 50%      5.156000e+03
# 75%      4.258700e+04
# max      8.744526e+07
# Name: Value, dtype: float64

# %% [markdown]
# # Missing Values Exploration

# %%
df1.isna().sum()
# Out:
# Code                   0
# Region/Country/Area    0
# Year                   0
# Series                 0
# Value                  0
# dtype: int64

# %% [markdown]
# # Grouping and Aggregation

# %% [markdown]
# Filter By Region

# %%
regions = ['Africa', 'Northern Africa', 'Sub-Saharan Africa', 'Eastern Africa', 'Middle Africa', 'Southern Africa', 'Western Africa', 
           'Americas', 'Northern America', 'Latin America & the Caribbean', 'Caribbean', 'Central America', 'South America', 'Asia', 
           'Central Asia', 'Eastern Asia', 'South-central Asia', 'South-eastern Asia', 'Southern Asia', 'Western Asia', 'Europe', 
           'Eastern Europe', 'Northern Europe', 'Southern Europe', 'Western Europe', 'Oceania', 'Australia and New Zealand', 'Melanesia']

df_reg_filt = df1[df1['Region/Country/Area'].isin(regions)]
df_reg_filt
# Out:
#      Code Region/Country/Area  Year  \
# 28      2              Africa  1995
# 29      2              Africa  2005
# 30      2              Africa  2010
# 31      2              Africa  2015
# 32      2              Africa  2017
# ..    ...                 ...   ...
# 779    54           Melanesia  2010
# 780    54           Melanesia  2015
# 781    54           Melanesia  2017
# 782    54           Melanesia  2018
# 783    54           Melanesia  2019
#
#                                              Series      Value
# 28   GDP in current prices (millions of US dollars)   586929.0
# 29   GDP in current prices (millions of US dollars)  1128065.0
# 30   GDP in current prices (millions of US dollars)  1969815.0
# 31   GDP in current prices (millions of US dollars)  2314902.0
# 32   GDP in current prices (millions of US dollars)  2244978.0
# ..                                              ...        ...
# 779              GDP real rates of growth (percent)        8.2
# ...

# %%
df_reg_filt.rename(columns={
    'Region/Country/Area': 'Region'
}, inplace=True)

df_reg_filt
# Out:
#      Code     Region  Year                                          Series  \
# 28      2     Africa  1995  GDP in current prices (millions of US dollars)
# 29      2     Africa  2005  GDP in current prices (millions of US dollars)
# 30      2     Africa  2010  GDP in current prices (millions of US dollars)
# 31      2     Africa  2015  GDP in current prices (millions of US dollars)
# 32      2     Africa  2017  GDP in current prices (millions of US dollars)
# ..    ...        ...   ...                                             ...
# 779    54  Melanesia  2010              GDP real rates of growth (percent)
# 780    54  Melanesia  2015              GDP real rates of growth (percent)
# 781    54  Melanesia  2017              GDP real rates of growth (percent)
# 782    54  Melanesia  2018              GDP real rates of growth (percent)
# 783    54  Melanesia  2019              GDP real rates of growth (percent)
#
#          Value
# 28    586929.0
# 29   1128065.0
# 30   1969815.0
# ...

# %% [markdown]
# Filter GDP in Millions

# %%
millions = ['GDP in current prices (millions of US dollars)', 
            'GDP in constant 2010 prices (millions of US dollars)']


df_reg_filt_mill = df_reg_filt[df_reg_filt['Series'].isin(millions)]
df_reg_filt_mill
# Out:
#      Code     Region  Year                                             Series  \
# 28      2     Africa  1995     GDP in current prices (millions of US dollars)
# 29      2     Africa  2005     GDP in current prices (millions of US dollars)
# 30      2     Africa  2010     GDP in current prices (millions of US dollars)
# 31      2     Africa  2015     GDP in current prices (millions of US dollars)
# 32      2     Africa  2017     GDP in current prices (millions of US dollars)
# ..    ...        ...   ...                                                ...
# 772    54  Melanesia  2010  GDP in constant 2010 prices (millions of US do...
# 773    54  Melanesia  2015  GDP in constant 2010 prices (millions of US do...
# 774    54  Melanesia  2017  GDP in constant 2010 prices (millions of US do...
# 775    54  Melanesia  2018  GDP in constant 2010 prices (millions of US do...
# 776    54  Melanesia  2019  GDP in constant 2010 prices (millions of US do...
#
#          Value
# 28    586929.0
# ...

# %% [markdown]
# Aggregated GDP Grouped By Region in Millions of US Dollars

# %%
df_reg_gpd_agg = df_reg_filt_mill.groupby('Region').agg(
    min_GDP = pd.NamedAgg('Value', np.min),
    mean_GDP = pd.NamedAgg('Value', np.mean),
    max_GDP = pd.NamedAgg('Value', np.max),
    total_GDP = pd.NamedAgg('Value', np.sum)
)

df_reg_gpd_agg
# Out:
#                                   min_GDP      mean_GDP     max_GDP  \
# Region
# Africa                           586929.0  1.971981e+06   2591409.0
# Americas                       10217473.0  2.302161e+07  28619075.0
# Asia                            9220248.0  2.354296e+07  33081821.0
# Australia and New Zealand        454246.0  1.298450e+06   1666873.0
# Caribbean                        120476.0  3.100285e+05    388983.0
# Central America                  412010.0  1.242307e+06   1528259.0
# Central Asia                      41639.0  2.460185e+05    375468.0
# Eastern Africa                    69332.0  2.694722e+05    407967.0
# Eastern Asia                    6571799.0  1.578982e+07  22132386.0
# Eastern Europe                   794684.0  2.468966e+06   3354841.0
# Europe                         10642810.0  1.847289e+07  21991871.0
# Latin America & the Caribbean   1967903.0  4.759104e+06   5780761.0
# Melanesia                         13575.0  3.228857e+04     42563.0
# ...

# %% [markdown]
# Filter Top and Bottom 10 Regions GDP in Millions of Dollars

# %%
top_10_gdp_reg = df_reg_gpd_agg['total_GDP'].sort_values(ascending=False).head(10)
bottom_10_gdp_reg = df_reg_gpd_agg['total_GDP'].sort_values(ascending=True).head(10)

print(top_10_gdp_reg)
print('\n')
print(bottom_10_gdp_reg)
# Out:
# Region
# Asia                             329601398.0
# Americas                         322302541.0
# Europe                           258620514.0
# Northern America                 255675081.0
# Eastern Asia                     221057466.0
# Western Europe                   111567584.0
# Latin America & the Caribbean     66627459.0
# Northern Europe                   61183227.0
# Southern Europe                   51304185.0
# South America                     44894763.0
# Name: total_GDP, dtype: float64
#
#
# Region
# Melanesia                      452040.0
# Middle Africa                 2641887.0
# Central Asia                  3444259.0
# Eastern Africa                3772611.0
# Caribbean                     4340399.0
# Southern Africa               4579366.0
# Western Africa                7671497.0
# Northern Africa               8942368.0
# Central America              17392296.0
# Australia and New Zealand    18178306.0
# Name: total_GDP, dtype: float64

# %% [markdown]
# # Data Visualization By Region

# %%
# helper function for formatting plot y-axis
from matplotlib.ticker import FuncFormatter

def million(x, pos):
    'The two args are the value and tick position'
    return '%1.1fM' % (x * 1e-6)

formatter = FuncFormatter(million)


# helper function to plot horizontal bar chart 
def plot_hbar(y, width, align='center', xlabel=None, ylabel=None, title=None, color=None):

    # Initialize the matplotlib figure
    fig, ax = plt.subplots()

    # plot bar chart
    ax.barh(
        y=y, width=width,
        align=align
    )

    # Add informative axis label
    ax.set(xlabel=xlabel, ylabel=ylabel, title=title)

    # labels read top-to-bottom
    ax.invert_yaxis()  

    # set axis formatter
    ax.xaxis.set_major_formatter(formatter)

    # despine x-axis and y-axis
    sns.despine(left=True, bottom=True)

# %% [markdown]
# Top 10 Regions

# %%
plot_hbar(y=top_10_gdp_reg.keys(), width=top_10_gdp_reg.values, 
          xlabel='GDP in current prices ($)', ylabel='Region', title='GDP by Region')

# %% [markdown]
# Bottom 10 Regions

# %%
plot_hbar(y=bottom_10_gdp_reg.keys(), width=sorted(bottom_10_gdp_reg.values), 
          xlabel='GDP in current prices ($)', ylabel='Region', title='GDP by Region')

# %% [markdown]
# Filter GDP per capita in US Dollars

# %%
per_cap = ['GDP per capita (US dollars)']

df_reg_filt_percap = df_reg_filt[df_reg_filt['Series'].isin(per_cap)]
df_reg_filt_percap
# Out:
#      Code     Region  Year                       Series   Value
# 35      2     Africa  1995  GDP per capita (US dollars)   819.0
# 36      2     Africa  2005  GDP per capita (US dollars)  1233.0
# 37      2     Africa  2010  GDP per capita (US dollars)  1898.0
# 38      2     Africa  2015  GDP per capita (US dollars)  1960.0
# 39      2     Africa  2017  GDP per capita (US dollars)  1807.0
# ..    ...        ...   ...                          ...     ...
# 765    54  Melanesia  2010  GDP per capita (US dollars)  3066.0
# 766    54  Melanesia  2015  GDP per capita (US dollars)  3658.0
# 767    54  Melanesia  2017  GDP per capita (US dollars)  3771.0
# 768    54  Melanesia  2018  GDP per capita (US dollars)  3933.0
# 769    54  Melanesia  2019  GDP per capita (US dollars)  3898.0
#
# [189 rows x 5 columns]

# %%
df_reg_gpd_agg1 = df_reg_filt_percap.groupby('Region').agg(
    min_GDP_per_capita = pd.NamedAgg('Value', np.min),
    mean_GDP_per_capita = pd.NamedAgg('Value', np.mean),
    max_GDP_per_capita = pd.NamedAgg('Value', np.max),
    total_GDP_per_capita = pd.NamedAgg('Value', np.sum)
)

df_reg_gpd_agg1
# Out:
#                                min_GDP_per_capita  mean_GDP_per_capita  \
# Region
# Africa                                      819.0          1637.142857
# Americas                                  13160.0         23560.714286
# Asia                                       2640.0          5369.000000
# Australia and New Zealand                 20964.0         46566.428571
# Caribbean                                  3419.0          7354.000000
# Central America                            3308.0          7307.714286
# Central Asia                                783.0          3244.285714
# Eastern Africa                              318.0           697.714286
# Eastern Asia                               4908.0          9697.428571
# Eastern Europe                             2568.0          8504.714286
# Europe                                    14611.0         24992.857143
# Latin America & the Caribbean              4083.0          7617.142857
# ...

# %%
# helper function for formatting plot y-axis
from matplotlib.ticker import FuncFormatter

def thousand(x, pos):
    'The two args are the value and tick position'
    return '%1.1fK' % (x * 1e-3)

formatter1 = FuncFormatter(thousand)


# helper function to plot horizontal bar chart 
def plot_hbar1(y, width, align='center', xlabel=None, ylabel=None, title=None, color=None):

    # Initialize the matplotlib figure
    fig, ax = plt.subplots()

    # plot bar chart
    ax.barh(
        y=y, width=width,
        align=align
    )

    # Add informative axis label
    ax.set(xlabel=xlabel, ylabel=ylabel, title=title)

    # labels read top-to-bottom
    ax.invert_yaxis()  

    # set axis formatter
    ax.xaxis.set_major_formatter(formatter1)

    # despine x-axis and y-axis
    sns.despine(left=True, bottom=True)

# %% [markdown]
# Filter Top and Bottom 10 Regions GDP per Capita in Dollars

# %%
top_10_gdp_cap_reg = df_reg_gpd_agg1['total_GDP_per_capita'].sort_values(ascending=False).head(10)
bottom_10_gdp_cap_reg = df_reg_gpd_agg1['total_GDP_per_capita'].sort_values(ascending=True).head(10)

print(top_10_gdp_cap_reg)
print('\n')
print(bottom_10_gdp_cap_reg)
# Out:
# Region
# Northern America             358495.0
# Australia and New Zealand    325965.0
# Western Europe               293672.0
# Northern Europe              293005.0
# Oceania                      242699.0
# Europe                       174950.0
# Southern Europe              170710.0
# Americas                     164925.0
# Western Asia                  69640.0
# Eastern Asia                  67882.0
# Name: total_GDP_per_capita, dtype: float64
#
#
# Region
# Eastern Africa         4884.0
# Middle Africa          8540.0
# Sub-Saharan Africa     9815.0
# Western Africa        10295.0
# Southern Asia         10742.0
# Africa                11460.0
# Northern Africa       18310.0
# Melanesia             22470.0
# Central Asia          22710.0
# South-eastern Asia    24008.0
# Name: total_GDP_per_capita, dtype: float64

# %% [markdown]
# Top 10 Regions

# %%
plot_hbar1(y=top_10_gdp_cap_reg.keys(), width=top_10_gdp_cap_reg.values, 
          xlabel='GDP per capita ($)', ylabel='Region', title='GDP per capita by Region')

# %% [markdown]
# Bottom 10 Regions

# %%
plot_hbar1(y=bottom_10_gdp_cap_reg.keys(), width=bottom_10_gdp_cap_reg.values, 
          xlabel='GDP per capita ($)', ylabel='Region', title='GDP per capita by Region')

# %% [markdown]
# Filter GDP real rates in percent

# %%
percentage = ['GDP real rates of growth (percent)']

df_reg_filt_pct = df_reg_filt[df_reg_filt['Series'].isin(percentage)]
df_reg_filt_pct
# Out:
#      Code     Region  Year                              Series  Value
# 49      2     Africa  1995  GDP real rates of growth (percent)    2.6
# 50      2     Africa  2005  GDP real rates of growth (percent)    6.2
# 51      2     Africa  2010  GDP real rates of growth (percent)    5.7
# 52      2     Africa  2015  GDP real rates of growth (percent)    2.8
# 53      2     Africa  2017  GDP real rates of growth (percent)    3.3
# ..    ...        ...   ...                                 ...    ...
# 779    54  Melanesia  2010  GDP real rates of growth (percent)    8.2
# 780    54  Melanesia  2015  GDP real rates of growth (percent)    4.6
# 781    54  Melanesia  2017  GDP real rates of growth (percent)    3.4
# 782    54  Melanesia  2018  GDP real rates of growth (percent)    0.8
# 783    54  Melanesia  2019  GDP real rates of growth (percent)    4.4
#
# [189 rows x 5 columns]

# %% [markdown]
# Group By Region

# %%
df_reg_gdp_rates = df_reg_filt_pct[['Region', 'Year', 'Value']].groupby('Region')
df_reg_gdp_rates.head()
# Out:
#         Region  Year  Value
# 49      Africa  1995    2.6
# 50      Africa  2005    6.2
# 51      Africa  2010    5.7
# 52      Africa  2015    2.8
# 53      Africa  2017    3.3
# ..         ...   ...    ...
# 777  Melanesia  1995    0.3
# 778  Melanesia  2005    3.7
# 779  Melanesia  2010    8.2
# 780  Melanesia  2015    4.6
# 781  Melanesia  2017    3.4
#
# [135 rows x 3 columns]

# %% [markdown]
# # GDP real rates of growth in Percent by Region Exploration

# %% [markdown]
# Get Continents Dataframe

# %%
africa_df = df_reg_gdp_rates.get_group('Africa')
americas_df = df_reg_gdp_rates.get_group('Americas')
asia_df = df_reg_gdp_rates.get_group('Asia')
anz_df = df_reg_gdp_rates.get_group('Australia and New Zealand')
oceania_df = df_reg_gdp_rates.get_group('Oceania')
europe_df = df_reg_gdp_rates.get_group('Europe')

# %%
# bar plot helper function
def plot_bar(df, x, y, xlabel=None, ylabel=None, title=None):

    # set plot theme
    sns.set_theme(style='white', context='talk')

    # Initialize the matplotlib figure
    fig, ax = plt.subplots()
    fig.autofmt_xdate()

    # plot bar chart
    sns.barplot(
        x=x, y=y, 
        data=df, ci=None,
        ax=ax
    )

    sns.despine(left=True, bottom=True)

    # matplotlib axis label
    ax.set(xlabel=xlabel, ylabel=ylabel, title=title)

    return plot_bar

# %%
plot_bar(df=africa_df, 
         x='Year', y='Value', 
         xlabel='Year', ylabel='GDP real rates of growth (percent)', title='GDP Real Rates of Growth (Africa)')
# Out:
# <function __main__.plot_bar(df, x, y, xlabel=None, ylabel=None, title=None)>

# %%
plot_bar(df=americas_df, 
         x='Year', y='Value', 
         xlabel='Year', ylabel='GDP real rates of growth (percent)', title='GDP Real Rates of Growth (Americas)')
# Out:
# <function __main__.plot_bar(df, x, y, xlabel=None, ylabel=None, title=None)>

# %%
plot_bar(df=asia_df, 
         x='Year', y='Value', 
         xlabel='Year', ylabel='GDP real rates of growth (percent)', title='GDP Real Rates of Growth (Asia)')
# Out:
# <function __main__.plot_bar(df, x, y, xlabel=None, ylabel=None, title=None)>

# %%
plot_bar(df=anz_df, 
         x='Year', y='Value', 
         xlabel='Year', ylabel='GDP real rates of growth (percent)', title='GDP Real Rates of Growth (Australia and New Zealand)')
# Out:
# <function __main__.plot_bar(df, x, y, xlabel=None, ylabel=None, title=None)>

# %%
plot_bar(df=oceania_df, 
         x='Year', y='Value', 
         xlabel='Year', ylabel='GDP real rates of growth (percent)', title='GDP Real Rates of Growth (Oceania)')
# Out:
# <function __main__.plot_bar(df, x, y, xlabel=None, ylabel=None, title=None)>

# %%
plot_bar(df=europe_df, 
         x='Year', y='Value', 
         xlabel='Year', ylabel='GDP real rates of growth (percent)', title='GDP Real Rates of Growth (Europe)')
# Out:
# <function __main__.plot_bar(df, x, y, xlabel=None, ylabel=None, title=None)>
