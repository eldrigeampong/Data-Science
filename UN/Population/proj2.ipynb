# %% [markdown]
# # International migrants and refugees

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings

# %% [markdown]
# # Options and Settings

# %%
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.autolayout'] = True
plt.rcParams['figure.figsize'] = [12, 9]
plt.rcParams['font.size'] = 12
path = os.getcwd()                                         # get current working directory
warnings.simplefilter('ignore')

# %% [markdown]
# # Import Data

# %%
filepath = os.path.join('datasets', 'International Migrants and Refugees.csv')
df = pd.read_csv(filepath)

# %% [markdown]
# # Head and Tail

# %%
df
# Out:
#       Region/Country/Area                     Unnamed: 1  Year  \
# 0                       1  Total, all countries or areas  2005
# 1                       1  Total, all countries or areas  2005
# 2                       1  Total, all countries or areas  2005
# 3                       1  Total, all countries or areas  2005
# 4                       1  Total, all countries or areas  2010
# ...                   ...                            ...   ...
# 6587                  716                       Zimbabwe  2020
# 6588                  716                       Zimbabwe  2020
# 6589                  716                       Zimbabwe  2020
# 6590                  716                       Zimbabwe  2020
# 6591                  716                       Zimbabwe  2020
#
#                                                  Series        Value  \
# 0      International migrant stock: Both sexes (number)  191446828.0
# ...

# %%
df.shape
# Out:
# (6592, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6592 entries, 0 to 6591
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Region/Country/Area  6592 non-null   int64
#  1   Unnamed: 1           6592 non-null   object
#  2   Year                 6592 non-null   int64
#  3   Series               6592 non-null   object
#  4   Value                6592 non-null   float64
#  5   Footnotes            3856 non-null   object
#  6   Source               6592 non-null   object
#  7   Unnamed: 7           629 non-null    object
#  8   Unnamed: 8           16 non-null     object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 463.6+ KB

# %%
df.rename(columns={'Region/Country/Area': 'Code', 
                   'Unnamed: 1': 'Region/Country/Area',
                   }, inplace=True)

df
# Out:
#       Code            Region/Country/Area  Year  \
# 0        1  Total, all countries or areas  2005
# 1        1  Total, all countries or areas  2005
# 2        1  Total, all countries or areas  2005
# 3        1  Total, all countries or areas  2005
# 4        1  Total, all countries or areas  2010
# ...    ...                            ...   ...
# 6587   716                       Zimbabwe  2020
# 6588   716                       Zimbabwe  2020
# 6589   716                       Zimbabwe  2020
# 6590   716                       Zimbabwe  2020
# 6591   716                       Zimbabwe  2020
#
#                                                  Series        Value  \
# 0      International migrant stock: Both sexes (number)  191446828.0
# 1     International migrant stock: Both sexes (% tot...          2.9
# 2     International migrant stock: Male (% total Pop...          3.0
# 3     International migrant stock: Female (% total P...          2.9
# ...

# %%
df1 = df[['Code', 'Region/Country/Area', 'Year', 'Series', 'Value']]
df1
# Out:
#       Code            Region/Country/Area  Year  \
# 0        1  Total, all countries or areas  2005
# 1        1  Total, all countries or areas  2005
# 2        1  Total, all countries or areas  2005
# 3        1  Total, all countries or areas  2005
# 4        1  Total, all countries or areas  2010
# ...    ...                            ...   ...
# 6587   716                       Zimbabwe  2020
# 6588   716                       Zimbabwe  2020
# 6589   716                       Zimbabwe  2020
# 6590   716                       Zimbabwe  2020
# 6591   716                       Zimbabwe  2020
#
#                                                  Series        Value
# 0      International migrant stock: Both sexes (number)  191446828.0
# 1     International migrant stock: Both sexes (% tot...          2.9
# 2     International migrant stock: Male (% total Pop...          3.0
# 3     International migrant stock: Female (% total P...          2.9
# ...

# %%
df1.shape
# Out:
# (6592, 5)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6592 entries, 0 to 6591
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Code                 6592 non-null   int64
#  1   Region/Country/Area  6592 non-null   object
#  2   Year                 6592 non-null   int64
#  3   Series               6592 non-null   object
#  4   Value                6592 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 257.6+ KB

# %%
df1.describe(include='object')
# Out:
#          Region/Country/Area                                            Series
# count                   6592                                              6592
# unique                   263                                                 8
# top     China, Hong Kong SAR  International migrant stock: Both sexes (number)
# freq                      36                                              1045

# %%
df1['Region/Country/Area'].value_counts()
# Out:
# China, Hong Kong SAR    36
# Eritrea                 35
# Egypt                   35
# Switzerland             35
# Ghana                   34
#                         ..
# San Marino               8
# Isle of Man              8
# Tokelau                  8
# Cook Islands             8
# Latin America            4
# Name: Region/Country/Area, Length: 263, dtype: int64

# %%
df1['Series'].value_counts()
# Out:
# International migrant stock: Both sexes (number)                 1045
# International migrant stock: Both sexes (% total population)     1045
# International migrant stock: Male (% total Population)            913
# International migrant stock: Female (% total Population)          913
# Total population of concern to UNHCR (number)                     752
# Total refugees and people in refugee-like situations (number)     702
# Asylum seekers, including pending cases (number)                  685
# Other of concern to UNHCR (number)                                537
# Name: Series, dtype: int64

# %%
df1['Code'].value_counts()
# Out:
# 344    36
# 232    35
# 818    35
# 756    35
# 288    34
#        ..
# 674     8
# 833     8
# 772     8
# 184     8
# 420     4
# Name: Code, Length: 263, dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
df1['Region/Country/Area'].replace(
    {'C�te d�Ivoire': "Côte d'Ivoire", 
    'Cura�ao': 'Curaçao',
    'R�union': 'Réunion'}, inplace=True
)

df1['Region/Country/Area'].unique()
# Out:
# array(['Total, all countries or areas', 'Africa', 'Northern Africa',
#        'Sub-Saharan Africa', 'Eastern Africa', 'Middle Africa',
#        'Southern Africa', 'Western Africa', 'Northern America',
#        'Latin America & the Caribbean', 'Caribbean', 'Latin America',
#        'Central America', 'South America', 'Asia', 'Central Asia',
#        'Eastern Asia', 'South-central Asia', 'South-eastern Asia',
#        'Southern Asia', 'Western Asia', 'Europe', 'Eastern Europe',
#        'Northern Europe', 'Southern Europe', 'Western Europe', 'Oceania',
#        'Australia and New Zealand', 'Melanesia', 'Micronesia',
#        'Polynesia', 'Afghanistan', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
# ...

# %%
df1['Year'].value_counts()
# Out:
# 2020    1666
# 2015    1640
# 2010    1609
# 2005    1535
# 2019      61
# 2017      28
# 2018      27
# 2016      26
# Name: Year, dtype: int64

# %%
df1['Value'].describe()
# Out:
# count    6.592000e+03
# mean     7.122918e+05
# std      7.074442e+06
# min      0.000000e+00
# 25%      4.200000e+00
# 50%      6.260000e+01
# 75%      2.429975e+04
# max      2.805981e+08
# Name: Value, dtype: float64

# %% [markdown]
# # Missing Values Exploration

# %%
df1.isna().sum()
# Out:
# Code                   0
# Region/Country/Area    0
# Year                   0
# Series                 0
# Value                  0
# dtype: int64

# %% [markdown]
# # Grouping and Aggregation

# %% [markdown]
# Filter By Region

# %%
regions = ['Africa', 'Northern Africa', 'Sub-Saharan Africa', 'Eastern Africa', 'Middle Africa', 'Southern Africa', 'Western Africa', 
           'Northern America', 'Latin America & the Caribbean', 'Caribbean', 'Latin America', 'Central America', 'South America', 
           'Asia', 'Central Asia', 'Eastern Asia', 'South-central Asia', 'South-eastern Asia', 'Southern Asia', 'Western Asia', 
           'Europe',  'Eastern Europe', 'Northern Europe', 'Southern Europe', 'Western Europe', 'Oceania', 'Australia and New Zealand', 
           'Melanesia']

df_reg_filt = df1[df1['Region/Country/Area'].isin(regions)]
df_reg_filt
# Out:
#      Code Region/Country/Area  Year  \
# 24      2              Africa  2005
# 25      2              Africa  2005
# 26      2              Africa  2005
# 27      2              Africa  2005
# 28      2              Africa  2010
# ..    ...                 ...   ...
# 496    54           Melanesia  2015
# 497    54           Melanesia  2020
# 498    54           Melanesia  2020
# 499    54           Melanesia  2020
# 500    54           Melanesia  2020
#
#                                                 Series       Value
# 24    International migrant stock: Both sexes (number)  16040087.0
# 25   International migrant stock: Both sexes (% tot...         1.8
# 26   International migrant stock: Male (% total Pop...         1.9
# 27   International migrant stock: Female (% total P...         1.6
# 28    International migrant stock: Both sexes (number)  17806677.0
# ..                                                 ...         ...
# ...

# %%
df_reg_filt.rename(columns={
    'Region/Country/Area': 'Region'
}, inplace=True)

df_reg_filt
# Out:
#      Code     Region  Year                                             Series  \
# 24      2     Africa  2005   International migrant stock: Both sexes (number)
# 25      2     Africa  2005  International migrant stock: Both sexes (% tot...
# 26      2     Africa  2005  International migrant stock: Male (% total Pop...
# 27      2     Africa  2005  International migrant stock: Female (% total P...
# 28      2     Africa  2010   International migrant stock: Both sexes (number)
# ..    ...        ...   ...                                                ...
# 496    54  Melanesia  2015  International migrant stock: Female (% total P...
# 497    54  Melanesia  2020   International migrant stock: Both sexes (number)
# 498    54  Melanesia  2020  International migrant stock: Both sexes (% tot...
# 499    54  Melanesia  2020  International migrant stock: Male (% total Pop...
# 500    54  Melanesia  2020  International migrant stock: Female (% total P...
#
#           Value
# ...

# %% [markdown]
# Filter International migrant stock: Both sexes (number)

# %%
number = ['International migrant stock: Both sexes (number)']

df_reg_filt_ims = df_reg_filt[df_reg_filt['Series'].isin(number)]
df_reg_filt_ims
# Out:
#      Code                     Region  Year  \
# 24      2                     Africa  2005
# 28      2                     Africa  2010
# 32      2                     Africa  2015
# 40      2                     Africa  2020
# 48     15            Northern Africa  2005
# ..    ...                        ...   ...
# 481    53  Australia and New Zealand  2020
# 485    54                  Melanesia  2005
# 489    54                  Melanesia  2010
# 493    54                  Melanesia  2015
# 497    54                  Melanesia  2020
#
#                                                Series       Value
# 24   International migrant stock: Both sexes (number)  16040087.0
# 28   International migrant stock: Both sexes (number)  17806677.0
# 32   International migrant stock: Both sexes (number)  22860792.0
# 40   International migrant stock: Both sexes (number)  25389464.0
# 48   International migrant stock: Both sexes (number)   1749718.0
# ...

# %% [markdown]
# Aggregated International migrant stock

# %%
df_reg_gpd_agg = df_reg_filt_ims.groupby('Region').agg(
    min_ims = pd.NamedAgg('Value', np.min),
    mean_ims = pd.NamedAgg('Value', np.mean),
    max_ims = pd.NamedAgg('Value', np.max),
    total_ims = pd.NamedAgg('Value', np.sum)
)

df_reg_gpd_agg
# Out:
#                                   min_ims     mean_ims     max_ims  \
# Region
# Africa                         16040087.0  20524255.00  25389464.0
# Asia                           53249787.0  70545794.50  85618502.0
# Australia and New Zealand       5717982.0   7346363.75   9067584.0
# Caribbean                       1275731.0   1430213.25   1605148.0
# Central America                 1378041.0   1822821.25   2302001.0
# Central Asia                    5235877.0   5364412.25   5564042.0
# Eastern Africa                  4743657.0   5978007.25   7682801.0
# Eastern Asia                    6228684.0   7533400.75   8975729.0
# Eastern Europe                 19110686.0  19881158.50  20835402.0
# Europe                         63585731.0  73919510.50  86706068.0
# Latin America & the Caribbean   7184113.0   9936706.75  14794623.0
# Melanesia                        103881.0    114497.00    124073.0
# Middle Africa                   1961951.0   2935058.00   3861568.0
# ...

# %% [markdown]
# Filter Top and Bottom 10 Regions International migrant stock

# %%
top_10_ims_reg = df_reg_gpd_agg['total_ims'].sort_values(ascending=False).head(10)
bottom_10_ims_reg = df_reg_gpd_agg['total_ims'].sort_values(ascending=True).head(10)

print(top_10_ims_reg)
print('\n')
print(bottom_10_ims_reg)
# Out:
# Region
# Europe                295678042.0
# Asia                  282183178.0
# Northern America      210676149.0
# Western Asia          138599474.0
# Western Europe        105413268.0
# Africa                 82097020.0
# Eastern Europe         79524634.0
# South-central Asia     77225168.0
# Sub-Saharan Africa     73088418.0
# Southern Europe        61691442.0
# Name: total_ims, dtype: float64
#
#
# Region
# Melanesia            457988.0
# Caribbean           5720853.0
# Central America     7291285.0
# Northern Africa     9008602.0
# Southern Africa    10538237.0
# Middle Africa      11740232.0
# Central Asia       21457649.0
# Eastern Africa     23912029.0
# South America      26734689.0
# Western Africa     26897920.0
# Name: total_ims, dtype: float64

# %% [markdown]
# # Data Visualization By Region

# %%
# helper function for formatting plot y-axis
from matplotlib.ticker import FuncFormatter

def million(x, pos):
    'The two args are the value and tick position'
    return '%1.1fM' % (x * 1e-6)

formatter = FuncFormatter(million)


# helper function to plot horizontal bar chart 
def plot_hbar(y, width, color=True, align='center', xlabel=None, ylabel=None, title=None):

    # Initialize the matplotlib figure
    fig, ax = plt.subplots()

    # plot bar chart
    ax.barh(
        y=y, width=width,
        color='b',
        align=align
    )

    # Add informative axis label
    ax.set(xlabel=xlabel, ylabel=ylabel, title=title)

    # labels read top-to-bottom
    ax.invert_yaxis()  

    # set axis formatter
    ax.xaxis.set_major_formatter(formatter)

    # despine x-axis and y-axis
    sns.despine(left=True, bottom=True)

# %% [markdown]
# Top 10 Regions

# %%
plot_hbar(y=top_10_ims_reg.keys(), width=top_10_ims_reg.values, 
          xlabel='International migrant stock', ylabel='Region', title='International migrant stock by Region')

# %% [markdown]
# Bottom 10 Regions

# %%
plot_hbar(y=bottom_10_ims_reg.keys(), width=bottom_10_ims_reg.values, 
          xlabel='International migrant stock', ylabel='Region', title='International migrant stock by Region')

# %% [markdown]
# Filter International migrant stock in Percentage

# %%
ims_pct = ['International migrant stock: Both sexes (% total population)',
           'International migrant stock: Male (% total Population)',
           'International migrant stock: Female (% total Population)']

df_reg_filt_imspct = df_reg_filt[df_reg_filt['Series'].isin(ims_pct)]
df_reg_filt_imspct
# Out:
#      Code     Region  Year                                             Series  \
# 25      2     Africa  2005  International migrant stock: Both sexes (% tot...
# 26      2     Africa  2005  International migrant stock: Male (% total Pop...
# 27      2     Africa  2005  International migrant stock: Female (% total P...
# 29      2     Africa  2010  International migrant stock: Both sexes (% tot...
# 30      2     Africa  2010  International migrant stock: Male (% total Pop...
# ..    ...        ...   ...                                                ...
# 495    54  Melanesia  2015  International migrant stock: Male (% total Pop...
# 496    54  Melanesia  2015  International migrant stock: Female (% total P...
# 498    54  Melanesia  2020  International migrant stock: Both sexes (% tot...
# 499    54  Melanesia  2020  International migrant stock: Male (% total Pop...
# 500    54  Melanesia  2020  International migrant stock: Female (% total P...
#
#      Value
# 25     1.8
# ...

# %% [markdown]
# # International migrant stock by Region Exploration

# %% [markdown]
# Filter Africa, Americas, Asia, Australia and New Zealand, Oceania and Europe Continents

# %%
continents = ['Africa', 'Americas', 'Asia', 'Australia and New Zealand', 'Oceania', 'Europe']

continents_df = df_reg_filt_imspct[df_reg_filt_imspct['Region'].isin(continents)]
continents_df.head()
# Out:
#     Code  Region  Year                                             Series  \
# 25     2  Africa  2005  International migrant stock: Both sexes (% tot...
# 26     2  Africa  2005  International migrant stock: Male (% total Pop...
# 27     2  Africa  2005  International migrant stock: Female (% total P...
# 29     2  Africa  2010  International migrant stock: Both sexes (% tot...
# 30     2  Africa  2010  International migrant stock: Male (% total Pop...
#
#     Value
# 25    1.8
# 26    1.9
# 27    1.6
# 29    1.7
# 30    1.8

# %%
# bar plot helper function
def plot_bar(df, x, y, hue, xlabel=None, ylabel=None, title=None):

    # set plot theme
    sns.set_theme(style='white', context='talk')

    # Initialize the matplotlib figure
    fig, ax = plt.subplots()
    fig.autofmt_xdate()

    # plot bar chart
    sns.barplot(
        x=x, y=y, 
        hue=hue, data=df, ci=None, 
        ax=ax
    )

    # despine axes
    sns.despine(left=True, bottom=True)

    # matplotlib axis label
    ax.set(xlabel=xlabel, ylabel=ylabel, title=title)

    return plot_bar

# %%
plot_bar(df=continents_df,
         x='Year', y='Value', 
         hue='Region', 
         xlabel='Year', ylabel='International migrant stock')
# Out:
# <function __main__.plot_bar(df, x, y, hue, xlabel=None, ylabel=None, title=None)>

# %% [markdown]
# Filter Total refugees and people in refugee-like situations (number)

# %%
tot_refug = ['Total refugees and people in refugee-like situations (number)']

df_reg_filt_totref = df_reg_filt[df_reg_filt['Series'].isin(tot_refug)]
df_reg_filt_totref
# Out:
#      Code                         Region  Year  \
# 36      2                         Africa  2015
# 44      2                         Africa  2020
# 148    21               Northern America  2015
# 151    21               Northern America  2019
# 171   419  Latin America & the Caribbean  2015
# 175   419  Latin America & the Caribbean  2019
# 199   420                  Latin America  2020
# 247   142                           Asia  2015
# 255   142                           Asia  2020
# 367   150                         Europe  2015
# 375   150                         Europe  2020
# 455     9                        Oceania  2015
# 458     9                        Oceania  2019
# 466     9                        Oceania  2020
#
#                                                 Series      Value
# 36   Total refugees and people in refugee-like situ...  4493139.0
# 44   Total refugees and people in refugee-like situ...  6999300.0
# ...

# %% [markdown]
# # Total refugees and people in refugee-like situations by Continent Exploration

# %%
# helper function for formatting plot y-axis
from matplotlib.ticker import FuncFormatter

def million(x, pos):
    'The two args are the value and tick position'
    return '%1.1fM' % (x * 1e-6)

formatter1 = FuncFormatter(million)


def plot_bar1(df ,x, y, hue=True, xlabel=None, ylabel=None, title=None):

    # Initialize the matplotlib figure
    fig, ax = plt.subplots()
    fig.autofmt_xdate()

    # create barplot
    sns.barplot(
    x=x, y=y,
    hue='Region', ci=None,
    data=df, ax=ax)

    # label axis
    ax.set(xlabel=xlabel, ylabel=ylabel, title=title)

    # Add informative axis label
    ax.yaxis.set_major_formatter(formatter1)

    # despine x-axis and y-axis
    sns.despine(left=True, bottom=True)

    # add plot legend
    ax.legend(loc=9)

    return plot_bar1

# %%
continents = ['Africa', 'Americas', 'Asia', 'Australia and New Zealand', 'Oceania', 'Europe']

continents_df1 = df_reg_filt_totref[df_reg_filt_totref['Region'].isin(continents)]
continents_df1.head()
# Out:
#      Code  Region  Year                                             Series  \
# 36      2  Africa  2015  Total refugees and people in refugee-like situ...
# 44      2  Africa  2020  Total refugees and people in refugee-like situ...
# 247   142    Asia  2015  Total refugees and people in refugee-like situ...
# 255   142    Asia  2020  Total refugees and people in refugee-like situ...
# 367   150  Europe  2015  Total refugees and people in refugee-like situ...
#
#          Value
# 36   4493139.0
# 44   6999300.0
# 247  8178380.0
# 255  9904753.0
# 367  1626214.0

# %%
plot_bar1(
    df=continents_df1,
    x='Year', y='Value',
    xlabel='Year', ylabel='Total refugees and people in refugee-like situations',
)
# Out:
# <function __main__.plot_bar1(df, x, y, hue=True, xlabel=None, ylabel=None, title=None)>

# %% [markdown]
# Filter Asylum seekers, including pending cases (number)

# %%
asy_seek = ['Asylum seekers, including pending cases (number)']

df_reg_filt_asyseek = df_reg_filt[df_reg_filt['Series'].isin(asy_seek)]
df_reg_filt_asyseek
# Out:
#      Code                         Region  Year  \
# 37      2                         Africa  2015
# 45      2                         Africa  2020
# 149    21               Northern America  2015
# 152    21               Northern America  2019
# 172   419  Latin America & the Caribbean  2015
# 176   419  Latin America & the Caribbean  2019
# 200   420                  Latin America  2020
# 248   142                           Asia  2015
# 256   142                           Asia  2020
# 368   150                         Europe  2015
# 376   150                         Europe  2020
# 456     9                        Oceania  2015
# 459     9                        Oceania  2019
# 467     9                        Oceania  2020
#
#                                                Series      Value
# 37   Asylum seekers, including pending cases (number)  1044031.0
# 45   Asylum seekers, including pending cases (number)   617584.0
# ...

# %% [markdown]
# # Asylum seekers, including pending cases by Continent Exploration

# %%
continents = ['Africa', 'Americas', 'Asia', 'Australia and New Zealand', 'Oceania', 'Europe']

continents_df2 = df_reg_filt_asyseek[df_reg_filt_asyseek['Region'].isin(continents)]
continents_df2.head()
# Out:
#      Code  Region  Year                                            Series  \
# 37      2  Africa  2015  Asylum seekers, including pending cases (number)
# 45      2  Africa  2020  Asylum seekers, including pending cases (number)
# 248   142    Asia  2015  Asylum seekers, including pending cases (number)
# 256   142    Asia  2020  Asylum seekers, including pending cases (number)
# 368   150  Europe  2015  Asylum seekers, including pending cases (number)
#
#          Value
# 37   1044031.0
# 45    617584.0
# 248   320437.0
# 256   624623.0
# 368   678737.0

# %%
plot_bar1(
    df=continents_df2,
    x='Year', y='Value',
    xlabel='Year', ylabel='Asylum seekers, including pending cases',
)
# Out:
# <function __main__.plot_bar1(df, x, y, hue=True, xlabel=None, ylabel=None, title=None)>

# %% [markdown]
# Filter Other's of concern to UNHCR (number)

# %%
others = ['Other of concern to UNHCR (number)']

df_reg_filt_others = df_reg_filt[df_reg_filt['Series'].isin(others)]
df_reg_filt_others
# Out:
#      Code                         Region  Year  \
# 38      2                         Africa  2015
# 46      2                         Africa  2020
# 153    21               Northern America  2019
# 173   419  Latin America & the Caribbean  2015
# 177   419  Latin America & the Caribbean  2019
# 201   420                  Latin America  2020
# 249   142                           Asia  2015
# 257   142                           Asia  2020
# 369   150                         Europe  2015
# 377   150                         Europe  2020
# 460     9                        Oceania  2019
#
#                                  Series       Value
# 38   Other of concern to UNHCR (number)  11530138.0
# 46   Other of concern to UNHCR (number)  24919267.0
# 153  Other of concern to UNHCR (number)      3790.0
# 173  Other of concern to UNHCR (number)   6697290.0
# 177  Other of concern to UNHCR (number)  12450136.0
# 201  Other of concern to UNHCR (number)  12526860.0
# ...

# %% [markdown]
# # Other of concern to UNHCR by Continent Exploration

# %%
continents = ['Africa', 'Americas', 'Asia', 'Australia and New Zealand', 'Oceania', 'Europe']

continents_df3 = df_reg_filt_others[df_reg_filt_others['Region'].isin(continents)]
continents_df3.head()
# Out:
#      Code  Region  Year                              Series       Value
# 38      2  Africa  2015  Other of concern to UNHCR (number)  11530138.0
# 46      2  Africa  2020  Other of concern to UNHCR (number)  24919267.0
# 249   142    Asia  2015  Other of concern to UNHCR (number)  19921907.0
# 257   142    Asia  2020  Other of concern to UNHCR (number)  18096139.0
# 369   150  Europe  2015  Other of concern to UNHCR (number)   2368815.0

# %%
plot_bar1(
    df=continents_df3,
    x='Year', y='Value',
    xlabel='Year', ylabel='Other of concern to UNHCR',
)
# Out:
# <function __main__.plot_bar1(df, x, y, hue=True, xlabel=None, ylabel=None, title=None)>

# %% [markdown]
# Filter Total population of concern to UNHCR (number)

# %%
tot_pop = ['Total population of concern to UNHCR (number)']

df_reg_filt_totpop = df_reg_filt[df_reg_filt['Series'].isin(tot_pop)]
df_reg_filt_totpop
# Out:
#      Code                         Region  Year  \
# 39      2                         Africa  2015
# 47      2                         Africa  2020
# 150    21               Northern America  2015
# 154    21               Northern America  2019
# 174   419  Latin America & the Caribbean  2015
# 178   419  Latin America & the Caribbean  2019
# 202   420                  Latin America  2020
# 250   142                           Asia  2015
# 258   142                           Asia  2020
# 370   150                         Europe  2015
# 378   150                         Europe  2020
# 457     9                        Oceania  2015
# 461     9                        Oceania  2019
# 468     9                        Oceania  2020
#
#                                             Series       Value
# 39   Total population of concern to UNHCR (number)  17067308.0
# 47   Total population of concern to UNHCR (number)  32536151.0
# 150  Total population of concern to UNHCR (number)    655374.0
# ...

# %% [markdown]
# # Total population of concern to UNHCR by Continent Exploration

# %%
continents = ['Africa', 'Americas', 'Asia', 'Australia and New Zealand', 'Oceania', 'Europe']

continents_df4 = df_reg_filt_totpop[df_reg_filt_totpop['Region'].isin(continents)]
continents_df4.head()
# Out:
#      Code  Region  Year                                         Series  \
# 39      2  Africa  2015  Total population of concern to UNHCR (number)
# 47      2  Africa  2020  Total population of concern to UNHCR (number)
# 250   142    Asia  2015  Total population of concern to UNHCR (number)
# 258   142    Asia  2020  Total population of concern to UNHCR (number)
# 370   150  Europe  2015  Total population of concern to UNHCR (number)
#
#           Value
# 39   17067308.0
# 47   32536151.0
# 250  28420724.0
# 258  28625515.0
# 370   4673766.0

# %%
plot_bar1(
    df=continents_df4,
    x='Year', y='Value',
    xlabel='Year', ylabel='Total population of concern to UNHCR',
)
# Out:
# <function __main__.plot_bar1(df, x, y, hue=True, xlabel=None, ylabel=None, title=None)>
