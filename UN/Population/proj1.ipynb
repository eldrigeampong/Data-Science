# %% [markdown]
# # Population, surface area and density

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings

# %% [markdown]
# # Options and Settings

# %%
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.autolayout'] = True
plt.rcParams['figure.figsize'] = [12, 9]
plt.rcParams['font.size'] = 12
path = os.getcwd()                                         # get current working directory
warnings.simplefilter('ignore')

# %% [markdown]
# # Import Data

# %%
filepath = os.path.join('datasets', 'Population, Surface Area and Density.csv')
df = pd.read_csv(filepath)

# %% [markdown]
# # Head and Tail

# %%
df
# Out:
#       Region/Country/Area                     Unnamed: 1  Year  \
# 0                       1  Total, all countries or areas  2010
# 1                       1  Total, all countries or areas  2010
# 2                       1  Total, all countries or areas  2010
# 3                       1  Total, all countries or areas  2010
# 4                       1  Total, all countries or areas  2010
# ...                   ...                            ...   ...
# 7255                  716                       Zimbabwe  2021
# 7256                  716                       Zimbabwe  2021
# 7257                  716                       Zimbabwe  2021
# 7258                  716                       Zimbabwe  2021
# 7259                  716                       Zimbabwe  2021
#
#                                                  Series    Value  \
# 0              Population mid-year estimates (millions)  6956.82
# 1     Population mid-year estimates for males (milli...  3507.70
# ...

# %%
df.shape
# Out:
# (7260, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7260 entries, 0 to 7259
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Region/Country/Area  7260 non-null   int64
#  1   Unnamed: 1           7260 non-null   object
#  2   Year                 7260 non-null   int64
#  3   Series               7260 non-null   object
#  4   Value                7260 non-null   float64
#  5   Footnotes            2282 non-null   object
#  6   Source               7260 non-null   object
#  7   Unnamed: 7           114 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 453.9+ KB

# %%
df.rename(
    columns={
        'Region/Country/Area': 'Code', 
        'Unnamed: 1': 'Region/Country/Area'}, inplace=True)

df.head()
# Out:
#    Code            Region/Country/Area  Year  \
# 0     1  Total, all countries or areas  2010
# 1     1  Total, all countries or areas  2010
# 2     1  Total, all countries or areas  2010
# 3     1  Total, all countries or areas  2010
# 4     1  Total, all countries or areas  2010
#
#                                               Series    Value Footnotes  \
# 0           Population mid-year estimates (millions)  6956.82       NaN
# 1  Population mid-year estimates for males (milli...  3507.70       NaN
# 2  Population mid-year estimates for females (mil...  3449.12       NaN
# 3                  Sex ratio (males per 100 females)   101.70       NaN
# 4     Population aged 0 to 14 years old (percentage)    27.00       NaN
#
#                                               Source Unnamed: 7
# 0  United Nations Population Division, New York, ...        NaN
# 1  United Nations Population Division, New York, ...        NaN
# 2  United Nations Population Division, New York, ...        NaN
# ...

# %%
df1 = df[['Code', 'Region/Country/Area', 'Year', 'Series', 'Value']]
df1
# Out:
#       Code            Region/Country/Area  Year  \
# 0        1  Total, all countries or areas  2010
# 1        1  Total, all countries or areas  2010
# 2        1  Total, all countries or areas  2010
# 3        1  Total, all countries or areas  2010
# 4        1  Total, all countries or areas  2010
# ...    ...                            ...   ...
# 7255   716                       Zimbabwe  2021
# 7256   716                       Zimbabwe  2021
# 7257   716                       Zimbabwe  2021
# 7258   716                       Zimbabwe  2021
# 7259   716                       Zimbabwe  2021
#
#                                                  Series    Value
# 0              Population mid-year estimates (millions)  6956.82
# 1     Population mid-year estimates for males (milli...  3507.70
# 2     Population mid-year estimates for females (mil...  3449.12
# 3                     Sex ratio (males per 100 females)   101.70
# ...

# %%
df1.shape
# Out:
# (7260, 5)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7260 entries, 0 to 7259
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Code                 7260 non-null   int64
#  1   Region/Country/Area  7260 non-null   object
#  2   Year                 7260 non-null   int64
#  3   Series               7260 non-null   object
#  4   Value                7260 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 283.7+ KB

# %%
df1.describe(include='object')
# Out:
#                   Region/Country/Area  \
# count                            7260
# unique                            266
# top     Total, all countries or areas
# freq                               30
#
#                                           Series
# count                                       7260
# unique                                         8
# top     Population mid-year estimates (millions)
# freq                                        1058

# %%
df1['Region/Country/Area'].value_counts()
# Out:
# Total, all countries or areas    30
# Guinea                           30
# Maldives                         30
# Mali                             30
# Malta                            30
#                                  ..
# American Samoa                   10
# Dominica                         10
# Saint Martin (French part)        6
# Bonaire, St. Eustatius & Saba     6
# Saint Barth�lemy                  6
# Name: Region/Country/Area, Length: 266, dtype: int64

# %%
df1['Series'].value_counts()
# Out:
# Population mid-year estimates (millions)                1058
# Population density                                      1058
# Population mid-year estimates for males (millions)       925
# Population mid-year estimates for females (millions)     925
# Sex ratio (males per 100 females)                        925
# Population aged 0 to 14 years old (percentage)           925
# Population aged 60+ years old (percentage)               925
# Surface area (thousand km2)                              519
# Name: Series, dtype: int64

# %%
df1['Code'].value_counts()
# Out:
# 1      30
# 324    30
# 462    30
# 466    30
# 470    30
#        ..
# 16     10
# 212    10
# 663     6
# 535     6
# 652     6
# Name: Code, Length: 266, dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
df1['Region/Country/Area'].replace(
    {'C�te d�Ivoire': "Côte d'Ivoire", 
    'Cura�ao': 'Curaçao',
    'R�union': 'Réunion',
    'Saint Barth�lemy': 'Saint Barthélemy'}, inplace=True
)

df1['Region/Country/Area'].unique()
# Out:
# array(['Total, all countries or areas', 'Africa', 'Northern Africa',
#        'Sub-Saharan Africa', 'Eastern Africa', 'Middle Africa',
#        'Southern Africa', 'Western Africa', 'Americas',
#        'Northern America', 'Latin America & the Caribbean', 'Caribbean',
#        'Central America', 'South America', 'Asia', 'Central Asia',
#        'Eastern Asia', 'South-central Asia', 'South-eastern Asia',
#        'Southern Asia', 'Western Asia', 'Europe', 'Eastern Europe',
#        'Northern Europe', 'Southern Europe', 'Western Europe', 'Oceania',
#        'Australia and New Zealand', 'Melanesia', 'Micronesia',
#        'Polynesia', 'Afghanistan', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
# ...

# %%
df1['Year'].value_counts()
# Out:
# 2015    1951
# 2019    1893
# 2010    1692
# 2021    1692
# 2017      32
# Name: Year, dtype: int64

# %%
df1['Value'].describe()
# Out:
# count      7260.000000
# mean        276.482474
# std        2762.778277
# min           0.000000
# 25%           5.295000
# 50%          22.800000
# 75%          96.000000
# max      136162.000000
# Name: Value, dtype: float64

# %%
sns.kdeplot(data=df1, x='Value')
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Density'>

# %% [markdown]
# # Missing Values Exploration

# %%
df1.isna().sum()
# Out:
# Code                   0
# Region/Country/Area    0
# Year                   0
# Series                 0
# Value                  0
# dtype: int64

# %% [markdown]
# # Grouping and Aggregation

# %%
df1_grpd = df1.groupby(['Region/Country/Area', 'Series'])
df1_grpd.head()
# Out:
#       Code            Region/Country/Area  Year  \
# 0        1  Total, all countries or areas  2010
# 1        1  Total, all countries or areas  2010
# 2        1  Total, all countries or areas  2010
# 3        1  Total, all countries or areas  2010
# 4        1  Total, all countries or areas  2010
# ...    ...                            ...   ...
# 7255   716                       Zimbabwe  2021
# 7256   716                       Zimbabwe  2021
# 7257   716                       Zimbabwe  2021
# 7258   716                       Zimbabwe  2021
# 7259   716                       Zimbabwe  2021
#
#                                                  Series    Value
# 0              Population mid-year estimates (millions)  6956.82
# 1     Population mid-year estimates for males (milli...  3507.70
# 2     Population mid-year estimates for females (mil...  3449.12
# 3                     Sex ratio (males per 100 females)   101.70
# ...

# %% [markdown]
# # Data Visualization

# %%
from matplotlib.ticker import FuncFormatter

# y-axis formatter functions
def billion(x, pos):
    return '%1.2fB' % (x * 1e-3)

format_bill = FuncFormatter(billion)


def million(x, pos):
    return '%1.1fM' % (x * 1)

format_mill = FuncFormatter(million)


def thousand(x, pos):
    return '%1.2fK' % (x * 1e-3)

format_tsd = FuncFormatter(thousand)


# line chart helper function
def plot_line(data, x, y, hue=None, size=None, style=None, title=None, xlabel=None, ylabel=None, formatter=None):
    # create figure and axis
    fig, ax = plt.subplots()
    fig.autofmt_xdate()

    # plot line chart
    sns.lineplot(
        data=data, 
        x=x, y=y, 
        hue=hue, size=size, style=style,
        ax=ax)

    # label plot axes
    ax.set(title=title, xlabel=xlabel, ylabel=ylabel)

    # set y-axis formatter
    ax.yaxis.set_major_formatter(formatter=formatter)

    # despine axes
    sns.despine(bottom=True, left=True)

    return plot_line


# pie chart helper function
def plot_pie(data, x, labels, explode: list, startangle: int, shadow: bool, title=None, xlabel=None, ylabel=None):
    # create figure and axis
    fig1, ax1 = plt.subplots()

    # plot pie chart
    ax1.pie(data=data, x=x, explode=explode, labels=labels, autopct='%1.1f%%', shadow=shadow, startangle=startangle)

    # label plot axes
    ax1.set(title=title, xlabel=xlabel, ylabel=ylabel)

    return plot_pie


# bar plot helper function
def plot_bar(data, x, y, ci=None, hue=None, color=None, title=None, xlabel=None, ylabel=None, formatter=None):
    # create figure and axis
    fig2, ax2 = plt.subplots()
    fig2.autofmt_xdate()

    # plot bar charts
    sns.barplot(
        data=data,
        x=x, y=y, 
        ci=ci, hue=hue, color=color,
        ax=ax2)

    # label plot axes
    ax2.set(title=title, xlabel=xlabel, ylabel=ylabel)

    # y-axis formatter
    ax2.yaxis.set_major_formatter(formatter=formatter)

    # despine plot axes
    sns.despine(bottom=True, left=True)

    return plot_bar

# %% [markdown]
# # Population mid-year estimates exploration

# %%
plot_line(
    data=df1_grpd.get_group(('India', 'Population mid-year estimates (millions)')),
    x='Year', y='Value',
    hue='Series',
    title='India', xlabel='Year', ylabel='Value',
    formatter=format_bill
)
# Out:
# <function __main__.plot_line(data, x, y, hue=None, size=None, style=None, title=None, xlabel=None, ylabel=None, formatter=None)>

# %%
plot_line(
    data=df1_grpd.get_group(('Ghana', 'Population mid-year estimates (millions)')),
    x='Year', y='Value',
    hue='Series',
    title='Ghana', xlabel='Year', ylabel='Value',
    formatter=format_mill
)
# Out:
# <function __main__.plot_line(data, x, y, hue=None, size=None, style=None, title=None, xlabel=None, ylabel=None, formatter=None)>

# %% [markdown]
# # Population mid-year estimates for males exploration

# %%
plot_line(
    data=df1_grpd.get_group(('India', 'Population mid-year estimates for males (millions)')),
    x='Year', y='Value',
    hue='Series',
    title='India', xlabel='Year', ylabel='Value',
    formatter=format_bill
)
# Out:
# <function __main__.plot_line(data, x, y, hue=None, size=None, style=None, title=None, xlabel=None, ylabel=None, formatter=None)>

# %%
plot_line(
    data=df1_grpd.get_group(('Ghana', 'Population mid-year estimates for males (millions)')),
    x='Year', y='Value',
    hue='Series',
    title='Ghana', xlabel='Year', ylabel='Value',
    formatter=format_mill
)
# Out:
# <function __main__.plot_line(data, x, y, hue=None, size=None, style=None, title=None, xlabel=None, ylabel=None, formatter=None)>

# %% [markdown]
# # Population mid-year estimates for females exploration

# %%
plot_line(
    data=df1_grpd.get_group(('India', 'Population mid-year estimates for females (millions)')),
    x='Year', y='Value',
    hue='Series',
    title='India', xlabel='Year', ylabel='Value',
    formatter=format_bill
)
# Out:
# <function __main__.plot_line(data, x, y, hue=None, size=None, style=None, title=None, xlabel=None, ylabel=None, formatter=None)>

# %%
plot_line(
    data=df1_grpd.get_group(('Ghana', 'Population mid-year estimates for females (millions)')),
    x='Year', y='Value',
    hue='Series',
    title='Ghana', xlabel='Year', ylabel='Value',
    formatter=format_mill
)
# Out:
# <function __main__.plot_line(data, x, y, hue=None, size=None, style=None, title=None, xlabel=None, ylabel=None, formatter=None)>

# %% [markdown]
# # Sex ratio

# %%
plot_pie(
    data=df1_grpd.get_group(('Germany', 'Sex ratio (males per 100 females)')),
    x='Value', labels='Year', 
    explode=[0, 0, 0, 0], startangle=90, shadow=True,
    title='Germany', xlabel='Sex ratio (males per 100 females)'
)
# Out:
# <function __main__.plot_pie(data, x, labels, explode: list, startangle: int, shadow: bool, title=None, xlabel=None, ylabel=None)>

# %% [markdown]
# # Population aged 0 to 14 years old

# %%
plot_pie(
    data=df1_grpd.get_group(('China', 'Population aged 0 to 14 years old (percentage)')),
    x='Value', labels='Year', 
    explode=[0, 0, 0, 0], startangle=90, shadow=True,
    title='China', xlabel='Population aged 0 to 14 years old (percentage)'
)
# Out:
# <function __main__.plot_pie(data, x, labels, explode: list, startangle: int, shadow: bool, title=None, xlabel=None, ylabel=None)>

# %% [markdown]
# # Population aged 60+ years old

# %%
plot_pie(
    data=df1_grpd.get_group(('India', 'Population aged 60+ years old (percentage)')),
    x='Value', labels='Year', 
    explode=[0, 0, 0, 0], startangle=90, shadow=True,
    title='India', xlabel='Population aged 60+ years old (percentage)'
)
# Out:
# <function __main__.plot_pie(data, x, labels, explode: list, startangle: int, shadow: bool, title=None, xlabel=None, ylabel=None)>

# %% [markdown]
# # Population density

# %%
plot_pie(
    data=df1_grpd.get_group(('Nigeria', 'Population density')),
    x='Value', labels='Year', 
    explode=[0, 0, 0, 0], startangle=90, shadow=True,
    title='Nigeria', xlabel='Population density'
)
# Out:
# <function __main__.plot_pie(data, x, labels, explode: list, startangle: int, shadow: bool, title=None, xlabel=None, ylabel=None)>

# %% [markdown]
# # Surface area

# %%
plot_bar(
    data=df1_grpd.get_group(('Ghana', 'Surface area (thousand km2)')),
    x='Year', y='Value',
    title='Ghana', xlabel='Year', ylabel='Surface area (thousand km2)',
    formatter=format_tsd
)
# Out:
# <function __main__.plot_bar(data, x, y, ci=None, hue=None, color=None, title=None, xlabel=None, ylabel=None, formatter=None)>
