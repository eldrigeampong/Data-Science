# %% [markdown]
# # Population, surface area and density

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings

# %% [markdown]
# # Options and Settings

# %%
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.autolayout'] = True
plt.rcParams['figure.figsize'] = [12, 9]
plt.rcParams['font.size'] = 12
path = os.getcwd()                                         # get current working directory
warnings.simplefilter('ignore')

# %% [markdown]
# # Import Data

# %%
filepath = os.path.join('datasets', 'Population, Surface Area and Density.csv')
df = pd.read_csv(filepath)

# %% [markdown]
# # Head and Tail

# %%
df
# Out:
#       Region/Country/Area                     Unnamed: 1  Year  \
# 0                       1  Total, all countries or areas  2010
# 1                       1  Total, all countries or areas  2010
# 2                       1  Total, all countries or areas  2010
# 3                       1  Total, all countries or areas  2010
# 4                       1  Total, all countries or areas  2010
# ...                   ...                            ...   ...
# 7255                  716                       Zimbabwe  2021
# 7256                  716                       Zimbabwe  2021
# 7257                  716                       Zimbabwe  2021
# 7258                  716                       Zimbabwe  2021
# 7259                  716                       Zimbabwe  2021
#
#                                                  Series    Value  \
# 0              Population mid-year estimates (millions)  6956.82
# 1     Population mid-year estimates for males (milli...  3507.70
# ...

# %%
df.shape
# Out:
# (7260, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7260 entries, 0 to 7259
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Region/Country/Area  7260 non-null   int64
#  1   Unnamed: 1           7260 non-null   object
#  2   Year                 7260 non-null   int64
#  3   Series               7260 non-null   object
#  4   Value                7260 non-null   float64
#  5   Footnotes            2282 non-null   object
#  6   Source               7260 non-null   object
#  7   Unnamed: 7           114 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 453.9+ KB

# %%
df.rename(columns={'Region/Country/Area': 'Code', 
                   'Unnamed: 1': 'Region/Country/Area',
                   }, inplace=True)

df
# Out:
#       Code            Region/Country/Area  Year  \
# 0        1  Total, all countries or areas  2010
# 1        1  Total, all countries or areas  2010
# 2        1  Total, all countries or areas  2010
# 3        1  Total, all countries or areas  2010
# 4        1  Total, all countries or areas  2010
# ...    ...                            ...   ...
# 7255   716                       Zimbabwe  2021
# 7256   716                       Zimbabwe  2021
# 7257   716                       Zimbabwe  2021
# 7258   716                       Zimbabwe  2021
# 7259   716                       Zimbabwe  2021
#
#                                                  Series    Value  \
# 0              Population mid-year estimates (millions)  6956.82
# 1     Population mid-year estimates for males (milli...  3507.70
# 2     Population mid-year estimates for females (mil...  3449.12
# 3                     Sex ratio (males per 100 females)   101.70
# ...

# %%
df1 = df[['Code', 'Region/Country/Area', 'Year', 'Series', 'Value']]
df1
# Out:
#       Code            Region/Country/Area  Year  \
# 0        1  Total, all countries or areas  2010
# 1        1  Total, all countries or areas  2010
# 2        1  Total, all countries or areas  2010
# 3        1  Total, all countries or areas  2010
# 4        1  Total, all countries or areas  2010
# ...    ...                            ...   ...
# 7255   716                       Zimbabwe  2021
# 7256   716                       Zimbabwe  2021
# 7257   716                       Zimbabwe  2021
# 7258   716                       Zimbabwe  2021
# 7259   716                       Zimbabwe  2021
#
#                                                  Series    Value
# 0              Population mid-year estimates (millions)  6956.82
# 1     Population mid-year estimates for males (milli...  3507.70
# 2     Population mid-year estimates for females (mil...  3449.12
# 3                     Sex ratio (males per 100 females)   101.70
# ...

# %%
df1.shape
# Out:
# (7260, 5)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7260 entries, 0 to 7259
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Code                 7260 non-null   int64
#  1   Region/Country/Area  7260 non-null   object
#  2   Year                 7260 non-null   int64
#  3   Series               7260 non-null   object
#  4   Value                7260 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 283.7+ KB

# %%
df1.describe(include='object')
# Out:
#                   Region/Country/Area  \
# count                            7260
# unique                            266
# top     Total, all countries or areas
# freq                               30
#
#                                           Series
# count                                       7260
# unique                                         8
# top     Population mid-year estimates (millions)
# freq                                        1058

# %%
df1['Region/Country/Area'].value_counts()
# Out:
# Total, all countries or areas    30
# Guinea                           30
# Maldives                         30
# Mali                             30
# Malta                            30
#                                  ..
# American Samoa                   10
# Dominica                         10
# Saint Martin (French part)        6
# Bonaire, St. Eustatius & Saba     6
# Saint Barth�lemy                  6
# Name: Region/Country/Area, Length: 266, dtype: int64

# %%
df1['Series'].value_counts()
# Out:
# Population mid-year estimates (millions)                1058
# Population density                                      1058
# Population mid-year estimates for males (millions)       925
# Population mid-year estimates for females (millions)     925
# Sex ratio (males per 100 females)                        925
# Population aged 0 to 14 years old (percentage)           925
# Population aged 60+ years old (percentage)               925
# Surface area (thousand km2)                              519
# Name: Series, dtype: int64

# %%
df1['Code'].value_counts()
# Out:
# 1      30
# 324    30
# 462    30
# 466    30
# 470    30
#        ..
# 16     10
# 212    10
# 663     6
# 535     6
# 652     6
# Name: Code, Length: 266, dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
df1['Region/Country/Area'].replace(
    {'C�te d�Ivoire': "Côte d'Ivoire", 
    'Cura�ao': 'Curaçao',
    'R�union': 'Réunion',
    'Saint Barth�lemy': 'Saint Barthélemy'}, inplace=True
)

df1['Region/Country/Area'].unique()
# Out:
# array(['Total, all countries or areas', 'Africa', 'Northern Africa',
#        'Sub-Saharan Africa', 'Eastern Africa', 'Middle Africa',
#        'Southern Africa', 'Western Africa', 'Americas',
#        'Northern America', 'Latin America & the Caribbean', 'Caribbean',
#        'Central America', 'South America', 'Asia', 'Central Asia',
#        'Eastern Asia', 'South-central Asia', 'South-eastern Asia',
#        'Southern Asia', 'Western Asia', 'Europe', 'Eastern Europe',
#        'Northern Europe', 'Southern Europe', 'Western Europe', 'Oceania',
#        'Australia and New Zealand', 'Melanesia', 'Micronesia',
#        'Polynesia', 'Afghanistan', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
# ...

# %%
df1['Year'].value_counts()
# Out:
# 2015    1951
# 2019    1893
# 2010    1692
# 2021    1692
# 2017      32
# Name: Year, dtype: int64

# %%
df1['Value'].describe()
# Out:
# count      7260.000000
# mean        276.482474
# std        2762.778277
# min           0.000000
# 25%           5.295000
# 50%          22.800000
# 75%          96.000000
# max      136162.000000
# Name: Value, dtype: float64

# %% [markdown]
# # Missing Values Exploration

# %%
df1.isna().sum()
# Out:
# Code                   0
# Region/Country/Area    0
# Year                   0
# Series                 0
# Value                  0
# dtype: int64

# %% [markdown]
# # Grouping and Aggregation

# %% [markdown]
# Filter By Region

# %%
regions = ['Africa', 'Northern Africa', 'Sub-Saharan Africa', 'Eastern Africa', 'Middle Africa', 'Southern Africa', 'Western Africa', 
           'Americas', 'Northern America', 'Latin America & the Caribbean', 'Caribbean', 'Central America', 'South America', 'Asia', 
           'Central Asia', 'Eastern Asia', 'South-central Asia', 'South-eastern Asia', 'Southern Asia', 'Western Asia', 'Europe', 
           'Eastern Europe', 'Northern Europe', 'Southern Europe', 'Western Europe', 'Oceania', 'Australia and New Zealand', 'Melanesia']

df_reg_filt = df1[df1['Region/Country/Area'].isin(regions)]
df_reg_filt
# Out:
#      Code Region/Country/Area  Year  \
# 30      2              Africa  2010
# 31      2              Africa  2010
# 32      2              Africa  2010
# 33      2              Africa  2010
# 34      2              Africa  2010
# ..    ...                 ...   ...
# 865    54           Melanesia  2021
# 866    54           Melanesia  2021
# 867    54           Melanesia  2021
# 868    54           Melanesia  2021
# 869    54           Melanesia  2021
#
#                                                 Series    Value
# 30            Population mid-year estimates (millions)  1039.30
# 31   Population mid-year estimates for males (milli...   518.25
# 32   Population mid-year estimates for females (mil...   521.05
# 33                   Sex ratio (males per 100 females)    99.50
# 34      Population aged 0 to 14 years old (percentage)    41.50
# ..                                                 ...      ...
# 865  Population mid-year estimates for females (mil...     5.55
# ...

# %%
df_reg_filt.rename(columns={
    'Region/Country/Area': 'Region'
}, inplace=True)

df_reg_filt
# Out:
#      Code     Region  Year                                             Series  \
# 30      2     Africa  2010           Population mid-year estimates (millions)
# 31      2     Africa  2010  Population mid-year estimates for males (milli...
# 32      2     Africa  2010  Population mid-year estimates for females (mil...
# 33      2     Africa  2010                  Sex ratio (males per 100 females)
# 34      2     Africa  2010     Population aged 0 to 14 years old (percentage)
# ..    ...        ...   ...                                                ...
# 865    54  Melanesia  2021  Population mid-year estimates for females (mil...
# 866    54  Melanesia  2021                  Sex ratio (males per 100 females)
# 867    54  Melanesia  2021     Population aged 0 to 14 years old (percentage)
# 868    54  Melanesia  2021         Population aged 60+ years old (percentage)
# 869    54  Melanesia  2021                                 Population density
#
#        Value
# 30   1039.30
# ...

# %% [markdown]
# Filter Population in Millions

# %%
millions = ['Population mid-year estimates (millions)',
            'Population mid-year estimates for males (millions)',
            'Population mid-year estimates for females (millions)']

df_reg_filt_mill = df_reg_filt[df_reg_filt['Series'].isin(millions)]
df_reg_filt_mill
# Out:
#      Code     Region  Year                                             Series  \
# 30      2     Africa  2010           Population mid-year estimates (millions)
# 31      2     Africa  2010  Population mid-year estimates for males (milli...
# 32      2     Africa  2010  Population mid-year estimates for females (mil...
# 37      2     Africa  2015           Population mid-year estimates (millions)
# 38      2     Africa  2015  Population mid-year estimates for males (milli...
# ..    ...        ...   ...                                                ...
# 856    54  Melanesia  2019  Population mid-year estimates for males (milli...
# 857    54  Melanesia  2019  Population mid-year estimates for females (mil...
# 863    54  Melanesia  2021           Population mid-year estimates (millions)
# 864    54  Melanesia  2021  Population mid-year estimates for males (milli...
# 865    54  Melanesia  2021  Population mid-year estimates for females (mil...
#
#        Value
# 30   1039.30
# ...

# %%
df_reg_filt_mill['Value'] = df_reg_filt_mill['Value'] * 1e6                     # multiple values series by 10^6
df_reg_filt_mill
# Out:
#      Code     Region  Year                                             Series  \
# 30      2     Africa  2010           Population mid-year estimates (millions)
# 31      2     Africa  2010  Population mid-year estimates for males (milli...
# 32      2     Africa  2010  Population mid-year estimates for females (mil...
# 37      2     Africa  2015           Population mid-year estimates (millions)
# 38      2     Africa  2015  Population mid-year estimates for males (milli...
# ..    ...        ...   ...                                                ...
# 856    54  Melanesia  2019  Population mid-year estimates for males (milli...
# 857    54  Melanesia  2019  Population mid-year estimates for females (mil...
# 863    54  Melanesia  2021           Population mid-year estimates (millions)
# 864    54  Melanesia  2021  Population mid-year estimates for males (milli...
# 865    54  Melanesia  2021  Population mid-year estimates for females (mil...
#
#             Value
# ...

# %% [markdown]
# Aggregated Population mid-year estimates in Millions of US Dollars

# %%
df_reg_gpd_agg = df_reg_filt_mill.groupby('Region').agg(
    min_pop = pd.NamedAgg('Value', np.min),
    mean_pop = pd.NamedAgg('Value', np.mean),
    max_pop = pd.NamedAgg('Value', np.max),
    total_pop = pd.NamedAgg('Value', np.sum)
)

df_reg_gpd_agg
# Out:
#                                     min_pop      mean_pop       max_pop  \
# Region
# Africa                         5.182500e+08  8.172150e+08  1.373490e+09
# Americas                       4.610300e+08  6.601975e+08  1.030850e+09
# Asia                           2.054280e+09  2.987351e+09  4.679660e+09
# Australia and New Zealand      1.323000e+07  1.928417e+07  3.065000e+07
# Caribbean                      2.039000e+07  2.848917e+07  4.376000e+07
# Central America                7.724000e+07  1.143075e+08  1.817200e+08
# Central Asia                   3.102000e+07  4.626500e+07  7.543000e+07
# Eastern Africa                 1.679700e+08  2.699908e+08  4.570500e+08
# Eastern Asia                   7.852100e+08  1.100918e+09  1.682850e+09
# Eastern Europe                 1.375900e+08  1.958650e+08  2.948700e+08
# Europe                         3.546200e+08  4.957333e+08  7.477500e+08
# Latin America & the Caribbean  2.914200e+08  4.205250e+08  6.597400e+08
# ...

# %% [markdown]
# Filter Top and Bottom 10 Regions Population mid-year estimates in Millions of Dollars

# %%
top_10_pop_reg = df_reg_gpd_agg['total_pop'].sort_values(ascending=False).head(10)
bottom_10_pop_reg = df_reg_gpd_agg['total_pop'].sort_values(ascending=True).head(10)

print(top_10_pop_reg)
print('\n')
print(bottom_10_pop_reg)
# Out:
# Region
# Asia                             3.584821e+10
# South-central Asia               1.540162e+10
# Southern Asia                    1.475183e+10
# Eastern Asia                     1.321101e+10
# Africa                           9.806580e+09
# Sub-Saharan Africa               7.968160e+09
# Americas                         7.922370e+09
# Europe                           5.948800e+09
# South-eastern Asia               5.136760e+09
# Latin America & the Caribbean    5.046300e+09
# Name: total_pop, dtype: float64
#
#
# Region
# Melanesia                    8.312000e+07
# Australia and New Zealand    2.314100e+08
# Oceania                      3.241500e+08
# Caribbean                    3.418700e+08
# Southern Africa              5.127200e+08
# Central Asia                 5.551800e+08
# Northern Europe              8.328000e+08
# Southern Europe              1.220940e+09
# Middle Africa                1.290220e+09
# Central America              1.371690e+09
# ...

# %% [markdown]
# # Data Visualization By Region

# %%
# helper function for formatting plot y-axis
from matplotlib.ticker import FuncFormatter

def billion(x, pos):
    'The two args are the value and tick position'
    return '%1.1fBn' % (x * 1e-9)

formatter = FuncFormatter(billion)


# helper function to plot horizontal bar chart 
def plot_hbar(y, width, color=True, align='center', xlabel=None, ylabel=None, title=None):

    # Initialize the matplotlib figure
    fig, ax = plt.subplots()

    # plot bar chart
    ax.barh(
        y=y, width=width,
        color='b',
        align=align
    )

    # Add informative axis label
    ax.set(xlabel=xlabel, ylabel=ylabel, title=title)

    # labels read top-to-bottom
    ax.invert_yaxis()  

    # set axis formatter
    ax.xaxis.set_major_formatter(formatter)

    # despine x-axis and y-axis
    sns.despine(left=True, bottom=True)

# %% [markdown]
# Top 10 Regions

# %%
plot_hbar(y=top_10_pop_reg.keys(), width=top_10_pop_reg.values, 
          xlabel='Population mid-year estimates', ylabel='Region', title='Population mid-year estimates by Region')

# %% [markdown]
# Bottom 10 Regions

# %%
plot_hbar(y=bottom_10_pop_reg.keys(), width=bottom_10_pop_reg.values, 
          xlabel='Population mid-year estimates', ylabel='Region', title='Population mid-year estimates by Region')

# %% [markdown]
# Filter Sex ratio

# %%
sex_ratio = ['Sex ratio (males per 100 females)']

df_reg_filt_sr = df_reg_filt[df_reg_filt['Series'].isin(sex_ratio)]
df_reg_filt_sr
# Out:
#      Code                     Region  Year                             Series  \
# 33      2                     Africa  2010  Sex ratio (males per 100 females)
# 40      2                     Africa  2015  Sex ratio (males per 100 females)
# 48      2                     Africa  2019  Sex ratio (males per 100 females)
# 56      2                     Africa  2021  Sex ratio (males per 100 females)
# 63     15            Northern Africa  2010  Sex ratio (males per 100 females)
# ..    ...                        ...   ...                                ...
# 836    53  Australia and New Zealand  2021  Sex ratio (males per 100 females)
# 843    54                  Melanesia  2010  Sex ratio (males per 100 females)
# 850    54                  Melanesia  2015  Sex ratio (males per 100 females)
# 858    54                  Melanesia  2019  Sex ratio (males per 100 females)
# 866    54                  Melanesia  2021  Sex ratio (males per 100 females)
#
#      Value
# 33    99.5
# ...

# %% [markdown]
# # Sex ratio by Region Exploration

# %% [markdown]
# Filter Africa, Americas, Asia, Australia and New Zealand, Oceania and Europe Continents

# %%
continents = ['Africa', 'Americas', 'Asia', 'Australia and New Zealand', 'Oceania', 'Europe']

continents_df = df_reg_filt_sr[df_reg_filt_sr['Region'].isin(continents)]
continents_df.head()
# Out:
#      Code    Region  Year                             Series  Value
# 33      2    Africa  2010  Sex ratio (males per 100 females)   99.5
# 40      2    Africa  2015  Sex ratio (males per 100 females)   99.7
# 48      2    Africa  2019  Sex ratio (males per 100 females)   99.8
# 56      2    Africa  2021  Sex ratio (males per 100 females)   99.9
# 243    19  Americas  2010  Sex ratio (males per 100 females)   97.3

# %%
# bar plot helper function
def plot_bar(df, x, y, hue, xlabel=None, ylabel=None, title=None):

    # set plot theme
    sns.set_theme(style='white', context='talk')

    # Initialize the matplotlib figure
    fig, ax = plt.subplots()
    fig.autofmt_xdate()

    # plot bar chart
    sns.barplot(
        x=x, y=y, 
        hue=hue, data=df, ci=None, 
        ax=ax
    )

    # despine axes
    sns.despine(left=True, bottom=True)

    # matplotlib axis label
    ax.set(xlabel=xlabel, ylabel=ylabel, title=title)

    return plot_bar

# %%
plot_bar(df=continents_df,
         x='Year', y='Value', 
         hue='Region', 
         xlabel='Year', ylabel='Sex ratio (males per 100 females)')
# Out:
# <function __main__.plot_bar(df, x, y, hue, xlabel=None, ylabel=None, title=None)>

# %% [markdown]
# Filter Population in Percentage

# %%
pop_pct = ['Population aged 0 to 14 years old (percentage)',
           'Population aged 60+ years old (percentage)']

df_reg_filt_pct = df_reg_filt[df_reg_filt['Series'].isin(pop_pct)]
df_reg_filt_pct
# Out:
#      Code     Region  Year                                          Series  \
# 34      2     Africa  2010  Population aged 0 to 14 years old (percentage)
# 35      2     Africa  2010      Population aged 60+ years old (percentage)
# 41      2     Africa  2015  Population aged 0 to 14 years old (percentage)
# 42      2     Africa  2015      Population aged 60+ years old (percentage)
# 49      2     Africa  2019  Population aged 0 to 14 years old (percentage)
# ..    ...        ...   ...                                             ...
# 852    54  Melanesia  2015      Population aged 60+ years old (percentage)
# 859    54  Melanesia  2019  Population aged 0 to 14 years old (percentage)
# 860    54  Melanesia  2019      Population aged 60+ years old (percentage)
# 867    54  Melanesia  2021  Population aged 0 to 14 years old (percentage)
# 868    54  Melanesia  2021      Population aged 60+ years old (percentage)
#
#      Value
# 34    41.5
# 35     5.1
# 41    41.1
# 42     5.3
# ...

# %% [markdown]
# # Population by Continent Exploration

# %%
continents = ['Africa', 'Americas', 'Asia', 'Australia and New Zealand', 'Oceania', 'Europe']

continents_df1 = df_reg_filt_pct[df_reg_filt_pct['Region'].isin(continents)]
continents_df1.head()
# Out:
#     Code  Region  Year                                          Series  Value
# 34     2  Africa  2010  Population aged 0 to 14 years old (percentage)   41.5
# 35     2  Africa  2010      Population aged 60+ years old (percentage)    5.1
# 41     2  Africa  2015  Population aged 0 to 14 years old (percentage)   41.1
# 42     2  Africa  2015      Population aged 60+ years old (percentage)    5.3
# 49     2  Africa  2019  Population aged 0 to 14 years old (percentage)   40.6

# %%
plot_bar(df=continents_df1,
         x='Year', y='Value', 
         hue='Region', 
         xlabel='Year', ylabel='Population (percentage)', title='Population by Continent')
# Out:
# <function __main__.plot_bar(df, x, y, hue, xlabel=None, ylabel=None, title=None)>

# %% [markdown]
# Filter Population Density

# %%
pop_dens = ['Population density']

df_reg_filt_popdens = df_reg_filt[df_reg_filt['Series'].isin(pop_dens)]
df_reg_filt_popdens
# Out:
#      Code                     Region  Year              Series  Value
# 36      2                     Africa  2010  Population density   35.1
# 43      2                     Africa  2015  Population density   39.9
# 51      2                     Africa  2019  Population density   44.1
# 59      2                     Africa  2021  Population density   46.3
# 66     15            Northern Africa  2010  Population density   26.1
# ..    ...                        ...   ...                 ...    ...
# 839    53  Australia and New Zealand  2021  Population density    3.9
# 846    54                  Melanesia  2010  Population density   17.3
# 853    54                  Melanesia  2015  Population density   19.1
# 861    54                  Melanesia  2019  Population density   20.6
# 869    54                  Melanesia  2021  Population density   21.4
#
# [112 rows x 5 columns]

# %% [markdown]
# # Population Density by Continent Exploration

# %%
continents = ['Africa', 'Americas', 'Asia', 'Australia and New Zealand', 'Oceania', 'Europe']

continents_df2 = df_reg_filt_popdens[df_reg_filt_popdens['Region'].isin(continents)]
continents_df2.head()
# Out:
#      Code    Region  Year              Series  Value
# 36      2    Africa  2010  Population density   35.1
# 43      2    Africa  2015  Population density   39.9
# 51      2    Africa  2019  Population density   44.1
# 59      2    Africa  2021  Population density   46.3
# 246    19  Americas  2010  Population density   24.1

# %%
plot_bar(df=continents_df2,
         x='Year', y='Value', 
         hue='Region', 
         xlabel='Year', ylabel='Population Density', title='Population Density by Continent')
# Out:
# <function __main__.plot_bar(df, x, y, hue, xlabel=None, ylabel=None, title=None)>

# %% [markdown]
# Filter Surface area in thousand km2

# %%
surf_area = ['Surface area (thousand km2)']

df_reg_filt_surfarea = df_reg_filt[df_reg_filt['Series'].isin(surf_area)]
df_reg_filt_surfarea.head()
# Out:
#      Code              Region  Year                       Series    Value
# 44      2              Africa  2015  Surface area (thousand km2)  30311.0
# 52      2              Africa  2019  Surface area (thousand km2)  29648.0
# 74     15     Northern Africa  2015  Surface area (thousand km2)   7880.0
# 82     15     Northern Africa  2019  Surface area (thousand km2)   7769.0
# 104   202  Sub-Saharan Africa  2015  Surface area (thousand km2)  22431.0

# %% [markdown]
# # Surface Area by Continent Exploration

# %%
continents = ['Africa', 'Americas', 'Asia', 'Australia and New Zealand', 'Oceania', 'Europe']

continents_df3 = df_reg_filt_surfarea[df_reg_filt_surfarea['Region'].isin(continents)]
continents_df3.head()
# Out:
#      Code    Region  Year                       Series    Value
# 44      2    Africa  2015  Surface area (thousand km2)  30311.0
# 52      2    Africa  2019  Surface area (thousand km2)  29648.0
# 254    19  Americas  2015  Surface area (thousand km2)  42322.0
# 262    19  Americas  2019  Surface area (thousand km2)  38791.0
# 434   142      Asia  2015  Surface area (thousand km2)  31915.0

# %%
plot_bar(df=continents_df3,
         x='Year', y='Value', 
         hue='Region', 
         xlabel='Year', ylabel='Surface area (thousand km2)', title='Surface Area by Continent')
# Out:
# <function __main__.plot_bar(df, x, y, hue, xlabel=None, ylabel=None, title=None)>
