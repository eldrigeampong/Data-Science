# %% [markdown]
# # Abstract Project

# %% [markdown]
# Source1: https://www.science.org/doi/abs/10.1126/science.aaa8415

# %% [markdown]
# Source2: https://en.wikipedia.org/wiki/List_of_time_periods#Human_time_periods

# %%
import os
import codecs
import spacy
from spacy import displacy

# %% [markdown]
# # Read Text Document

# %%
# get current working directory
cwd = os.getcwd()

abstract_filepath = os.path.join(cwd, 'files', 'abstract.txt')

with open(abstract_filepath, 'r', encoding='utf-8', errors='ignore') as f:
    text = f.read()
    print(text)
# Out:
# Machine learning addresses the question of how to build computers that improve automatically through experience. It is one of todays most rapidly growing technical fields, lying at the intersection of computer science and statistics, and at the core of artificial intelligence and data science. Recent progress in machine learning has been driven both by the development of new learning algorithms and theory and by the ongoing explosion in the availability of online data and low-cost computation. The adoption of data-intensive machine-learning methods can be found throughout science, technology and commerce, leading to more evidence-based decision-making across many walks of life, including health care, manufacturing, education, financial modeling, policing, and marketing.

# %%
history_filepath = os.path.join(cwd, 'files', 'history.txt')

with open(history_filepath, 'r', encoding='utf-8', errors='ignore') as fp:
    text1 = fp.read()
    print(text1)
# Out:
# Pre-History – Period between the appearance of Homo ("humans"; first stone tools c. three million years ago) and the invention of writing systems (for the Ancient Near East: c. five thousand years ago).
# Paleolithic – the earliest period of the Stone Age
# Lower Paleolithic – time of archaic human species, predates Homo sapiens
# Middle Paleolithic – coexistence of archaic and anatomically modern human species
# Upper Paleolithic – worldwide expansion of anatomically modern humans, the disappearance of archaic humans by extinction or admixture with modern humans; earliest evidence for pictorial art.
# Mesolithic (Epipaleolithic) – a period in the development of human technology between the Palaeolithic and Neolithic periods.
# Neolithic – a period of primitive technological and social development, beginning about 10,200 BCE in parts of the Middle East, and later in other parts of the world.
# Chalcolithic (or "Eneolithic", "Copper Age") – still largely Neolithic in character, where early copper metallurgy appeared alongside the use of stone tools.
# Bronze Age – not part of prehistory for all regions and civilizations who had adopted or developed a writing system.
# Iron Age – not part of prehistory for all civilizations who had introduced written records during the Bronze Age.
# Protohistory – period between prehistory and history, during which a culture or civilization has not yet developed writing but other cultures have already noted its existence in their own writings; the absolute timescale of "protohistory" varies widely depending on the region, from the late 4th millennium BCE in the Ancient Near East to the present in the case of uncontacted peoples.
# Ancient History – Aggregate of past events from the beginning of recorded human history and extending as far as the Early Middle Ages or the Postclassical Era. The span of recorded history is roughly less than five thousand years, beginning with the earliest linguistic records in the third millennium BCE in Mesopotamia and Egypt.
# Classical Antiquity – Broad term for a long period of cultural history centered on the Mediterranean Sea, comprising the interlocking civilizations of ancient Greece and ancient Rome, collectively known as the Greco-Roman world. It is the period in which Greek and Roman society flourished and wielded great influence throughout Europe, North Africa and the Middle East.
# Post-Classical History – Period of time that immediately followed ancient history. Depending on the continent, the era generally falls between the years CE 200–600 and CE 1200–1500. The major classical civilizations that the era follows are Han China (ending in 220), the Western Roman Empire (in 476), the Gupta Empire (in the 550s), and the Sasanian Empire (in 651).
# Middle Ages – Lasted from the 5th to the 15th century. It began with the collapse of the Western Roman Empire in 476 and is variously demarcated by historians as ending with the Fall of Constantinople in 1453, merging into the Renaissance and the Age of Discovery.
# Early Middle Ages (also called Dark Ages)
# High Middle Ages
# Late Middle Ages
# Modern History – After the post-classical era
# Early Modern Period – The chronological limits of this period are open to debate. It emerges from the Late Middle Ages (c. 1500), demarcated by historians as beginning with the Fall of Constantinople in 1453, in forms such as the Italian Renaissance in the West, the Ming Dynasty in the East, and the rise of the Aztec in the New World. The period ends with the beginning of the Age of Revolutions.
# Late Modern Period – Began approximately in the mid-18th century; notable historical milestones included the French Revolution, the American Revolution, the Industrial Revolution and the Great Divergence
# Contemporary History – History within living memory. It shifts forward with the generations, and today is the span of historic events from approximately 1945 that are immediately relevant to the present time.

# %% [markdown]
# # Data Exploration

# %%
# load spacy instance
nlp = spacy.load('en_core_web_md')

# %%
# convert text file to spacy doc object
doc = nlp(text)
doc
# Out:
# Machine learning addresses the question of how to build computers that improve automatically through experience. It is one of todays most rapidly growing technical fields, lying at the intersection of computer science and statistics, and at the core of artificial intelligence and data science. Recent progress in machine learning has been driven both by the development of new learning algorithms and theory and by the ongoing explosion in the availability of online data and low-cost computation. The adoption of data-intensive machine-learning methods can be found throughout science, technology and commerce, leading to more evidence-based decision-making across many walks of life, including health care, manufacturing, education, financial modeling, policing, and marketing.

# %%
print(f'Text length: {len(doc)}')

for idx, token in enumerate(doc):
    print(idx, token.text, token.pos_, token.dep_)
# Out:
# Text length: 134
# 0 Machine NOUN compound
# 1 learning NOUN nsubj
# 2 addresses VERB ROOT
# 3 the DET det
# 4 question NOUN dobj
# 5 of ADP prep
# 6 how SCONJ advmod
# 7 to PART aux
# 8 build VERB pcomp
# 9 computers NOUN dobj
# 10 that PRON nsubj
# 11 improve VERB relcl
# 12 automatically ADV advmod
# 13 through ADP prep
# 14 experience NOUN pobj
# 15 . PUNCT punct
# 16 It PRON nsubj
# 17 is AUX ROOT
# 18 one NUM attr
# 19 of ADP prep
# 20 todays NOUN pobj
# 21 most ADV advmod
# 22 rapidly ADV advmod
# 23 growing VERB amod
# 24 technical ADJ amod
# 25 fields NOUN appos
# 26 , PUNCT punct
# 27 lying VERB advcl
# 28 at ADP prep
# 29 the DET det
# 30 intersection NOUN pobj
# 31 of ADP prep
# 32 computer NOUN compound
# 33 science NOUN pobj
# 34 and CCONJ cc
# 35 statistics NOUN conj
# 36 , PUNCT punct
# 37 and CCONJ cc
# 38 at ADP conj
# 39 the DET det
# 40 core NOUN pobj
# 41 of ADP prep
# 42 artificial ADJ amod
# 43 intelligence NOUN nmod
# 44 and CCONJ cc
# 45 data NOUN conj
# 46 science NOUN pobj
# 47 . PUNCT punct
# 48 Recent ADJ amod
# 49 progress NOUN nsubjpass
# 50 in ADP prep
# 51 machine NOUN compound
# 52 learning NOUN pobj
# 53 has AUX aux
# 54 been AUX auxpass
# 55 driven VERB ROOT
# 56 both CCONJ preconj
# 57 by ADP agent
# 58 the DET det
# 59 development NOUN pobj
# 60 of ADP prep
# 61 new ADJ amod
# 62 learning NOUN compound
# 63 algorithms NOUN pobj
# 64 and CCONJ cc
# 65 theory NOUN conj
# 66 and CCONJ cc
# 67 by ADP conj
# 68 the DET det
# 69 ongoing ADJ amod
# 70 explosion NOUN pobj
# 71 in ADP prep
# 72 the DET det
# 73 availability NOUN pobj
# 74 of ADP prep
# 75 online ADJ amod
# 76 data NOUN pobj
# 77 and CCONJ cc
# 78 low ADJ amod
# 79 - PUNCT punct
# 80 cost NOUN compound
# 81 computation NOUN conj
# 82 . PUNCT punct
# 83 The DET det
# 84 adoption NOUN nsubjpass
# 85 of ADP prep
# 86 data NOUN npadvmod
# 87 - PUNCT punct
# 88 intensive ADJ amod
# 89 machine NOUN npadvmod
# 90 - PUNCT punct
# 91 learning VERB amod
# 92 methods NOUN pobj
# 93 can AUX aux
# 94 be AUX auxpass
# 95 found VERB ROOT
# 96 throughout ADP prep
# 97 science NOUN pobj
# 98 , PUNCT punct
# 99 technology NOUN conj
# 100 and CCONJ cc
# 101 commerce NOUN conj
# 102 , PUNCT punct
# 103 leading VERB advcl
# 104 to ADP prep
# 105 more ADJ amod
# 106 evidence NOUN npadvmod
# 107 - PUNCT punct
# 108 based VERB amod
# 109 decision NOUN compound
# 110 - PUNCT punct
# 111 making VERB pobj
# 112 across ADP prep
# 113 many ADJ amod
# 114 walks NOUN pobj
# 115 of ADP prep
# 116 life NOUN pobj
# 117 , PUNCT punct
# 118 including VERB prep
# 119 health NOUN compound
# 120 care NOUN pobj
# 121 , PUNCT punct
# 122 manufacturing NOUN conj
# 123 , PUNCT punct
# 124 education NOUN conj
# 125 , PUNCT punct
# 126 financial ADJ amod
# 127 modeling NOUN conj
# 128 , PUNCT punct
# 129 policing NOUN conj
# 130 , PUNCT punct
# 131 and CCONJ cc
# 132 marketing NOUN conj
# 133 . PUNCT punct

# %% [markdown]
# # Document Visualization

# %%
displacy.render(doc, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e2f3d88119894002851ecfdabb076c9e-0" class="displacy" width="20175" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Machine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">learning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">addresses</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">question</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">how</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">build</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">computers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">improve</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">automatically</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">through</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">experience.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">todays</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">rapidly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">growing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">technical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">fields,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">lying</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">intersection</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">computer</tspan>
#     <tspan class="displacy-tag"

# %%
# get all sentences and the number of tokens from the doc object
for sent in doc.sents:
    print(f'Sentence: {sent} \n Token count: {len(sent)}')
# Out:
# Sentence: Machine learning addresses the question of how to build computers that improve automatically through experience.
#  Token count: 16
# Sentence: It is one of todays most rapidly growing technical fields, lying at the intersection of computer science and statistics, and at the core of artificial intelligence and data science.
#  Token count: 32
# Sentence: Recent progress in machine learning has been driven both by the development of new learning algorithms and theory and by the ongoing explosion in the availability of online data and low-cost computation.
#  Token count: 35
# Sentence: The adoption of data-intensive machine-learning methods can be found throughout science, technology and commerce, leading to more evidence-based decision-making across many walks of life, including health care, manufacturing, education, financial modeling, policing, and marketing.
#  Token count: 51

# %% [markdown]
# # Sentence Similarity

# %%
sentence1 = list(doc.sents)[0]
sentence2 = list(doc.sents)[1]
sentence3 = list(doc.sents)[2]
sentence4 = list(doc.sents)[3]

print(sentence1, '\n')
print(sentence2, '\n')
print(sentence3, '\n')
print(sentence4)
# Out:
# Machine learning addresses the question of how to build computers that improve automatically through experience.
#
# It is one of todays most rapidly growing technical fields, lying at the intersection of computer science and statistics, and at the core of artificial intelligence and data science.
#
# Recent progress in machine learning has been driven both by the development of new learning algorithms and theory and by the ongoing explosion in the availability of online data and low-cost computation.
#
# The adoption of data-intensive machine-learning methods can be found throughout science, technology and commerce, leading to more evidence-based decision-making across many walks of life, including health care, manufacturing, education, financial modeling, policing, and marketing.

# %%
print('Sentence 1 & 2 Similarity: {:.2%}'.format(sentence1.similarity(sentence2)))
print('Sentence 1 & 3 Similarity: {:.2%}'.format(sentence1.similarity(sentence3)))
print('Sentence 2 & 4 Similarity: {:.2%}'.format(sentence2.similarity(sentence4)))
print('Sentence 3 & 4 Similarity: {:.2%}'.format(sentence3.similarity(sentence4)))
# Out:
# Sentence 1 & 2 Similarity: 88.42%
# Sentence 1 & 3 Similarity: 91.20%
# Sentence 2 & 4 Similarity: 93.60%
# Sentence 3 & 4 Similarity: 90.96%

# %%
# access document text
doc.text
# Out:
# 'Machine learning addresses the question of how to build computers that improve automatically through experience. It is one of todays most rapidly growing technical fields, lying at the intersection of computer science and statistics, and at the core of artificial intelligence and data science. Recent progress in machine learning has been driven both by the development of new learning algorithms and theory and by the ongoing explosion in the availability of online data and low-cost computation. The adoption of data-intensive machine-learning methods can be found throughout science, technology and commerce, leading to more evidence-based decision-making across many walks of life, including health care, manufacturing, education, financial modeling, policing, and marketing.'

# %%
[t.text for t in doc]
# Out:
# ['Machine',
#  'learning',
#  'addresses',
#  'the',
#  'question',
#  'of',
#  'how',
#  'to',
#  'build',
#  'computers',
#  'that',
#  'improve',
#  'automatically',
#  'through',
#  'experience',
#  '.',
#  'It',
#  'is',
#  'one',
#  'of',
#  'todays',
#  'most',
#  'rapidly',
#  'growing',
#  'technical',
#  'fields',
#  ',',
#  'lying',
#  'at',
#  'the',
#  'intersection',
#  'of',
#  'computer',
#  'science',
#  'and',
#  'statistics',
#  ',',
#  'and',
#  'at',
#  'the',
#  'core',
#  'of',
#  'artificial',
#  'intelligence',
#  'and',
#  'data',
#  'science',
#  '.',
#  'Recent',
#  'progress',
#  'in',
#  'machine',
#  'learning',
#  'has',
#  'been',
#  'driven',
#  'both',
#  'by',
#  'the',
#  'development',
#  'of',
#  'new',
#  'learning',
#  'algorithms',
#  'and',
#  'theory',
#  'and',
#  'by',
#  'the',
#  'ongoing',
#  'explosion',
#  'in',
#  'the',
#  'availability',
#  'of',
#  'online',
#  'data',
#  'and',
#  'low',
#  '-',
#  'cost',
#  'computation',
#  '.',
#  'The',
#  'adoption',
#  'of',
#  'data',
#  '-',
#  'intensive',
#  'machine',
#  '-',
#  'learning',
#  'methods',
#  'can',
#  'be',
#  'found',
#  'throughout',
#  'science',
#  ',',
#  'technology',
#  'and',
#  'commerce',
#  ',',
#  'leading',
#  'to',
#  'more',
#  'evidence',
#  '-',
#  'based',
#  'decision',
#  '-',
#  'making',
#  'across',
#  'many',
#  'walks',
#  'of',
#  'life',
#  ',',
#  'including',
#  'health',
#  'care',
#  ',',
#  'manufacturing',
#  ',',
#  'education',
#  ',',
#  'financial',
#  'modeling',
#  ',',
#  'policing',
#  ',',
#  'and',
#  'marketing',
#  '.']

# %%
# iterate over the text in the document
for text in doc.text:
    print(text)
# Out:
# M
# a
# c
# h
# i
# n
# e
#
# l
# e
# a
# r
# n
# i
# n
# g
#
# a
# d
# d
# r
# e
# s
# s
# e
# s
#
# t
# h
# e
#
# q
# u
# e
# s
# t
# i
# o
# n
#
# o
# f
#
# h
# o
# w
#
# t
# o
#
# b
# u
# i
# l
# d
#
# c
# o
# m
# p
# u
# t
# e
# r
# s
#
# t
# h
# a
# t
#
# i
# m
# p
# r
# o
# v
# e
#
# a
# u
# t
# o
# m
# a
# t
# i
# c
# a
# l
# l
# y
#
# t
# h
# r
# o
# u
# g
# h
#
# e
# x
# p
# e
# r
# i
# e
# n
# c
# e
# .
#
# I
# t
#
# i
# s
#
# o
# n
# e
#
# o
# f
#
# t
# o
# d
# a
# y
# s
#
# m
# o
# s
# t
#
# r
# a
# p
# i
# d
# l
# y
#
# g
# r
# o
# w
# i
# n
# g
#
# t
# e
# c
# h
# n
# i
# c
# a
# l
#
# f
# i
# e
# l
# d
# s
# ,
#
# l
# y
# i
# n
# g
#
# a
# t
#
# t
# h
# e
#
# i
# n
# t
# e
# r
# s
# e
# c
# t
# i
# o
# n
#
# o
# f
#
# c
# o
# m
# p
# u
# t
# e
# r
#
# s
# c
# i
# e
# n
# c
# e
#
# a
# n
# d
#
# s
# t
# a
# t
# i
# s
# t
# i
# c
# s
# ,
#
# a
# n
# d
#
# a
# t
#
# t
# h
# e
#
# c
# o
# r
# e
#
# o
# f
#
# a
# r
# t
# i
# f
# i
# c
# i
# a
# l
#
# i
# n
# t
# e
# l
# l
# i
# g
# e
# n
# c
# e
#
# a
# n
# d
#
# d
# a
# t
# a
#
# s
# c
# i
# e
# n
# c
# e
# .
#
# R
# e
# c
# e
# n
# t
#
# p
# r
# o
# g
# r
# e
# s
# s
#
# i
# n
#
# m
# a
# c
# h
# i
# n
# e
#
# l
# e
# a
# r
# n
# i
# n
# g
#
# h
# a
# s
#
# b
# e
# e
# n
#
# d
# r
# i
# v
# e
# n
#
# b
# o
# t
# h
#
# b
# y
#
# t
# h
# e
#
# d
# e
# v
# e
# l
# o
# p
# m
# e
# n
# t
#
# o
# f
#
# n
# e
# w
#
# l
# e
# a
# r
# n
# i
# n
# g
#
# a
# l
# g
# o
# r
# i
# t
# h
# m
# s
#
# a
# n
# d
#
# t
# h
# e
# o
# r
# y
#
# a
# n
# d
#
# b
# y
#
# t
# h
# e
#
# o
# n
# g
# o
# i
# n
# g
#
# e
# x
# p
# l
# o
# s
# i
# o
# n
#
# i
# n
#
# t
# h
# e
#
# a
# v
# a
# i
# l
# a
# b
# i
# l
# i
# t
# y
#
# o
# f
#
# o
# n
# l
# i
# n
# e
#
# d
# a
# t
# a
#
# a
# n
# d
#
# l
# o
# w
# -
# c
# o
# s
# t
#
# c
# o
# m
# p
# u
# t
# a
# t
# i
# o
# n
# .
#
# T
# h
# e
#
# a
# d
# o
# p
# t
# i
# o
# n
#
# o
# f
#
# d
# a
# t
# a
# -
# i
# n
# t
# e
# n
# s
# i
# v
# e
#
# m
# a
# c
# h
# i
# n
# e
# -
# l
# e
# a
# r
# n
# i
# n
# g
#
# m
# e
# t
# h
# o
# d
# s
#
# c
# a
# n
#
# b
# e
#
# f
# o
# u
# n
# d
#
# t
# h
# r
# o
# u
# g
# h
# o
# u
# t
#
# s
# c
# i
# e
# n
# c
# e
# ,
#
# t
# e
# c
# h
# n
# o
# l
# o
# g
# y
#
# a
# n
# d
#
# c
# o
# m
# m
# e
# r
# c
# e
# ,
#
# l
# e
# a
# d
# i
# n
# g
#
# t
# o
#
# m
# o
# r
# e
#
# e
# v
# i
# d
# e
# n
# c
# e
# -
# b
# a
# s
# e
# d
#
# d
# e
# c
# i
# s
# i
# o
# n
# -
# m
# a
# k
# i
# n
# g
#
# a
# c
# r
# o
# s
# s
#
# m
# a
# n
# y
#
# w
# a
# l
# k
# s
#
# o
# f
#
# l
# i
# f
# e
# ,
#
# i
# n
# c
# l
# u
# d
# i
# n
# g
#
# h
# e
# a
# l
# t
# h
#
# c
# a
# r
# e
# ,
#
# m
# a
# n
# u
# f
# a
# c
# t
# u
# r
# i
# n
# g
# ,
#
# e
# d
# u
# c
# a
# t
# i
# o
# n
# ,
#
# f
# i
# n
# a
# n
# c
# i
# a
# l
#
# m
# o
# d
# e
# l
# i
# n
# g
# ,
#
# p
# o
# l
# i
# c
# i
# n
# g
# ,
#
# a
# n
# d
#
# m
# a
# r
# k
# e
# t
# i
# n
# g
# .

# %%
# get a span of tokens between 0 - 10
tok_10 = doc[:10]
tok_10
# Out:
# Machine learning addresses the question of how to build computers

# %%
displacy.render(docs=tok_10, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9e80e35daa7c42828c5a2a11ed74f23d-0" class="displacy" width="1800" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Machine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">learning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">addresses</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">question</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">how</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">build</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">computers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9e80e35daa7c42828c5a2a11ed74f23d-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9e80e35daa7c42828c5a2a11ed74f23d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9e80e35daa7c42828c5a2a11ed74f23d-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9e80e35daa7c42828c5a2a11ed74f23d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9e80e35daa7c42828c5a2a11ed74f23d-0-2" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9e80e35daa7c42828c5a2a11ed74f23d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,266.5 L587,254.5 603,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9e80e35daa7c42828c5a2a11ed74f23d-0-3" stroke-width="2px" d="M420,264.5 C420,89.5 745.0,89.5 745.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9e80e35daa7c42828c5a2a11ed74f23d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,266.5 L753.0,254.5 737.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9e80e35daa7c42828c5a2a11ed74f23d-0-4" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9e80e35daa7c42828c5a2a11ed74f23d-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,266.5 L923.0,254.5 907.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9e80e35daa7c42828c5a2a11ed74f23d-0-5" stroke-width="2px" d="M1120,264.5 C1120,89.5 1445.0,89.5 1445.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9e80e35daa7c42828c5a2a11ed74f23d-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,266.5 L1112,254.5 1128,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9e80e35daa7c42828c5a2a11ed74f23d-0-6" stroke-width="2px" d="M1295,264.5 C1295,177.0 1440.0,177.0 1440.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9e80e35daa7c42828c5a2a11ed74f23d-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,266.5 L1287,254.5 1303,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9e80e35daa7c42828c5a2a11ed74f23d-0-7" stroke-width="2px" d="M945,264.5 C945,2.0 1450.0,2.0 1450.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9e80e35daa7c42828c5a2a11ed74f23d-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1450.0,266.5 L1458.0,254.5 1442.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9e80e35daa7c42828c5a2a11ed74f23d-0-8" stroke-width="2px" d="M1470,264.5 C1470,177.0 1615.0,177.0 1615.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9e80e35daa7c42828c5a2a11ed74f23d-0-8" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1

# %%
# export given token attributes to a numpy ndarray
from spacy.attrs import LOWER, POS, ENT_TYPE, IS_ALPHA

token_array = doc.to_array([LOWER, POS, ENT_TYPE, IS_ALPHA])
token_array[:5]
# Out:
# array([[ 1826470356240629538,                   92,                    0,
#                            1],
#        [ 7342778914265824300,                   92,                    0,
#                            1],
#        [13677849008941035348,                  100,                    0,
#                            1],
#        [ 7425985699627899538,                   90,                    0,
#                            1],
#        [10779227342117629034,                   92,                    0,
#                            1]], dtype=uint64)

# %%
# save the current state to a directory
path = os.path.join(os.getcwd(), 'files', 'saved_file')
doc.to_disk(path)

# %%
# export the document contents to a binary string
bytes = doc.to_bytes()[:100]
bytes
# Out:
# b'\x89\xa4text\xda\x03\x0cMachine learning addresses the question of how to build computers that improve automaticall'

# %%
# load history text file
doc1 = nlp(text1)

# %%
print(f'Text length: {len(doc1)}')

for i, tok in enumerate(doc1):
    print(i, tok.text, tok.pos_, tok.dep_)
# Out:
# Text length: 732
# 0 Pre ADJ compound
# 1 - NOUN dobj
# 2 History NOUN conj
# 3 – PUNCT punct
# 4 Period NOUN dep
# 5 between ADP prep
# 6 the DET det
# 7 appearance NOUN pobj
# 8 of ADP prep
# 9 Homo PROPN pobj
# 10 ( PUNCT punct
# 11 " PUNCT punct
# 12 humans NOUN appos
# 13 " PUNCT punct
# 14 ; PUNCT punct
# 15 first ADJ amod
# 16 stone NOUN compound
# 17 tools NOUN ROOT
# 18 c. NOUN appos
# 19 three NUM compound
# 20 million NUM nummod
# 21 years NOUN npadvmod
# 22 ago ADV advmod
# 23 ) PUNCT punct
# 24 and CCONJ cc
# 25 the DET det
# 26 invention NOUN conj
# 27 of ADP prep
# 28 writing NOUN compound
# 29 systems NOUN pobj
# 30 ( PUNCT punct
# 31 for ADP prep
# 32 the DET det
# 33 Ancient PROPN compound
# 34 Near PROPN compound
# 35 East PROPN pobj
# 36 : PUNCT punct
# 37 c. NOUN appos
# 38 five NUM compound
# 39 thousand NUM nummod
# 40 years NOUN npadvmod
# 41 ago ADV advmod
# 42 ) PUNCT punct
# 43 . PUNCT punct
# 44
#  SPACE dep
# 45 Paleolithic PROPN nsubj
# 46 – PUNCT punct
# 47 the DET det
# 48 earliest ADJ amod
# 49 period NOUN appos
# 50 of ADP prep
# 51 the DET det
# 52 Stone PROPN compound
# 53 Age PROPN nmod
# 54
#  SPACE dep
# 55 Lower PROPN compound
# 56 Paleolithic PROPN pobj
# 57 – PUNCT punct
# 58 time NOUN appos
# 59 of ADP prep
# 60 archaic ADJ amod
# 61 human ADJ amod
# 62 species NOUN pobj
# 63 , PUNCT punct
# 64 predates VERB ROOT
# 65 Homo NOUN nsubj
# 66 sapiens VERB ccomp
# 67
#  SPACE dep
# 68 Middle PROPN compound
# 69 Paleolithic PROPN dobj
# 70 – PUNCT punct
# 71 coexistence NOUN dobj
# 72 of ADP prep
# 73 archaic ADJ amod
# 74 and CCONJ cc
# 75 anatomically ADV advmod
# 76 modern ADJ conj
# 77 human ADJ amod
# 78 species NOUN pobj
# 79
#  SPACE dep
# 80 Upper PROPN compound
# 81 Paleolithic PROPN appos
# 82 – PUNCT punct
# 83 worldwide ADV amod
# 84 expansion NOUN appos
# 85 of ADP prep
# 86 anatomically ADV advmod
# 87 modern ADJ amod
# 88 humans NOUN pobj
# 89 , PUNCT punct
# 90 the DET det
# 91 disappearance NOUN conj
# 92 of ADP prep
# 93 archaic ADJ amod
# 94 humans NOUN pobj
# 95 by ADP prep
# 96 extinction NOUN pobj
# 97 or CCONJ cc
# 98 admixture NOUN conj
# 99 with ADP prep
# 100 modern ADJ amod
# 101 humans NOUN pobj
# 102 ; PUNCT punct
# 103 earliest ADJ amod
# 104 evidence NOUN conj
# 105 for ADP prep
# 106 pictorial ADJ amod
# 107 art NOUN pobj
# 108 . PUNCT punct
# 109
#  SPACE dep
# 110 Mesolithic PROPN ROOT
# 111 ( PUNCT punct
# 112 Epipaleolithic PROPN appos
# 113 ) PUNCT punct
# 114 – PUNCT punct
# 115 a DET det
# 116 period NOUN appos
# 117 in ADP prep
# 118 the DET det
# 119 development NOUN pobj
# 120 of ADP prep
# 121 human ADJ amod
# 122 technology NOUN pobj
# 123 between ADP prep
# 124 the DET det
# 125 Palaeolithic ADJ amod
# 126 and CCONJ cc
# 127 Neolithic ADJ conj
# 128 periods NOUN pobj
# 129 . PUNCT punct
# 130
#  SPACE dep
# 131 Neolithic PROPN ROOT
# 132 – PUNCT punct
# 133 a DET det
# 134 period NOUN appos
# 135 of ADP prep
# 136 primitive ADJ amod
# 137 technological ADJ amod
# 138 and CCONJ cc
# 139 social ADJ conj
# 140 development NOUN pobj
# 141 , PUNCT punct
# 142 beginning VERB acl
# 143 about ADV advmod
# 144 10,200 NUM nummod
# 145 BCE PROPN dobj
# 146 in ADP prep
# 147 parts NOUN pobj
# 148 of ADP prep
# 149 the DET det
# 150 Middle PROPN compound
# 151 East PROPN pobj
# 152 , PUNCT punct
# 153 and CCONJ cc
# 154 later ADV advmod
# 155 in ADP prep
# 156 other ADJ amod
# 157 parts NOUN pobj
# 158 of ADP prep
# 159 the DET det
# 160 world NOUN pobj
# 161 . PUNCT punct
# 162
#  SPACE dep
# 163 Chalcolithic PROPN ROOT
# 164 ( PUNCT punct
# 165 or CCONJ cc
# 166 " PUNCT punct
# 167 Eneolithic PROPN conj
# 168 " PUNCT punct
# 169 , PUNCT punct
# 170 " PUNCT punct
# 171 Copper PROPN compound
# 172 Age PROPN npadvmod
# 173 " PUNCT punct
# 174 ) PUNCT punct
# 175 – PUNCT punct
# 176 still ADV advmod
# 177 largely ADV advmod
# 178 Neolithic ADJ appos
# 179 in ADP prep
# 180 character NOUN pobj
# 181 , PUNCT punct
# 182 where SCONJ advmod
# 183 early ADJ amod
# 184 copper NOUN compound
# 185 metallurgy NOUN nsubj
# 186 appeared VERB relcl
# 187 alongside ADP prep
# 188 the DET det
# 189 use NOUN pobj
# 190 of ADP prep
# 191 stone NOUN compound
# 192 tools NOUN pobj
# 193 . PUNCT punct
# 194
#  SPACE dep
# 195 Bronze PROPN compound
# 196 Age PROPN ROOT
# 197 – PUNCT punct
# 198 not PART neg
# 199 part NOUN appos
# 200 of ADP prep
# 201 prehistory NOUN pobj
# 202 for ADP prep
# 203 all DET det
# 204 regions NOUN pobj
# 205 and CCONJ cc
# 206 civilizations NOUN conj
# 207 who PRON nsubj
# 208 had AUX aux
# 209 adopted VERB relcl
# 210 or CCONJ cc
# 211 developed VERB conj
# 212 a DET det
# 213 writing NOUN compound
# 214 system NOUN dobj
# 215 . PUNCT punct
# 216
#  SPACE dep
# 217 Iron PROPN compound
# 218 Age PROPN ROOT
# 219 – PUNCT punct
# 220 not PART neg
# 221 part NOUN appos
# 222 of ADP prep
# 223 prehistory NOUN pobj
# 224 for ADP prep
# 225 all DET det
# 226 civilizations NOUN pobj
# 227 who PRON nsubj
# 228 had AUX aux
# 229 introduced VERB relcl
# 230 written VERB amod
# 231 records NOUN dobj
# 232 during ADP prep
# 233 the DET det
# 234 Bronze PROPN compound
# 235 Age PROPN pobj
# 236 . PUNCT punct
# 237
#  SPACE dep
# 238 Protohistory PROPN dep
# 239 – PUNCT punct
# 240 period NOUN nsubj
# 241 between ADP prep
# 242 prehistory NOUN pobj
# 243 and CCONJ cc
# 244 history NOUN conj
# 245 , PUNCT punct
# 246 during ADP prep
# 247 which PRON pobj
# 248 a DET det
# 249 culture NOUN nsubj
# 250 or CCONJ cc
# 251 civilization NOUN conj
# 252 has AUX aux
# 253 not PART neg
# 254 yet ADV advmod
# 255 developed VERB relcl
# 256 writing NOUN dobj
# 257 but CCONJ cc
# 258 other ADJ amod
# 259 cultures NOUN conj
# 260 have AUX aux
# 261 already ADV advmod
# 262 noted VERB ccomp
# 263 its PRON poss
# 264 existence NOUN dobj
# 265 in ADP prep
# 266 their PRON poss
# 267 own ADJ amod
# 268 writings NOUN pobj
# 269 ; PUNCT punct
# 270 the DET det
# 271 absolute ADJ amod
# 272 timescale NOUN nsubj
# 273 of ADP prep
# 274 " PUNCT punct
# 275 protohistory NOUN pobj
# 276 " PUNCT punct
# 277 varies VERB ROOT
# 278 widely ADV advmod
# 279 depending VERB prep
# 280 on ADP prep
# 281 the DET det
# 282 region NOUN pobj
# 283 , PUNCT punct
# 284 from ADP prep
# 285 the DET det
# 286 late ADJ amod
# 287 4th ADJ amod
# 288 millennium NOUN compound
# 289 BCE PROPN pobj
# 290 in ADP prep
# 291 the DET det
# 292 Ancient PROPN compound
# 293 Near PROPN compound
# 294 East PROPN pobj
# 295 to ADP prep
# 296 the DET det
# 297 present NOUN pobj
# 298 in ADP prep
# 299 the DET det
# 300 case NOUN pobj
# 301 of ADP prep
# 302 uncontacted ADJ amod
# 303 peoples NOUN pobj
# 304 . PUNCT punct
# 305
#  SPACE dep
# 306 Ancient PROPN compound
# 307 History NOUN ROOT
# 308 – PUNCT punct
# 309 Aggregate VERB ROOT
# 310 of ADP prep
# 311 past ADJ amod
# 312 events NOUN pobj
# 313 from ADP prep
# 314 the DET det
# 315 beginning NOUN pobj
# 316 of ADP prep
# 317 recorded VERB amod
# 318 human ADJ amod
# 319 history NOUN pobj
# 320 and CCONJ cc
# 321 extending VERB conj
# 322 as ADV advmod
# 323 far ADV advmod
# 324 as ADP prep
# 325 the DET det
# 326 Early PROPN compound
# 327 Middle PROPN compound
# 328 Ages PROPN pobj
# 329 or CCONJ cc
# 330 the DET det
# 331 Postclassical PROPN compound
# 332 Era PROPN conj
# 333 . PUNCT punct
# 334 The DET det
# 335 span NOUN nsubj
# 336 of ADP prep
# 337 recorded VERB amod
# 338 history NOUN pobj
# 339 is AUX ROOT
# 340 roughly ADV advmod
# 341 less ADJ amod
# 342 than ADP quantmod
# 343 five NUM compound
# 344 thousand NUM nummod
# 345 years NOUN attr
# 346 , PUNCT punct
# 347 beginning VERB advcl
# 348 with ADP prep
# 349 the DET det
# 350 earliest ADJ amod
# 351 linguistic ADJ amod
# 352 records NOUN pobj
# 353 in ADP prep
# 354 the DET det
# 355 third ADJ amod
# 356 millennium NOUN pobj
# 357 BCE PROPN appos
# 358 in ADP prep
# 359 Mesopotamia PROPN pobj
# 360 and CCONJ cc
# 361 Egypt PROPN conj
# 362 . PUNCT punct
# 363
#  SPACE dep
# 364 Classical PROPN compound
# 365 Antiquity PROPN ROOT
# 366 – PUNCT punct
# 367 Broad ADJ amod
# 368 term NOUN appos
# 369 for ADP prep
# 370 a DET det
# 371 long ADJ amod
# 372 period NOUN pobj
# 373 of ADP prep
# 374 cultural ADJ amod
# 375 history NOUN pobj
# 376 centered VERB acl
# 377 on ADP prep
# 378 the DET det
# 379 Mediterranean PROPN compound
# 380 Sea PROPN pobj
# 381 , PUNCT punct
# 382 comprising VERB acl
# 383 the DET det
# 384 interlocking VERB amod
# 385 civilizations NOUN dobj
# 386 of ADP prep
# 387 ancient ADJ amod
# 388 Greece PROPN pobj
# 389 and CCONJ cc
# 390 ancient ADJ amod
# 391 Rome PROPN conj
# 392 , PUNCT punct
# 393 collectively ADV advmod
# 394 known VERB acl
# 395 as ADP prep
# 396 the DET det
# 397 Greco PROPN compound
# 398 - PUNCT punct
# 399 Roman ADJ amod
# 400 world NOUN pobj
# 401 . PUNCT punct
# 402 It PRON nsubj
# 403 is AUX ROOT
# 404 the DET det
# 405 period NOUN attr
# 406 in ADP prep
# 407 which PRON pobj
# 408 Greek ADJ amod
# 409 and CCONJ cc
# 410 Roman ADJ conj
# 411 society NOUN nsubj
# 412 flourished VERB relcl
# 413 and CCONJ cc
# 414 wielded VERB conj
# 415 great ADJ amod
# 416 influence NOUN dobj
# 417 throughout ADP prep
# 418 Europe PROPN pobj
# 419 , PUNCT punct
# 420 North PROPN compound
# 421 Africa PROPN conj
# 422 and CCONJ cc
# 423 the DET det
# 424 Middle PROPN compound
# 425 East PROPN conj
# 426 . PUNCT punct
# 427
#  SPACE dep
# 428 Post ADJ amod
# 429 - ADJ amod
# 430 Classical ADJ amod
# 431 History NOUN ROOT
# 432 – PUNCT punct
# 433 Period NOUN appos
# 434 of ADP prep
# 435 time NOUN pobj
# 436 that PRON nsubj
# 437 immediately ADV advmod
# 438 followed VERB relcl
# 439 ancient ADJ amod
# 440 history NOUN dobj
# 441 . PUNCT punct
# 442 Depending VERB prep
# 443 on ADP prep
# 444 the DET det
# 445 continent NOUN pobj
# 446 , PUNCT punct
# 447 the DET det
# 448 era NOUN nsubj
# 449 generally ADV advmod
# 450 falls VERB ROOT
# 451 between ADP prep
# 452 the DET det
# 453 years NOUN pobj
# 454 CE PROPN compound
# 455 200–600 NUM appos
# 456 and CCONJ cc
# 457 CE PROPN conj
# 458 1200–1500 NUM nummod
# 459 . PUNCT punct
# 460 The DET det
# 461 major ADJ amod
# 462 classical ADJ amod
# 463 civilizations NOUN nsubj
# 464 that SCONJ dobj
# 465 the DET det
# 466 era NOUN nsubj
# 467 follows VERB relcl
# 468 are AUX ROOT
# 469 Han PROPN compound
# 470 China PROPN attr
# 471 ( PUNCT punct
# 472 ending VERB acl
# 473 in ADP prep
# 474 220 NUM pobj
# 475 ) PUNCT punct
# 476 , PUNCT punct
# 477 the DET det
# 478 Western PROPN compound
# 479 Roman PROPN compound
# 480 Empire PROPN conj
# 481 ( PUNCT punct
# 482 in ADP prep
# 483 476 NUM pobj
# 484 ) PUNCT punct
# 485 , PUNCT punct
# 486 the DET det
# 487 Gupta PROPN compound
# 488 Empire PROPN conj
# 489 ( PUNCT punct
# 490 in ADP prep
# 491 the DET det
# 492 550s NOUN pobj
# 493 ) PUNCT punct
# 494 , PUNCT punct
# 495 and CCONJ cc
# 496 the DET det
# 497 Sasanian PROPN compound
# 498 Empire PROPN conj
# 499 ( PUNCT punct
# 500 in ADP prep
# 501 651 NUM pobj
# 502 ) PUNCT punct
# 503 . PUNCT punct
# 504
#  SPACE dep
# 505 Middle PROPN compound
# 506 Ages PROPN nsubj
# 507 – PUNCT punct
# 508 Lasted VERB ROOT
# 509 from ADP prep
# 510 the DET det
# 511 5th NOUN pobj
# 512 to ADP prep
# 513 the DET det
# 514 15th ADJ amod
# 515 century NOUN pobj
# 516 . PUNCT punct
# 517 It PRON nsubj
# 518 began VERB ROOT
# 519 with ADP prep
# 520 the DET det
# 521 collapse NOUN pobj
# 522 of ADP prep
# 523 the DET det
# 524 Western PROPN compound
# 525 Roman PROPN compound
# 526 Empire PROPN pobj
# 527 in ADP prep
# 528 476 NUM pobj
# 529 and CCONJ cc
# 530 is AUX auxpass
# 531 variously ADV advmod
# 532 demarcated VERB conj
# 533 by ADP agent
# 534 historians NOUN pobj
# 535 as ADP prep
# 536 ending VERB pcomp
# 537 with ADP prep
# 538 the DET det
# 539 Fall NOUN pobj
# 540 of ADP prep
# 541 Constantinople PROPN pobj
# 542 in ADP prep
# 543 1453 NUM pobj
# 544 , PUNCT punct
# 545 merging VERB advcl
# 546 into ADP prep
# 547 the DET det
# 548 Renaissance PROPN pobj
# 549 and CCONJ cc
# 550 the DET det
# 551 Age PROPN conj
# 552 of ADP prep
# 553 Discovery PROPN pobj
# 554 . PUNCT punct
# 555
#  SPACE dep
# 556 Early PROPN compound
# 557 Middle PROPN compound
# 558 Ages PROPN nsubj
# 559 ( PUNCT punct
# 560 also ADV advmod
# 561 called VERB acl
# 562 Dark PROPN compound
# 563 Ages PROPN oprd
# 564 ) PUNCT punct
# 565
#  SPACE dep
# 566 High PROPN compound
# 567 Middle PROPN compound
# 568 Ages PROPN nmod
# 569
#  SPACE dep
# 570 Late PROPN compound
# 571 Middle PROPN compound
# 572 Ages PROPN appos
# 573
#  SPACE dep
# 574 Modern ADJ compound
# 575 History NOUN appos
# 576 – PUNCT punct
# 577 After ADP prep
# 578 the DET det
# 579 post ADJ amod
# 580 - ADJ amod
# 581 classical ADJ amod
# 582 era NOUN pobj
# 583
#  SPACE dep
# 584 Early PROPN compound
# 585 Modern PROPN compound
# 586 Period PROPN appos
# 587 – PUNCT punct
# 588 The DET det
# 589 chronological ADJ amod
# 590 limits NOUN nsubj
# 591 of ADP prep
# 592 this DET det
# 593 period NOUN pobj
# 594 are AUX ROOT
# 595 open ADJ acomp
# 596 to PART aux
# 597 debate VERB xcomp
# 598 . PUNCT punct
# 599 It PRON nsubj
# 600 emerges VERB ROOT
# 601 from ADP prep
# 602 the DET det
# 603 Late PROPN compound
# 604 Middle PROPN compound
# 605 Ages PROPN pobj
# 606 ( PUNCT punct
# 607 c. PROPN appos
# 608 1500 NUM nummod
# 609 ) PUNCT punct
# 610 , PUNCT punct
# 611 demarcated VERB acl
# 612 by ADP agent
# 613 historians NOUN pobj
# 614 as ADP prep
# 615 beginning VERB pcomp
# 616 with ADP prep
# 617 the DET det
# 618 Fall NOUN pobj
# 619 of ADP prep
# 620 Constantinople PROPN pobj
# 621 in ADP prep
# 622 1453 NUM pobj
# 623 , PUNCT punct
# 624 in ADP prep
# 625 forms NOUN pobj
# 626 such ADJ amod
# 627 as ADP prep
# 628 the DET det
# 629 Italian ADJ amod
# 630 Renaissance PROPN pobj
# 631 in ADP prep
# 632 the DET det
# 633 West PROPN pobj
# 634 , PUNCT punct
# 635 the DET det
# 636 Ming PROPN compound
# 637 Dynasty PROPN conj
# 638 in ADP prep
# 639 the DET det
# 640 East PROPN pobj
# 641 , PUNCT punct
# 642 and CCONJ cc
# 643 the DET det
# 644 rise NOUN conj
# 645 of ADP prep
# 646 the DET det
# 647 Aztec PROPN pobj
# 648 in ADP prep
# 649 the DET det
# 650 New PROPN compound
# 651 World PROPN pobj
# 652 . PUNCT punct
# 653 The DET det
# 654 period NOUN nsubj
# 655 ends VERB ROOT
# 656 with ADP prep
# 657 the DET det
# 658 beginning NOUN pobj
# 659 of ADP prep
# 660 the DET det
# 661 Age PROPN pobj
# 662 of ADP prep
# 663 Revolutions PROPN pobj
# 664 . PUNCT punct
# 665
#  SPACE dep
# 666 Late PROPN compound
# 667 Modern PROPN compound
# 668 Period PROPN nsubj
# 669 – PUNCT punct
# 670 Began VERB ccomp
# 671 approximately ADV advmod
# 672 in ADP prep
# 673 the DET det
# 674 mid-18th ADJ amod
# 675 century NOUN pobj
# 676 ; PUNCT punct
# 677 notable ADJ amod
# 678 historical ADJ amod
# 679 milestones NOUN nsubj
# 680 included VERB ROOT
# 681 the DET det
# 682 French PROPN compound
# 683 Revolution PROPN dobj
# 684 , PUNCT punct
# 685 the DET det
# 686 American PROPN compound
# 687 Revolution PROPN conj
# 688 , PUNCT punct
# 689 the DET det
# 690 Industrial PROPN compound
# 691 Revolution PROPN conj
# 692 and CCONJ cc
# 693 the DET det
# 694 Great PROPN compound
# 695 Divergence PROPN nmod
# 696
#  SPACE dep
# 697 Contemporary ADJ compound
# 698 History NOUN conj
# 699 – PUNCT punct
# 700 History NOUN appos
# 701 within ADP prep
# 702 living VERB amod
# 703 memory NOUN pobj
# 704 . PUNCT punct
# 705 It PRON nsubj
# 706 shifts VERB ROOT
# 707 forward ADV advmod
# 708 with ADP prep
# 709 the DET det
# 710 generations NOUN pobj
# 711 , PUNCT punct
# 712 and CCONJ cc
# 713 today NOUN nsubj
# 714 is AUX conj
# 715 the DET det
# 716 span NOUN attr
# 717 of ADP prep
# 718 historic ADJ amod
# 719 events NOUN pobj
# 720 from ADP prep
# 721 approximately ADV advmod
# 722 1945 NUM pobj
# 723 that PRON nsubj
# 724 are AUX relcl
# 725 immediately ADV advmod
# 726 relevant ADJ acomp
# 727 to ADP prep
# 728 the DET det
# 729 present ADJ amod
# 730 time NOUN pobj
# 731 . PUNCT punct

# %%
# iterate over the entities in the document
for ent in doc1.ents:
    print(ent)
# Out:
# first
# three million years ago
# five thousand years ago
# Palaeolithic
# Neolithic
# about 10,200
# BCE
# the Middle East
# Chalcolithic
# Eneolithic
# Copper Age
# Neolithic
# the Bronze Age
# the late 4th millennium
# BCE
# the Ancient Near East
# the Early Middle Ages
# roughly less than five thousand years
# third
# BCE
# Mesopotamia
# Egypt
# the Mediterranean Sea
# Greece
# Rome
# Greco
# Greek
# Roman
# Europe
# North Africa
# the Middle East
# years
# Han China
# 220
# the Western Roman Empire
# 476
# the Gupta Empire
# the Sasanian Empire
# 651
# 5th
# the 15th century
# the Western Roman Empire
# 476
# the Fall of Constantinople
# 1453
# Renaissance
# Discovery
# Early Middle Ages
# Dark Ages
# Late Middle Ages
# Early Modern Period
# the Late Middle Ages
# 1500
# the Fall of Constantinople
# 1453
# the Italian Renaissance
# West
# the Ming Dynasty
# East
# Aztec
# the mid-18th century
# the French Revolution
# today

# %%
doc1.has_vector
# Out:
# True

# %%
# visualize entities within the history text file
displacy.render(docs=doc1, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Pre-History – Period between the appearance of Homo (&quot;humans&quot;;
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  stone tools c.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three million years ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ) and the invention of writing systems (for the Ancient Near East: c.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     five thousand years ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ).</br>Paleolithic – the earliest period of the Stone Age</br>Lower Paleolithic – time of archaic human species, predates Homo sapiens</br>Middle Paleolithic – coexistence of archaic and anatomically modern human species</br>Upper Paleolithic – worldwide expansion of anatomically modern humans, the disappearance of archaic humans by extinction or admixture with modern humans; earliest evidence for pictorial art.</br>Mesolithic (Epipaleolithic) – a period in the development of human technology between the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Palaeolithic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  and
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Neolithic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  periods.</br>Neolithic – a period of primitive technological and social development, beginning
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 10,200
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BCE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in parts of
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Middle East
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , and later in other parts of the world.</br>
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chalcolithic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  (or &quot;
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Eneolithic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# &quot;, &quot;
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Copper Age
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# &quot;) – still largely
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Neolithic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in character, where early copper metallurgy appeared alongside the use of stone tools.</br>Bronze Age – not part of prehistory for all regions and civilizations who had adopted or developed a writing system.</br>Iron Age – not part of prehistory for all civilizations who had introduced written records during
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Bronze Age
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# .</br>Protohistory – period between prehistory and history, during which a culture or civilization has not yet developed writing but other cultures have already noted its existence in their own writings; the absolute timescale of &quot;protohistory&quot; varies widely depending on the region, from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the late 4th millennium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BCE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Ancient Near East
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  to the present in the case of uncontacted peoples.</br>Ancient History – Aggregate of past events from the beginning of recorded human history and extending as far as
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Early Middle Ages
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  or the Postclassical Era. The span of recorded history is
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     roughly less than five thousand years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , beginning with the earliest linguistic records in the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  millennium
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BCE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; bo
